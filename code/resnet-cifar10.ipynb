# %%
import pandas as pd

import numpy as np
import six
import sys
sys.modules['sklearn.externals.six'] = six
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import _tree
import random

from skopt.space import Real, Categorical, Integer
random.seed(42)

# %%
def _sample_search_space(param_space, categorical_columns, num_samples = 1000):
    """
        Uniformly sample the search space for generating explanation dataset. Maintains the original order of search space.
        Sensitive to order: place categoricals first and everything else later.

        Args:
        - param_space (param space): parameter space
        - categorical_columns (list): list of categorical variables
        - num_samples (int): number of generated samples

        Returns:
        - new_data (numpy array): the augmented dataset
        """
    samples = []
    
    for _ in range(num_samples):
        sample = [param.rvs() for param in param_space]
        samples.append(sample)
    
    # Create a DataFrame with the samples
    param_names = [param.name for param in param_space]
    df = pd.DataFrame(samples, columns=param_names)
    
    # One-hot encode categorical variables and add dynamic prefixes
    encoded_columns = []
    for col in categorical_columns:
        prefix = f'categorical_{col}'
        encoded = pd.get_dummies(df[col], prefix=prefix).astype(float)
        encoded_columns.extend(encoded.columns)
        df = pd.concat([df.drop(col, axis=1), encoded], axis=1)
    
    # Rearrange columns: categorical columns in front, followed by non-categorical columns
    ordered_columns = []
    for col in param_space:
        if col.name in categorical_columns:
            ordered_columns.extend([col_name for col_name in df.columns if col_name.startswith(f'categorical_{col.name}')])
        elif col.name in df.columns:
            ordered_columns.append(col.name)
    
    # Now you have the DataFrame with categorical variables in the front and non-categorical variables in their original order
    df = df[ordered_columns]
    
    # Convert numerical variables from lists to floats
    for col in param_names:
        if col not in categorical_columns:
            df[col] = df[col]
    df = df.to_numpy().astype(np.float32)
    return df

# %%
df = pd.read_csv('cifar10_resnet_25.csv')
df = df.drop(columns=['training_epoch_accuracy','training_epoch_loss','validation_epoch_loss','validation_evaluation_accuracy_vs_iterations','validation_evaluation_loss_vs_iterations'])

# %%
ye = df['validation_epoch_accuracy']
y = ye.to_numpy()

Xe = df.drop(columns='validation_epoch_accuracy')
dum1 = pd.get_dummies(Xe['conv3_depth'],prefix = 'categorical_conv3depth')
dum2 = pd.get_dummies(Xe['optimizer'],prefix = 'categorical_optimizer')
dum3 = pd.get_dummies(Xe['conv4_depth'],prefix = 'categorical_conv4depth')
dum4 = pd.get_dummies(Xe['version'],prefix = 'categorical_version')
dum5 = pd.get_dummies(Xe['pooling'],prefix = 'categorical_pooling')
Xe = Xe.drop(columns = ['conv3_depth','optimizer','conv4_depth','version','pooling'])
Xe = pd.concat([dum1, dum2, dum3, dum4, dum5, Xe], axis=1)

param_space = [
    Categorical(categories=['4', '8'], name='conv3_depth'),
    Categorical(categories=['adam', 'sgd', 'rmsprop'], name='optimizer'),
    Categorical(categories=['6', '23', '36'], name='conv4_depth'),
    Categorical(categories=['v1','v2', 'next'], name='version'),
    Categorical(categories=['avg', 'max'], name='pooling'),
    Integer(low=0, high=1, name='learning_rate')
]

# Define the categorical columns
categorical_columns = ['conv3_depth','optimizer','conv4_depth','version','pooling']

print (Xe.iloc[np.argmin(ye.values)])
print (np.max(ye.values))
# Out:
# categorical_conv3depth_4         0.0
# categorical_conv3depth_8         1.0
# categorical_optimizer_adam       1.0
# categorical_optimizer_rmsprop    0.0
# categorical_optimizer_sgd        0.0
# categorical_conv4depth_6         1.0
# categorical_conv4depth_23        0.0
# categorical_conv4depth_36        0.0
# categorical_version_next         0.0
# categorical_version_v1           1.0
# categorical_version_v2           0.0
# categorical_pooling_avg          0.0
# categorical_pooling_max          1.0
# learning_rate                    0.1
# Name: 0, dtype: float64
# 0.707120001

# %%
import GPy

def _train_gp(x_train, y_train):
    """
        Train a GPR model from Gpy library.

        Args:
        - X_train (numpy array): input data
        - Y_train (numpy array): ground truth data
        - n_samples (int): number of times to sample the posterior of the trained gp
        - sample_points (numpy array): new input X locations where the posterior would be sampled

        Returns:
        - model (trained gp model): trained gp model
        - mean_y (numpy array): mean of the Y from the sampled posterior
        - std_y (numpy array): std dev of the Y from the sampled posterior
        - sum_log_likelihoods (numpy array): returns the likelihood of observing
          each input point given the trained model
    """
    kernel = GPy.kern.RBF(input_dim=x_train.shape[1])
    model = GPy.models.GPRegression(x_train, y_train, kernel)
    model.optimize()
    return model

def augment_with_noise(data, n_samples=1000):
    """
    Add noise to the input data to create new points and generate a new dataset
    with the desired number of samples.

    Args:
    - data (numpy array): the input data
    - num_samples (int): the number of samples to generate
    - noise_factor (float): the magnitude of the noise to add to the data (default: 0.01)

    Returns:
    - new_data (numpy array): the augmented dataset
    """
    n_points, n_dims = data.shape
    new_data = np.empty((n_samples, n_dims))  # Create a new array for the augmented data

    for i in range(n_samples):
        noise = np.random.uniform(low=-0.01, high=0.01, size=n_dims)
        new_data[i] = data[np.random.randint(n_points)] + noise

    return new_data
    
model = _train_gp(Xe.to_numpy(), y.reshape(-1, 1))
test_set = _sample_search_space(param_space, categorical_columns, num_samples = 100)
test_set = augment_with_noise(test_set)
mean_y, var_y = model.predict_noiseless(test_set, full_cov=False)
flattened_mean = [item for sublist in mean_y for item in sublist]
flattened_var = [item for sublist in var_y for item in sublist]
std = np.sqrt(flattened_var)

samp = _sample_search_space(param_space, categorical_columns, num_samples = 1000)
samp = augment_with_noise(samp)
yee, var = model.predict_noiseless(samp, full_cov=False)
yee = np.squeeze(yee, axis=1)

# %%
from rulekit import RuleKit
from rulekit.regression import RuleRegressor
from rulekit.params import Measures
RuleKit.init()

reg = RuleRegressor(
    induction_measure=Measures.C2,
    pruning_measure=Measures.C2,
    voting_measure=Measures.C2,
)
reg.fit(samp, yee)
predictions = reg.predict(test_set)
ru = []
for rule in reg.model.rules:
    ru.append(str(rule))
    print (rule)

print(len(ru))

from itertools import combinations

# Given rule list in the new representation
rule_list = ru

# Function to extract features from a rule
def extract_features(rule):
    # Extract only the part before "THEN" and split by "AND"
    features = set(rule.split('IF')[1].split(" THEN")[0].split(" AND"))
    return features

# Function to calculate Jaccard similarity between two rules
def jaccard_similarity(rule1, rule2):
    features1 = extract_features(rule1)
  
    features2 = extract_features(rule2)
   
    intersection = len(features1.intersection(features2))
    union = len(features1.union(features2))
    
    if union == 0:
        return 0.0  # Handle the case where both sets are empty
    else:
        return intersection / union

# Calculate Jaccard similarity between all pairs of rules and collect them
similarities = []
for rule1, rule2 in combinations(rule_list, 2):
    similarity = jaccard_similarity(rule1, rule2)
    similarities.append(similarity)

# Calculate the mean Jaccard similarity for the entire rule set
mean_similarity = sum(similarities) / len(similarities)

print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

## Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(predictions, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (count_within_bounds / len(predictions)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")
# Out:
# IF att6 = <0.99, inf) AND att14 = (-inf, 0.99) AND att5 = (-inf, 0.0063) AND att8 = (-inf, 0.0058) AND att2 = (-inf, 1.00) AND att10 = (-inf, 0.50) AND att4 = <0.0094, inf) AND att12 = <0.0096, inf) THEN label = {0.99} [0.99,0.99]
# IF att6 = <0.99, inf) AND att14 = (-inf, 0.99) AND att2 = (-inf, 1.00) AND att10 = (-inf, 0.50) AND att4 = <0.99, inf) AND att12 = <0.0096, inf) AND att3 = (-inf, 0.0094) THEN label = {0.99} [0.98,1.00]
# IF att6 = <0.99, inf) AND att10 = (-inf, 0.50) AND att4 = <0.0094, inf) AND att12 = <0.0096, inf) THEN label = {0.99} [0.94,1.03]
# IF att6 = <0.99, inf) AND att10 = <0.0097, inf) AND att1 = <1.00, 1.01) AND att4 = <0.0094, inf) AND att13 = (-inf, 0.0033) THEN label = {0.93} [0.93,0.93]
# IF att9 = <-0.008, inf) AND att8 = (-inf, 0.0046) AND att7 = (-inf, 0.0097) AND att1 = <-6.1E-4, 1.01) AND att10 = <0.0097, inf) AND att4 = <0.0094, inf) AND att13 = (-inf, 0.0027) THEN label = {0.93} [0.92,0.93]
# IF att9 = <-0.0064, inf) AND att5 = <-0.0077, inf) AND att8 = (-inf, 0.0083) AND att7 = (-inf, 0.0094) AND att1 = (-inf, 1.00) AND att10 = <0.50, inf) AND att4 = <0.0094, inf) AND att12 = <0.0096, inf) AND att3 = (-inf, 0.0083) THEN label = {0.93} [0.93,0.94]
# IF att6 = <0.99, inf) AND att4 = <0.0092, inf) AND att13 = <-0.0093, inf) AND att12 = <0.99, inf) THEN label = {0.96} [0.91,1.01]
# IF att9 = (-inf, 1.01) AND att6 = <0.50, 1.01) AND att5 = <-0.0054, inf) AND att14 = (-inf, 1.00) AND att8 = (-inf, 0.0071) AND att7 = <-0.0093, inf) AND att10 = (-inf, 0.99) AND att1 = <-0.0041, inf) AND att4 = (-inf, 1.00) AND att3 = (-inf, 0.0093) AND att12 = <0.99, inf) THEN label = {0.87} [0.83,0.91]
# IF att6 = <0.0095, inf) AND att14 = <0.0038, inf) AND att2 = <-0.0065, inf) AND att1 = <-0.0033, inf) AND att4 = <0.0085, inf) AND att13 = (-inf, 0.0038) AND att3 = <-0.0045, 0.0093) AND att12 = <0.99, inf) THEN label = {0.93} [0.87,0.99]
# IF att9 = <-0.0089, inf) AND att6 = (-inf, 1.00) AND att7 = <-0.0074, inf) AND att4 = <0.0085, inf) AND att12 = <0.0096, inf) THEN label = {0.88} [0.79,0.97]
# IF att6 = <-0.0038, 1.00) AND att14 = <-0.0035, inf) AND att5 = <-0.0057, inf) AND att8 = <-0.0044, inf) AND att7 = (-inf, 0.50) AND att2 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att1 = <-0.0015, 1.00) AND att4 = <0.0085, 1.00) AND att13 = (-inf, 0.0099) THEN label = {0.91} [0.81,1.00]
# IF att6 = (-inf, 1.00) AND att5 = (-inf, 0.50) AND att4 = <0.0088, inf) AND att13 = (-inf, 0.0079) THEN label = {0.88} [0.80,0.96]
# IF att9 = <-0.0056, inf) AND att5 = (-inf, 1.00) AND att14 = <-0.0067, inf) AND att8 = <0.0063, inf) AND att7 = (-inf, 0.0083) AND att2 = (-inf, 1.01) AND att10 = <-0.007, inf) AND att1 = (-inf, 0.99) AND att13 = <0.0045, inf) AND att12 = <0.0091, inf) AND att3 = (-inf, 0.0093) THEN label = {0.81} [0.77,0.85]
# IF att9 = <-0.0046, inf) AND att6 = (-inf, 0.50) AND att14 = <0.50, 1.01) AND att8 = <-0.0084, inf) AND att2 = <-0.0066, 1.00) AND att10 = (-inf, 0.99) AND att1 = <-0.0039, 1.01) AND att4 = <0.0085, 1.01) AND att13 = <0.99, inf) AND att3 = <-0.0059, inf) AND att12 = (-inf, 0.0081) THEN label = {0.77} [0.77,0.78]
# IF att9 = (-inf, 1.00) AND att5 = (-inf, 0.008) AND att14 = <-0.0091, 0.005) AND att8 = (-inf, 1.00) AND att2 = <-0.0069, 1.00) AND att10 = (-inf, 0.99) AND att1 = <-0.0014, 1.00) AND att4 = <0.0085, inf) AND att12 = (-inf, 0.0037) THEN label = {0.79} [0.79,0.79]
# IF att9 = (-inf, 1.01) AND att5 = (-inf, 0.0081) AND att14 = <-0.0091, 0.0013) AND att2 = <-0.0073, inf) AND att1 = <-0.0039, inf) AND att4 = <0.0085, 1.01) AND att3 = <-0.0093, inf) AND att12 = (-inf, 0.0011) THEN label = {0.80} [0.79,0.82]
# IF att6 = (-inf, 0.99) AND att14 = <-0.0091, inf) AND att8 = <-0.0033, inf) AND att2 = <-0.0073, 1.01) AND att1 = (-inf, 1.00) AND att4 = <0.0085, 1.01) AND att13 = <0.99, inf) AND att12 = <-0.0087, inf) THEN label = {0.77} [0.71,0.84]
# IF att9 = <-0.0046, inf) AND att6 = (-inf, 1.00) AND att14 = <-0.0091, 1.01) AND att5 = <-0.0056, 0.008) AND att11 = <-0.0088, inf) AND att2 = <-0.0043, inf) AND att13 = <0.99, inf) AND att4 = (-inf, 1.00) AND att3 = <-0.0019, inf) THEN label = {0.51} [0.41,0.61]
# IF att9 = <-0.0046, inf) AND att6 = <-0.0078, 1.00) AND att5 = <-0.0049, 0.008) AND att14 = <-0.0084, 1.01) AND att2 = <-0.007, 1.00) AND att1 = <-2.1E-4, inf) AND att10 = <-0.0073, inf) AND att4 = <0.0085, inf) AND att12 = (-inf, 0.0079) AND att3 = <-0.0032, inf) THEN label = {0.83} [0.80,0.87]
# IF att6 = <1.00, inf) AND att5 = <-0.0063, inf) AND att8 = <-0.0043, inf) AND att7 = <-0.0069, inf) AND att2 = <-0.0062, 1.00) AND att10 = (-inf, 0.99) AND att1 = <0.0053, inf) AND att12 = (-inf, 0.0097) AND att3 = <-0.0021, inf) THEN label = {0.86} [0.78,0.94]
# IF att14 = <-0.0091, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.004, 1.00) AND att2 = <-0.007, 1.00) AND att1 = <-0.0014, 1.00) AND att10 = <-0.0066, inf) AND att4 = <0.0085, inf) AND att13 = <0.99, 1.01) AND att3 = <-0.0068, inf) THEN label = {0.79} [0.71,0.87]
# IF att9 = <-0.0053, inf) AND att5 = <-0.0064, 0.008) AND att14 = <0.0041, inf) AND att8 = <-0.0049, 0.51) AND att11 = <-0.0089, inf) AND att4 = <0.0085, inf) AND att12 = (-inf, 0.0097) AND att3 = <-0.0038, inf) THEN label = {0.83} [0.75,0.91]
# IF att9 = <-0.0052, inf) AND att6 = (-inf, 1.00) AND att14 = <-0.0091, inf) AND att5 = <-0.0094, 0.008) AND att7 = <-0.0052, inf) AND att11 = (-inf, 1.00) AND att2 = <-0.0033, inf) AND att1 = <2.5E-4, inf) AND att4 = <0.0085, inf) AND att13 = <1.00, inf) AND att3 = <-0.0093, inf) THEN label = {0.79} [0.70,0.87]
# IF att5 = <-0.0068, inf) AND att7 = (-inf, 1.01) AND att2 = <-0.0074, inf) AND att11 = <1.4E-4, inf) AND att1 = (-inf, 1.00) AND att4 = <0.0085, inf) AND att13 = <0.99, inf) AND att3 = (-inf, 1.00) THEN label = {0.81} [0.74,0.87]
# IF att6 = <-0.0042, inf) AND att5 = (-inf, 0.008) AND att11 = <-0.0089, inf) AND att1 = <-0.006, inf) AND att4 = <0.0085, inf) AND att12 = (-inf, 0.0076) THEN label = {0.80} [0.73,0.88]
# IF att9 = <-0.0081, 1.00) AND att5 = (-inf, 0.0068) AND att14 = <-0.0089, inf) AND att4 = <0.0085, inf) AND att13 = <1.00, 1.01) THEN label = {0.78} [0.70,0.85]
# IF att6 = (-inf, 0.50) AND att5 = (-inf, 0.0088) AND att2 = <-0.0066, inf) AND att4 = <0.0085, inf) AND att12 = (-inf, 0.0086) THEN label = {0.76} [0.69,0.82]
# IF att8 = <-0.0085, inf) AND att2 = <-0.0065, inf) AND att10 = (-inf, 1.01) AND att1 = <0.99, 1.01) AND att4 = <0.0089, 1.01) AND att12 = (-inf, 0.0071) THEN label = {0.80} [0.74,0.87]
# IF att5 = <0.0094, inf) AND att2 = (-inf, 1.00) AND att1 = <-0.0037, inf) AND att4 = <0.0085, inf) AND att13 = (-inf, 1.01) AND att12 = (-inf, 0.0071) THEN label = {0.65} [0.59,0.70]
# IF att6 = <-0.0084, 0.005) AND att8 = <-0.0085, inf) AND att2 = (-inf, 1.01) AND att1 = (-inf, 1.01) AND att10 = <0.99, inf) AND att12 = <-0.0096, 0.0074) AND att3 = <0.0094, 1.01) THEN label = {0.47} [0.46,0.48]
# IF att9 = <-0.0088, inf) AND att6 = <-0.0083, 0.005) AND att5 = <-0.0087, inf) AND att8 = (-inf, 0.0066) AND att7 = (-inf, 1.01) AND att10 = (-inf, 0.0094) AND att1 = <-5.3E-4, 1.00) AND att12 = (-inf, 0.0074) AND att3 = <0.99, 1.01) THEN label = {0.51} [0.51,0.51]
# IF att9 = (-inf, 0.0055) AND att6 = (-inf, 0.0015) AND att8 = (-inf, 1.01) AND att7 = (-inf, -4.3E-4) AND att10 = (-inf, 0.0094) AND att1 = <-0.0032, inf) AND att12 = (-inf, 0.0074) AND att3 = <0.0096, inf) THEN label = {0.52} [0.52,0.53]
# IF att9 = (-inf, 1.00) AND att6 = <-0.0059, 0.0042) AND att5 = <-0.0085, inf) AND att7 = <-0.0059, inf) AND att2 = (-inf, 1.00) AND att1 = (-inf, 1.00) AND att4 = (-inf, 0.0023) AND att12 = <-0.0096, 0.0074) AND att3 = <0.0096, inf) THEN label = {0.48} [0.46,0.50]
# IF att6 = (-inf, 0.005) AND att14 = (-inf, 0.50) AND att8 = <-0.0076, inf) AND att7 = <3.6E-4, inf) AND att10 = (-inf, 0.50) AND att1 = <-0.001, inf) AND att12 = (-inf, 0.0074) AND att3 = <0.0096, 1.01) THEN label = {0.51} [0.50,0.51]
# IF att9 = (-inf, 0.99) AND att6 = <-0.0082, 0.005) AND att14 = <0.99, inf) AND att8 = (-inf, 1.01) AND att11 = <-0.0031, 1.01) AND att2 = <-7.1E-4, inf) AND att10 = <-0.0073, inf) AND att13 = <0.99, inf) AND att3 = <0.99, 1.00) THEN label = {0.48} [0.46,0.50]
# IF att6 = (-inf, 0.0023) AND att7 = <-0.0032, inf) AND att10 = <-0.0048, inf) AND att13 = <0.99, inf) AND att3 = <0.0094, inf) THEN label = {0.48} [0.41,0.55]
# IF att9 = <-0.0043, 1.00) AND att6 = <7.9E-4, inf) AND att5 = (-inf, 1.01) AND att8 = <-0.0087, 1.00) AND att7 = (-inf, 1.01) AND att2 = <-0.0013, inf) AND att10 = <-0.0083, inf) AND att1 = <-4.4E-4, inf) AND att3 = <0.0089, inf) AND att12 = (-inf, 0.0048) THEN label = {0.53} [0.46,0.59]
# IF att6 = <0.99, 1.01) AND att5 = (-inf, 0.009) AND att8 = <-0.0087, inf) AND att7 = (-inf, 0.0088) AND att11 = <-0.0082, 0.99) AND att1 = (-inf, 1.00) AND att12 = (-inf, 0.0061) AND att3 = <0.99, inf) THEN label = {0.59} [0.59,0.59]
# IF att5 = <-0.0097, 0.007) AND att14 = (-inf, 1.00) AND att8 = <-0.0082, inf) AND att7 = <-0.0055, 1.00) AND att4 = <-0.0081, 0.0085) AND att12 = (-inf, 0.0074) AND att3 = (-inf, 1.01) THEN label = {0.51} [0.48,0.54]
# IF att9 = (-inf, 0.50) AND att6 = <-7.0E-4, inf) AND att5 = <-0.0071, 0.0096) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.01) AND att13 = (-inf, 1.01) AND att12 = (-inf, 0.0074) AND att3 = <0.0095, 1.01) THEN label = {0.53} [0.46,0.59]
# IF att9 = <-0.0063, 1.00) AND att6 = (-inf, 1.01) AND att5 = <-0.0087, inf) AND att14 = <-0.0018, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.0066, inf) AND att2 = <-0.0022, inf) AND att1 = (-inf, 1.01) AND att10 = <-0.0063, 1.00) AND att4 = <-0.0043, 0.0073) AND att3 = <0.0089, 1.00) AND att12 = <-0.0096, 0.0026) THEN label = {0.50} [0.40,0.60]
# IF att9 = (-inf, 1.00) AND att6 = <-0.0087, 0.0046) AND att5 = <-0.0083, inf) AND att2 = (-inf, 1.00) AND att1 = <7.7E-4, inf) AND att4 = <7.0E-4, inf) AND att3 = <0.0098, inf) AND att12 = <0.0086, inf) THEN label = {0.57} [0.53,0.60]
# IF att5 = (-inf, 0.009) AND att14 = (-inf, 0.99) AND att8 = <0.0029, inf) AND att7 = (-inf, 1.00) AND att11 = <-0.0057, 0.51) AND att13 = <0.0083, inf) AND att4 = (-inf, 0.0056) AND att12 = <0.0053, inf) THEN label = {0.60} [0.53,0.67]
# IF att9 = <-0.0039, 1.00) AND att6 = <1.2E-4, inf) AND att8 = <-0.0087, 0.0094) AND att7 = (-inf, 1.00) AND att2 = <-0.0092, 1.01) AND att11 = <-0.0073, 1.00) AND att1 = <-0.0051, 1.01) AND att10 = (-inf, 1.00) AND att13 = <0.0083, inf) AND att4 = <-0.0093, inf) AND att12 = <-0.0096, inf) AND att3 = <0.99, 1.00) THEN label = {0.56} [0.51,0.61]
# IF att6 = <0.0051, inf) AND att5 = <-0.0068, inf) AND att14 = <-0.007, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.0089, 1.01) AND att2 = <-0.0071, 1.01) AND att10 = (-inf, 0.005) AND att1 = <0.0047, inf) AND att4 = (-inf, 0.0053) AND att3 = <1.00, inf) THEN label = {0.64} [0.58,0.69]
# IF att14 = (-inf, 1.01) AND att8 = <-0.0084, inf) AND att7 = (-inf, 1.01) AND att2 = (-inf, 1.01) AND att10 = <-0.0088, inf) AND att1 = <-0.0073, inf) AND att4 = <-0.0089, 0.0089) AND att12 = (-inf, 0.99) AND att3 = <0.99, 1.01) THEN label = {0.51} [0.46,0.56]
# IF att9 = <0.0028, inf) AND att6 = (-inf, 1.01) AND att14 = (-inf, 1.00) AND att7 = <0.0021, inf) AND att2 = <0.99, inf) AND att10 = <-2.4E-4, inf) AND att4 = <-0.006, inf) AND att3 = <0.0089, inf) AND att12 = <-0.0062, inf) THEN label = {0.64} [0.57,0.70]
# IF att6 = (-inf, 0.0064) AND att10 = (-inf, 1.00) AND att13 = <0.0075, inf) AND att4 = (-inf, 0.0087) AND att3 = <0.0089, inf) THEN label = {0.51} [0.45,0.57]
# IF att6 = <-2.4E-4, 1.01) AND att5 = (-inf, 0.0089) AND att8 = <-0.0088, inf) AND att2 = (-inf, 1.01) AND att1 = <-0.0065, inf) AND att13 = <0.0072, 1.00) AND att3 = <0.0089, inf) AND att12 = <2.5E-4, inf) THEN label = {0.59} [0.52,0.66]
# IF att9 = <-0.006, 1.00) AND att6 = (-inf, 1.01) AND att14 = <-0.0052, inf) AND att5 = <-0.0046, inf) AND att8 = <-0.0059, 1.01) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att1 = <-0.0012, 1.01) AND att10 = (-inf, 1.00) AND att4 = (-inf, 0.0061) AND att3 = <0.99, inf) AND att12 = <0.50, inf) THEN label = {0.63} [0.59,0.66]
# IF att6 = <-0.0088, 1.01) AND att8 = <-0.0082, inf) AND att7 = (-inf, 0.50) AND att2 = (-inf, 1.00) AND att1 = <-0.0012, inf) AND att13 = <0.0064, inf) AND att3 = <0.99, 1.01) AND att12 = <0.50, inf) THEN label = {0.60} [0.57,0.63]
# IF att6 = (-inf, 1.00) AND att8 = <-0.0084, 1.00) AND att7 = (-inf, 1.01) AND att11 = <-0.0046, inf) AND att2 = <-6.5E-4, 1.00) AND att1 = <-0.0028, 1.01) AND att10 = (-inf, 0.99) AND att4 = (-inf, 0.0068) AND att13 = (-inf, 0.0064) AND att3 = <0.0089, inf) AND att12 = (-inf, 1.01) THEN label = {0.64} [0.59,0.69]
# IF att9 = <-0.0087, inf) AND att6 = (-inf, 1.00) AND att5 = <-0.0077, 0.0064) AND att8 = <-0.007, 1.00) AND att2 = (-inf, 1.01) AND att11 = <-0.0017, 0.99) AND att1 = <-0.0059, 1.01) AND att4 = <-0.0055, 0.0053) AND att12 = <0.50, inf) THEN label = {0.63} [0.59,0.66]
# IF att14 = <6.8E-4, inf) AND att5 = (-inf, 0.0031) AND att2 = (-inf, 1.00) AND att1 = <-0.0065, 1.00) AND att4 = (-inf, 0.003) AND att12 = <0.50, 1.00) AND att3 = (-inf, 1.00) THEN label = {0.65} [0.60,0.69]
# IF att5 = <-0.0094, 0.0089) AND att14 = (-inf, 1.01) AND att7 = <-0.0079, inf) AND att2 = <0.0013, 1.01) AND att11 = <-0.005, inf) AND att1 = <-0.0068, 1.00) AND att13 = (-inf, 0.0068) AND att4 = <-0.0081, inf) AND att3 = <0.0093, 1.01) THEN label = {0.64} [0.58,0.70]
# IF att9 = (-inf, 1.01) AND att6 = (-inf, 1.01) AND att7 = (-inf, 1.00) AND att11 = (-inf, 0.99) AND att10 = <-0.0045, inf) AND att1 = (-inf, 0.99) AND att4 = <-0.0093, inf) AND att13 = <-0.0082, 0.0066) AND att12 = <0.99, 1.01) AND att3 = <0.0093, inf) THEN label = {0.63} [0.57,0.70]
# IF att9 = (-inf, 0.99) AND att6 = (-inf, 0.99) AND att14 = (-inf, 1.01) AND att5 = <-0.0057, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.0097, 1.00) AND att2 = <-0.0078, inf) AND att10 = <-0.0041, 1.00) AND att1 = (-inf, 1.00) AND att13 = (-inf, 0.0056) AND att4 = (-inf, 0.002) AND att3 = <0.99, inf) THEN label = {0.64} [0.62,0.66]
# IF att6 = (-inf, 1.00) AND att14 = (-inf, 1.01) AND att5 = <-0.0096, inf) AND att8 = <-0.0048, inf) AND att7 = (-inf, 1.00) AND att2 = <-0.007, 1.01) AND att1 = <-0.0015, 1.00) AND att10 = <-0.0034, 1.01) AND att4 = <-0.0095, inf) AND att3 = <0.0093, inf) AND att12 = <0.99, inf) THEN label = {0.63} [0.57,0.69]
# IF att9 = <-0.0062, 1.00) AND att5 = <-0.0077, inf) AND att14 = (-inf, 1.00) AND att7 = <-0.0083, 1.00) AND att2 = (-inf, 1.01) AND att1 = <-0.0081, 0.0069) AND att13 = <-0.0076, 0.0069) AND att4 = <-0.0062, inf) AND att3 = <0.0093, inf) AND att12 = (-inf, 1.01) THEN label = {0.64} [0.55,0.73]
# IF att14 = (-inf, 1.01) AND att8 = <-0.0083, inf) AND att7 = <-2.4E-4, 1.00) AND att2 = <-0.001, 1.01) AND att11 = <9.2E-4, inf) AND att10 = (-inf, 0.99) AND att13 = (-inf, 0.0067) AND att3 = <0.50, 1.00) AND att12 = <0.99, inf) THEN label = {0.63} [0.62,0.65]
# IF att6 = (-inf, 1.01) AND att5 = (-inf, 0.0097) AND att14 = (-inf, 1.01) AND att11 = <-0.0091, inf) AND att2 = (-inf, 1.00) AND att10 = (-inf, 1.01) AND att1 = <-0.0063, inf) AND att4 = <-0.0089, inf) AND att3 = <0.0093, inf) AND att12 = <0.99, 1.01) THEN label = {0.63} [0.56,0.70]
# IF att9 = (-inf, 1.00) AND att14 = <-0.001, inf) AND att1 = <6.5E-4, inf) AND att10 = <2.8E-4, inf) AND att3 = <0.0093, inf) AND att12 = <0.99, inf) THEN label = {0.60} [0.54,0.67]
# IF att6 = <-0.0039, 1.00) AND att5 = <-0.0081, inf) AND att14 = (-inf, 1.01) AND att7 = (-inf, 1.01) AND att2 = (-inf, 1.01) AND att11 = (-inf, 0.99) AND att1 = (-inf, 1.00) AND att10 = <-0.0074, inf) AND att13 = (-inf, 0.0058) AND att4 = (-inf, 0.0014) AND att12 = <1.00, inf) AND att3 = <0.50, inf) THEN label = {0.63} [0.58,0.67]
# IF att9 = <-0.0026, inf) AND att5 = <0.0058, inf) AND att8 = (-inf, 1.01) AND att7 = (-inf, 1.00) AND att11 = (-inf, 0.007) AND att4 = <0.0083, 1.00) AND att12 = <-0.0063, inf) AND att3 = (-inf, 0.0071) THEN label = {0.80} [0.73,0.87]
# IF att14 = <-0.0096, inf) AND att11 = <-0.0038, 1.00) AND att10 = <-0.0072, 1.01) AND att13 = (-inf, 1.01) AND att12 = <-0.0081, inf) AND att9 = (-inf, 1.00) AND att6 = <-0.0094, 0.99) AND att5 = <-0.0075, inf) AND att8 = <-0.0037, 1.00) AND att7 = <-0.0093, inf) AND att2 = <-0.0083, 1.01) AND att1 = <-0.0049, 1.01) AND att4 = <0.008, 1.01) AND att3 = <-0.0068, 0.50) THEN label = {0.84} [0.75,0.92]
# IF att9 = (-inf, 1.00) AND att6 = <-0.0081, 0.99) AND att5 = <-0.0071, inf) AND att7 = (-inf, 1.01) AND att2 = <-0.007, 1.01) AND att1 = <-0.0063, 1.00) AND att10 = (-inf, 1.00) AND att13 = <-0.0081, inf) AND att4 = (-inf, 1.00) AND att3 = <0.0086, 1.01) AND att12 = <0.99, 1.01) THEN label = {0.63} [0.57,0.69]
# IF att9 = <-0.0043, 1.00) AND att6 = (-inf, 1.00) AND att5 = <-0.0081, 1.01) AND att14 = <-0.0096, inf) AND att8 = (-inf, 1.01) AND att2 = <-0.0036, 1.01) AND att11 = (-inf, 1.01) AND att1 = <-0.007, 1.00) AND att10 = <-0.0031, 1.00) AND att4 = <0.0078, 1.01) AND att13 = (-inf, 1.01) AND att3 = (-inf, 1.00) THEN label = {0.82} [0.75,0.89]
# IF att9 = (-inf, 1.01) AND att14 = (-inf, 1.00) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att1 = (-inf, 1.00) AND att4 = <0.0073, 1.00) AND att13 = <-0.0053, inf) AND att12 = <0.0096, 1.00) AND att3 = <-0.0056, 0.0037) THEN label = {0.81} [0.74,0.87]
# IF att14 = <-0.0096, inf) AND att11 = <-6.8E-4, inf) AND att10 = (-inf, 1.01) AND att13 = (-inf, 1.01) AND att12 = <-0.009, 1.01) AND att9 = <-0.0047, 1.01) AND att6 = <-0.0092, 0.99) AND att5 = <-0.0049, 1.01) AND att8 = <-0.0051, 1.01) AND att7 = <-0.0092, 1.00) AND att2 = <-0.0063, inf) AND att1 = <-0.0083, 1.00) AND att4 = <0.0072, 1.01) AND att3 = (-inf, 0.99) THEN label = {0.84} [0.76,0.91]
# IF att6 = <-0.008, 1.01) AND att14 = <0.0056, 1.01) AND att5 = <0.0012, inf) AND att8 = (-inf, 1.00) AND att7 = (-inf, 0.99) AND att2 = <-0.002, 1.01) AND att11 = (-inf, 1.00) AND att1 = <-0.0058, 1.01) AND att4 = (-inf, 1.00) AND att3 = <0.0082, 1.00) THEN label = {0.63} [0.54,0.73]
# IF att6 = (-inf, 0.0077) AND att8 = <-0.0021, inf) AND att7 = (-inf, 1.00) AND att4 = (-inf, 0.0084) AND att3 = <0.0076, inf) AND att12 = (-inf, 0.0093) THEN label = {0.51} [0.46,0.56]
# IF att9 = (-inf, 1.00) AND att6 = (-inf, 0.0094) AND att14 = <0.99, 1.01) AND att5 = <0.0066, inf) AND att8 = <8.9E-4, 1.01) AND att2 = (-inf, 1.01) AND att10 = <-0.008, 1.01) AND att4 = <0.0068, inf) AND att13 = <-0.0055, inf) AND att3 = <-0.0084, 0.0078) THEN label = {0.78} [0.74,0.82]
# IF att9 = <-0.0056, 0.0082) AND att6 = (-inf, 0.0097) AND att8 = <-0.0058, 1.01) AND att7 = (-inf, 1.00) AND att11 = <3.5E-4, 1.01) AND att2 = (-inf, 1.01) AND att1 = <-0.0028, 1.00) AND att4 = <-0.0093, 1.00) AND att13 = <-0.0086, 1.00) AND att12 = <-0.006, inf) AND att3 = (-inf, 0.50) THEN label = {0.72} [0.65,0.80]
# IF att9 = (-inf, 1.01) AND att5 = (-inf, 1.01) AND att7 = <-0.0081, inf) AND att4 = <0.0064, 0.0073) AND att3 = (-inf, 0.0076) AND att12 = (-inf, 1.00) THEN label = {0.65} [0.60,0.70]
# IF att6 = (-inf, 1.00) AND att5 = (-inf, 1.01) AND att8 = <-0.0056, inf) AND att2 = <-0.002, inf) AND att1 = <-0.0024, 1.01) AND att4 = <0.0061, 0.0075) AND att3 = (-inf, 0.009) THEN label = {0.66} [0.62,0.70]
# IF att11 = <1.01, inf) AND att10 = (-inf, 0.0051) THEN label = {0.87} [0.81,0.93]
# IF att9 = <-0.0094, inf) AND att14 = (-inf, 1.00) AND att8 = (-inf, 1.00) AND att7 = (-inf, 1.01) AND att11 = <-0.0065, inf) AND att2 = <-0.0016, 1.01) AND att1 = <-0.0083, 1.00) AND att10 = <-0.0056, inf) AND att4 = <0.0058, inf) AND att13 = (-inf, 0.99) AND att12 = <0.008, inf) AND att3 = <-0.0045, 0.50) THEN label = {0.92} [0.85,1.00]
# IF att9 = <-0.0091, 1.01) AND att6 = <-0.0096, inf) AND att14 = <0.0036, 1.01) AND att5 = <0.0094, 1.00) AND att8 = (-inf, 1.01) AND att10 = (-inf, 1.01) AND att1 = <-0.0038, inf) AND att4 = <0.0057, 1.00) AND att13 = <-0.0084, inf) AND att3 = <-0.0069, 0.0078) THEN label = {0.65} [0.59,0.71]
# IF att9 = <-0.0081, inf) AND att6 = <0.99, inf) AND att8 = <-0.0079, 0.0053) AND att7 = <-0.0092, 0.0094) AND att2 = <0.0014, inf) AND att1 = <-0.0072, 0.99) AND att13 = (-inf, 0.99) AND att4 = (-inf, 0.50) AND att3 = (-inf, 0.0096) THEN label = {0.83} [0.77,0.90]
# IF att9 = <-0.0094, inf) AND att6 = (-inf, 0.0065) AND att5 = <-0.008, 0.99) AND att8 = <-0.0052, 1.01) AND att7 = (-inf, 1.00) AND att2 = <-0.0012, inf) AND att11 = <-0.008, 1.01) AND att10 = (-inf, 1.00) AND att1 = <-0.0027, inf) AND att13 = (-inf, 0.99) AND att3 = <-0.0092, 0.01) THEN label = {0.88} [0.81,0.94]
# IF att6 = <-0.0088, 0.0049) AND att8 = (-inf, 1.00) AND att2 = (-inf, 1.01) AND att1 = <-0.0029, inf) AND att4 = (-inf, 0.99) AND att3 = (-inf, 0.0088) AND att12 = <0.99, inf) THEN label = {0.75} [0.72,0.79]
# IF att6 = (-inf, 1.00) AND att5 = (-inf, 0.99) AND att11 = <-0.0087, inf) AND att10 = (-inf, 1.01) AND att1 = (-inf, 1.00) AND att13 = (-inf, 0.99) AND att4 = (-inf, 0.50) AND att3 = (-inf, 0.0088) AND att12 = (-inf, 1.00) THEN label = {0.78} [0.74,0.82]
# IF att9 = (-inf, 1.00) AND att6 = <-0.005, 0.99) AND att5 = (-inf, 0.99) AND att14 = (-inf, 1.01) AND att7 = <-0.0022, 1.01) AND att2 = <-0.0074, inf) AND att10 = <-0.007, inf) AND att1 = <-0.0058, inf) AND att4 = <-0.0072, 0.50) AND att3 = (-inf, 0.0092) THEN label = {0.63} [0.57,0.69]
# IF att6 = (-inf, 0.0076) AND att5 = (-inf, 0.99) AND att14 = <-0.0055, 1.00) AND att7 = <-0.0058, inf) AND att1 = (-inf, 1.01) AND att10 = <-0.0055, inf) AND att4 = (-inf, 0.99) AND att3 = <-0.0068, 0.0092) THEN label = {0.65} [0.59,0.71]
# IF att9 = <9.4E-4, inf) AND att6 = <-0.0034, inf) AND att5 = <0.0019, 0.99) AND att8 = (-inf, 1.00) AND att7 = <-0.0057, inf) AND att1 = <-0.0028, 0.99) AND att4 = (-inf, 1.00) AND att12 = <-0.0066, 1.00) AND att3 = (-inf, 0.0083) THEN label = {0.79} [0.71,0.87]
# IF att9 = <-0.007, 1.01) AND att6 = <-0.009, 1.00) AND att14 = <-0.0022, inf) AND att5 = <-0.0081, inf) AND att8 = (-inf, 1.01) AND att2 = <-0.0058, inf) AND att11 = (-inf, 1.01) AND att1 = <-0.007, 1.00) AND att10 = <-0.0082, 0.0058) AND att4 = <-0.0025, 1.01) AND att12 = <-0.0023, inf) AND att3 = <-0.0042, 0.0046) THEN label = {0.83} [0.75,0.91]
# IF att9 = (-inf, 1.00) AND att6 = (-inf, 1.01) AND att14 = <0.50, inf) AND att8 = <-0.005, 1.00) AND att7 = (-inf, 1.00) AND att11 = (-inf, 1.01) AND att1 = <-0.0062, 1.00) AND att10 = <-0.0055, 0.0089) AND att4 = <-0.0039, 1.01) AND att13 = <-0.0071, inf) AND att12 = <-0.0063, inf) AND att3 = <-0.0027, 0.0071) THEN label = {0.78} [0.71,0.85]
# IF att9 = <-0.0032, inf) AND att14 = <-0.0033, inf) AND att5 = <0.0052, inf) AND att8 = <-0.0063, inf) AND att7 = <-0.0075, inf) AND att2 = <-0.0068, 1.00) AND att10 = <-1.4E-4, 0.0094) AND att1 = <-0.0012, 1.00) AND att4 = <-0.0039, inf) AND att13 = (-inf, 1.01) AND att3 = (-inf, 0.004) THEN label = {0.81} [0.75,0.86]
# IF att9 = <-0.0081, 1.01) AND att6 = <-0.0042, 1.00) AND att14 = <0.0037, 1.00) AND att5 = <-0.0075, inf) AND att7 = <-0.0091, 1.01) AND att2 = <-0.0023, 0.0077) AND att11 = (-inf, 1.01) AND att10 = <-0.0091, 0.0076) AND att1 = (-inf, 1.01) AND att4 = (-inf, 1.01) AND att12 = <-0.0042, inf) AND att3 = (-inf, 0.0088) THEN label = {0.81} [0.74,0.87]
# IF att6 = (-inf, 0.50) AND att5 = <-0.0018, 1.01) AND att14 = <0.0025, 1.01) AND att7 = <-0.0046, inf) AND att2 = <-0.0023, 0.0091) AND att11 = <0.0013, inf) AND att1 = <0.99, 1.01) AND att4 = <-0.0063, inf) AND att3 = (-inf, 0.0063) THEN label = {0.68} [0.59,0.76]
# IF att9 = <-0.0041, 1.01) AND att6 = <-0.006, 1.01) AND att5 = <0.0065, 1.01) AND att14 = (-inf, 1.01) AND att7 = <-0.0019, 1.01) AND att2 = <-0.0048, 1.00) AND att11 = (-inf, 1.00) AND att10 = (-inf, 0.0097) AND att1 = (-inf, 1.00) AND att4 = <-0.0056, inf) AND att3 = <-0.0099, 0.0087) AND att12 = <-0.0032, 1.01) THEN label = {0.81} [0.74,0.87]
# IF att6 = <-0.0095, 1.00) AND att5 = <0.99, 1.00) AND att8 = <-0.0076, 1.00) AND att2 = <0.0054, inf) AND att10 = (-inf, 0.0097) AND att1 = <-0.0059, 1.00) AND att4 = <-0.0075, inf) AND att12 = <-0.0015, inf) AND att3 = (-inf, 0.0033) THEN label = {0.81} [0.74,0.88]
# IF att9 = (-inf, 0.0075) AND att14 = (-inf, 1.00) AND att5 = (-inf, 1.01) AND att8 = <-0.0091, 1.00) AND att7 = (-inf, 1.00) AND att2 = <0.0028, inf) AND att10 = (-inf, 0.0094) AND att1 = <0.0019, inf) AND att4 = <-0.0073, 0.0063) AND att3 = <-0.0078, 0.004) AND att12 = (-inf, 1.00) THEN label = {0.74} [0.68,0.80]
# IF att9 = <-0.0032, inf) AND att6 = <-0.0054, inf) AND att5 = (-inf, 1.01) AND att8 = <-0.0082, 1.00) AND att7 = <-0.0046, inf) AND att10 = <-0.0076, 0.0097) AND att13 = <-0.0075, 1.00) AND att4 = (-inf, 0.004) AND att12 = <-0.0053, 1.00) AND att3 = <-0.0073, 0.0065) THEN label = {0.79} [0.73,0.84]
# IF att5 = <1.00, 1.01) AND att8 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att10 = (-inf, 0.0074) AND att13 = (-inf, 1.00) AND att3 = (-inf, 0.0077) THEN label = {0.81} [0.74,0.88]
# IF att9 = <-0.0032, 1.01) AND att6 = <-0.0035, inf) AND att5 = <0.99, 1.01) AND att14 = (-inf, 1.00) AND att8 = (-inf, 1.00) AND att7 = <-0.0041, inf) AND att10 = <-0.008, 0.0093) AND att1 = <-0.0041, 1.00) AND att13 = <-0.0034, inf) AND att12 = <-0.0063, 1.01) AND att3 = <-0.0083, 0.0081) THEN label = {0.74} [0.70,0.79]
# IF att9 = <-0.0019, inf) AND att14 = <-0.0053, inf) AND att5 = <-0.0079, 1.01) AND att8 = <-8.4E-4, 1.01) AND att7 = <-0.0039, inf) AND att2 = <-0.0032, inf) AND att11 = (-inf, 1.00) AND att1 = <-0.006, inf) AND att13 = <1.00, inf) AND att4 = (-inf, 1.00) AND att3 = <-0.0073, 0.007) THEN label = {0.66} [0.61,0.71]
# IF att9 = (-inf, 0.0065) AND att6 = <-0.0043, 1.00) AND att14 = <-0.006, 1.00) AND att10 = <0.50, 1.00) AND att1 = (-inf, 0.99) AND att4 = (-inf, 0.50) AND att3 = <-0.0092, 0.0017) THEN label = {0.65} [0.59,0.71]
# IF att9 = <-0.0066, inf) AND att6 = <0.0077, inf) AND att5 = <1.00, inf) AND att2 = <0.001, inf) AND att10 = <0.50, inf) AND att13 = (-inf, 0.99) AND att4 = (-inf, 0.0068) THEN label = {0.77} [0.73,0.82]
# IF att9 = (-inf, 0.0075) AND att6 = <-0.0066, 1.00) AND att8 = <-0.0058, 1.01) AND att7 = <-0.0085, inf) AND att1 = <-0.0034, inf) AND att10 = <0.0087, 1.00) AND att13 = (-inf, 0.99) AND att4 = (-inf, 0.0043) AND att3 = <-0.0089, 0.0061) AND att12 = (-inf, 1.01) THEN label = {0.75} [0.71,0.79]
# IF att6 = (-inf, 0.99) AND att14 = <-0.004, inf) AND att8 = (-inf, 1.01) AND att2 = <-0.0035, inf) AND att1 = (-inf, 1.00) AND att10 = <0.99, inf) AND att13 = (-inf, 0.99) AND att4 = (-inf, 0.0067) AND att3 = (-inf, 0.0075) THEN label = {0.72} [0.68,0.75]
# IF att5 = (-inf, 1.01) AND att14 = (-inf, 1.01) AND att2 = <-0.0078, inf) AND att1 = <0.0095, inf) AND att10 = <0.99, inf) AND att4 = <-0.0047, 0.0051) AND att12 = <0.003, inf) THEN label = {0.60} [0.54,0.66]
# IF att14 = (-inf, 1.00) AND att7 = <-0.0043, 1.01) AND att2 = (-inf, 1.00) AND att11 = <0.004, inf) AND att1 = (-inf, 1.01) AND att10 = <-0.0065, inf) AND att13 = (-inf, 1.01) AND att3 = <-0.0071, 0.0081) AND att12 = (-inf, -0.0049) THEN label = {0.65} [0.62,0.68]
# IF att9 = (-inf, 1.00) AND att6 = <-0.0087, 1.00) AND att14 = <-0.0063, inf) AND att5 = <0.006, inf) AND att8 = <-0.0069, 1.01) AND att7 = <-0.0084, 1.01) AND att11 = (-inf, 1.00) AND att1 = <-0.0062, inf) AND att4 = <-0.0081, inf) AND att12 = <0.0028, 0.99) AND att3 = (-inf, 0.0023) THEN label = {0.62} [0.57,0.68]
# IF att6 = <-0.0071, 1.00) AND att5 = <-0.006, inf) AND att14 = <-0.008, 1.01) AND att8 = <0.0024, inf) AND att7 = (-inf, 0.99) AND att11 = (-inf, 1.01) AND att2 = <-0.0059, 1.00) AND att1 = (-inf, 1.01) AND att10 = <1.9E-5, inf) AND att4 = (-inf, 1.01) AND att3 = (-inf, 0.0085) AND att12 = (-inf, 0.0043) THEN label = {0.62} [0.58,0.67]
# IF att9 = <-0.003, inf) AND att14 = (-inf, 1.00) AND att5 = <0.0065, inf) AND att7 = (-inf, 1.00) AND att10 = <-0.0075, inf) AND att3 = <-0.0041, 0.005) AND att12 = (-inf, -6.2E-4) THEN label = {0.65} [0.58,0.71]
# 106
# Mean Jaccard Similarity for the Rule Set: 0.01
# Percentage of predictions within bounds: 0.721%

# %%
clf = DecisionTreeRegressor(random_state=0)
clf.fit(samp, yee)
pred = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
pr_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(pred, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (pr_count_within_bounds / len(pred)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        #rule += " then "
        if class_names is None:
            s = 0
            #rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        #rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules
rules = get_rules(clf, Xe.columns, None)
for r in rules:
    print(r)
len(rules)
# Out:
# Percentage of predictions within bounds: 1.0%
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.5) and (categorical_conv4depth_6 > 0.501) and (learning_rate > 0.501) and (categorical_conv3depth_4 > -0.001) and (categorical_optimizer_rmsprop > -0.001) and (learning_rate > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 > 1.008) and (categorical_conv4depth_36 <= 1.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam > -0.007) and (categorical_conv4depth_23 <= 1.006) and (categorical_conv4depth_36 > 0.0) and (categorical_optimizer_rmsprop > -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam > -0.007) and (categorical_conv4depth_23 <= 1.006) and (categorical_conv4depth_36 > 0.0) and (categorical_optimizer_rmsprop <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam > -0.007) and (categorical_conv4depth_23 <= 1.006) and (categorical_conv4depth_36 <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam <= -0.007) and (categorical_optimizer_rmsprop > 0.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam <= -0.007) and (categorical_optimizer_rmsprop <= 0.007) and (categorical_pooling_max > 0.997) and (categorical_version_v1 > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam <= -0.007) and (categorical_optimizer_rmsprop <= 0.007) and (categorical_pooling_max > 0.997) and (categorical_version_v1 <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam <= -0.007) and (categorical_optimizer_rmsprop <= 0.007) and (categorical_pooling_max <= 0.997)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next > 0.993) and (categorical_pooling_avg > -0.007) and (learning_rate > -0.002) and (categorical_conv3depth_8 > 0.503) and (categorical_conv4depth_23 > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next > 0.993) and (categorical_pooling_avg > -0.007) and (learning_rate > -0.002) and (categorical_conv3depth_8 > 0.503) and (categorical_conv4depth_23 <= 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next > 0.993) and (categorical_pooling_avg > -0.007) and (learning_rate > -0.002) and (categorical_conv3depth_8 <= 0.503)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next > 0.993) and (categorical_pooling_avg > -0.007) and (learning_rate <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next > 0.993) and (categorical_pooling_avg <= -0.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 > 1.008) and (categorical_conv4depth_36 > 1.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > -0.001) and (categorical_pooling_max > 0.995) and (categorical_optimizer_adam > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam > -0.003) and (categorical_optimizer_rmsprop > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > -0.001) and (categorical_pooling_max > 0.995) and (categorical_optimizer_adam <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > -0.001) and (categorical_pooling_max <= 0.995) and (categorical_conv3depth_8 > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > -0.001) and (categorical_pooling_max <= 0.995) and (categorical_conv3depth_8 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 <= -0.001) and (categorical_conv3depth_8 > -0.009) and (categorical_conv4depth_36 > 1.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 <= -0.001) and (categorical_conv3depth_8 > -0.009) and (categorical_conv4depth_36 <= 1.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 <= -0.001) and (categorical_conv3depth_8 <= -0.009)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 <= 0.5) and (categorical_conv4depth_6 > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 <= 0.5) and (categorical_version_next <= 0.993) and (categorical_conv4depth_36 <= 1.008) and (categorical_conv3depth_4 <= 0.5) and (categorical_conv4depth_6 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate > 0.501) and (categorical_conv4depth_23 > -0.004) and (categorical_optimizer_sgd > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate > 0.501) and (categorical_conv4depth_23 > -0.004) and (categorical_optimizer_sgd <= 0.004) and (categorical_conv3depth_4 > 0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate > 0.501) and (categorical_conv4depth_23 > -0.004) and (categorical_optimizer_sgd <= 0.004) and (categorical_conv3depth_4 <= 0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate > 0.501) and (categorical_conv4depth_23 <= -0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 > 1.002) and (categorical_optimizer_rmsprop > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 <= 1.0) and (categorical_optimizer_adam > -0.007) and (categorical_conv4depth_23 > 1.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 > 1.0) and (learning_rate <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 > 1.0) and (learning_rate > -0.002) and (categorical_version_v2 <= 1.006) and (learning_rate <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 > 1.0) and (learning_rate > -0.002) and (categorical_version_v2 <= 1.006) and (learning_rate > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop > 0.0) and (categorical_version_v1 > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop > 0.0) and (categorical_version_v1 <= 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop <= 0.0) and (categorical_conv4depth_6 > -0.001) and (categorical_conv4depth_23 > 1.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop <= 0.0) and (categorical_conv4depth_6 > -0.001) and (categorical_conv4depth_23 <= 1.0) and (categorical_conv3depth_4 > 0.997)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop <= 0.0) and (categorical_conv4depth_6 > -0.001) and (categorical_conv4depth_23 <= 1.0) and (categorical_conv3depth_4 <= 0.997)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 > -0.006) and (categorical_optimizer_rmsprop <= 0.0) and (categorical_conv4depth_6 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 > -0.008) and (categorical_conv4depth_6 <= -0.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 > 0.499) and (categorical_optimizer_adam <= 0.001) and (categorical_optimizer_adam <= -0.001) and (categorical_version_v2 <= -0.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 > 0.997) and (categorical_optimizer_adam > 0.004) and (categorical_conv4depth_6 > -0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 > 0.997) and (categorical_optimizer_adam > 0.004) and (categorical_conv4depth_6 <= -0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 > 0.997) and (categorical_optimizer_adam <= 0.004) and (learning_rate > 0.994)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 > 0.997) and (categorical_optimizer_adam <= 0.004) and (learning_rate <= 0.994) and (categorical_conv3depth_8 > 1.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 > 0.997) and (categorical_optimizer_adam <= 0.004) and (learning_rate <= 0.994) and (categorical_conv3depth_8 <= 1.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 <= 0.997) and (categorical_version_v1 > 0.001) and (categorical_version_v2 > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 <= 0.997) and (categorical_version_v1 > 0.001) and (categorical_version_v2 <= 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next > 0.008) and (categorical_conv3depth_8 <= 0.997) and (categorical_version_v1 <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop > -0.0) and (learning_rate > 0.999)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop > -0.0) and (learning_rate <= 0.999) and (categorical_optimizer_sgd > 0.992)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop > -0.0) and (learning_rate <= 0.999) and (categorical_optimizer_sgd <= 0.992)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate > 1.006) and (learning_rate > 1.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate > 1.006) and (learning_rate <= 1.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate <= 1.006) and (categorical_conv3depth_8 > 0.501) and (categorical_optimizer_adam > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate <= 1.006) and (categorical_conv3depth_8 > 0.501) and (categorical_optimizer_adam <= 0.003) and (categorical_conv3depth_4 > 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate <= 1.006) and (categorical_conv3depth_8 > 0.501) and (categorical_optimizer_adam <= 0.003) and (categorical_conv3depth_4 <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate <= 1.006) and (categorical_conv3depth_8 <= 0.501) and (categorical_pooling_avg > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv4depth_23 <= 0.499) and (categorical_version_next <= 0.008) and (categorical_optimizer_rmsprop <= -0.0) and (learning_rate <= 1.006) and (categorical_conv3depth_8 <= 0.501) and (categorical_pooling_avg <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_23 > 0.5) and (categorical_conv3depth_4 > 1.0) and (learning_rate > -0.002) and (categorical_version_v2 > 1.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 > 1.002) and (categorical_optimizer_rmsprop <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam > -0.003) and (categorical_optimizer_rmsprop <= 1.002) and (categorical_version_v2 > -0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.5) and (categorical_conv4depth_6 > 0.501) and (learning_rate > 0.501) and (categorical_conv3depth_4 > -0.001) and (categorical_optimizer_rmsprop > -0.001) and (learning_rate <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam <= -0.005) and (categorical_version_v2 > 0.008) and (categorical_conv4depth_6 <= 0.992)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 > -0.005) and (categorical_conv4depth_36 > -0.007) and (categorical_version_next > 1.008) and (categorical_conv3depth_8 > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 > -0.005) and (categorical_conv4depth_36 > -0.007) and (categorical_version_next > 1.008) and (categorical_conv3depth_8 <= 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 > -0.005) and (categorical_conv4depth_36 > -0.007) and (categorical_version_next <= 1.008) and (categorical_optimizer_rmsprop > 1.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 > -0.005) and (categorical_conv4depth_36 > -0.007) and (categorical_version_next <= 1.008) and (categorical_optimizer_rmsprop <= 1.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 > -0.005) and (categorical_conv4depth_36 <= -0.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 > -0.005) and (categorical_conv3depth_8 <= -0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 > 0.994) and (categorical_conv4depth_23 <= -0.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 <= 0.994) and (categorical_conv3depth_4 > 0.5)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg <= 0.008) and (categorical_conv3depth_4 <= 0.994) and (categorical_conv3depth_4 <= 0.5)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop <= 0.997) and (categorical_pooling_max > 0.994) and (categorical_conv4depth_23 > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop <= 0.997) and (categorical_pooling_max > 0.994) and (categorical_conv4depth_23 <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop <= 0.997) and (categorical_pooling_max <= 0.994)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam <= -0.005) and (categorical_version_v2 > 0.008) and (categorical_conv4depth_6 > 0.992)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam <= -0.005) and (categorical_version_v2 <= 0.008) and (categorical_version_v2 > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam > -0.003) and (categorical_optimizer_rmsprop <= 1.002) and (categorical_version_v2 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam <= -0.005) and (categorical_version_v2 <= 0.008) and (categorical_version_v2 <= 0.002) and (categorical_conv4depth_6 > 1.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam <= -0.005) and (categorical_version_v2 <= 0.008) and (categorical_version_v2 <= 0.002) and (categorical_conv4depth_6 <= 1.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 > 0.503)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 <= 0.503) and (categorical_optimizer_adam > -0.001) and (categorical_conv4depth_6 > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 <= 0.503) and (categorical_optimizer_adam > -0.001) and (categorical_conv4depth_6 <= 0.001) and (categorical_pooling_avg > -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 <= 0.503) and (categorical_optimizer_adam > -0.001) and (categorical_conv4depth_6 <= 0.001) and (categorical_pooling_avg <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 <= 0.503) and (categorical_optimizer_adam <= -0.001) and (categorical_pooling_max > 1.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd > -0.008) and (categorical_conv4depth_23 <= 0.503) and (categorical_optimizer_adam <= -0.001) and (categorical_pooling_max <= 1.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd <= -0.008) and (categorical_version_v1 > 1.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.006) and (categorical_optimizer_sgd <= -0.008) and (categorical_version_v1 <= 1.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate <= 0.006) and (categorical_conv4depth_23 > 0.502) and (categorical_pooling_avg > 0.001) and (categorical_version_next > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate <= 0.006) and (categorical_conv4depth_23 > 0.502) and (categorical_pooling_avg > 0.001) and (categorical_version_next <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 > 0.5) and (learning_rate <= 0.006) and (categorical_conv4depth_23 > 0.502) and (categorical_pooling_avg <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate <= 0.5) and (categorical_optimizer_adam > -0.005) and (categorical_optimizer_rmsprop > 0.997) and (categorical_pooling_avg > 0.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 <= 0.991)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 <= 0.005) and (categorical_version_v1 <= -0.009) and (categorical_version_next <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 <= 0.005) and (categorical_version_v1 <= -0.009) and (categorical_version_next > 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam <= -0.003) and (learning_rate > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam <= -0.003) and (learning_rate <= 0.004) and (categorical_version_v2 > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.501) and (learning_rate <= 0.501) and (categorical_conv3depth_8 <= 1.002) and (categorical_optimizer_adam <= -0.003) and (learning_rate <= 0.004) and (categorical_version_v2 <= 0.003)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam > 0.008) and (categorical_optimizer_sgd > -0.001) and (categorical_optimizer_sgd > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam > 0.008) and (categorical_optimizer_sgd > -0.001) and (categorical_optimizer_sgd <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam > 0.008) and (categorical_optimizer_sgd <= -0.001) and (categorical_version_v1 > 0.007)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam > 0.008) and (categorical_optimizer_sgd <= -0.001) and (categorical_version_v1 <= 0.007) and (categorical_version_next > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam > 0.008) and (categorical_optimizer_sgd <= -0.001) and (categorical_version_v1 <= 0.007) and (categorical_version_next <= 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg > 0.008) and (categorical_optimizer_sgd > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg > 0.008) and (categorical_optimizer_sgd <= 0.004) and (categorical_optimizer_sgd > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg > 0.008) and (categorical_optimizer_sgd <= 0.004) and (categorical_optimizer_sgd <= 0.004) and (categorical_version_v1 > -0.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg > 0.008) and (categorical_optimizer_sgd <= 0.004) and (categorical_optimizer_sgd <= 0.004) and (categorical_version_v1 <= -0.008)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 > 0.005) and (categorical_optimizer_sgd > 0.009)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 > 0.005) and (categorical_optimizer_sgd <= 0.009) and (categorical_version_v2 > 0.005) and (categorical_conv3depth_8 > 0.504)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 > 0.005) and (categorical_optimizer_sgd <= 0.009) and (categorical_version_v2 > 0.005) and (categorical_conv3depth_8 <= 0.504)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 > 0.005) and (categorical_optimizer_sgd <= 0.009) and (categorical_version_v2 <= 0.005) and (categorical_pooling_max > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 > 0.005) and (categorical_optimizer_sgd <= 0.009) and (categorical_version_v2 <= 0.005) and (categorical_pooling_max <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 <= 0.005) and (categorical_version_v1 > -0.009) and (learning_rate > 1.004) and (categorical_optimizer_adam > 0.005) and (categorical_version_v1 > -0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.501) and (learning_rate > 0.5) and (categorical_optimizer_adam <= 0.008) and (categorical_pooling_avg <= 0.008) and (categorical_conv4depth_6 > 0.991) and (categorical_version_v1 <= 0.005) and (categorical_version_v1 > -0.009) and (learning_rate > 1.004) and (categorical_optimizer_adam > 0.005) and (categorical_version_v1 <= -0.0)
# ...
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_8 <= 1.007) and (categorical_optimizer_adam > 0.0) and (categorical_version_v2 <= 0.004) and (categorical_conv4depth_23 <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 <= 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_8 <= 1.007) and (categorical_optimizer_adam <= 0.0) and (categorical_version_next > 1.004) and (categorical_conv3depth_8 > 0.503)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_4 <= 0.5) and (categorical_version_v1 > 1.0) and (categorical_optimizer_sgd > 1.005)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 <= 0.999) and (categorical_pooling_avg > 1.0)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 > 1.005) and (categorical_conv3depth_4 <= 0.004) and (categorical_pooling_avg > 0.009)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > 0.999) and (categorical_optimizer_sgd <= 0.997) and (categorical_conv4depth_36 <= 0.006)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 > 1.005) and (categorical_conv3depth_4 <= 0.004) and (categorical_pooling_avg <= 0.009) and (categorical_optimizer_rmsprop > -0.0) and (categorical_pooling_max > 1.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 > 1.005) and (categorical_conv3depth_4 <= 0.004) and (categorical_pooling_avg <= 0.009) and (categorical_optimizer_rmsprop > -0.0) and (categorical_pooling_max <= 1.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 > 1.005) and (categorical_conv3depth_4 <= 0.004) and (categorical_pooling_avg <= 0.009) and (categorical_optimizer_rmsprop <= -0.0)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg > 0.008)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max > 1.007) and (categorical_version_next > -0.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max > 1.007) and (categorical_version_next <= -0.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate > 0.004) and (categorical_conv4depth_36 > -0.0) and (categorical_version_v2 > -0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate > 0.004) and (categorical_conv4depth_36 > -0.0) and (categorical_version_v2 <= -0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate > 0.004) and (categorical_conv4depth_36 <= -0.0) and (categorical_pooling_avg > 0.002)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate > 0.004) and (categorical_conv4depth_36 <= -0.0) and (categorical_pooling_avg <= 0.002)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 > 0.991) and (learning_rate > -0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 > 0.991) and (learning_rate <= -0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd > -0.002) and (categorical_version_v1 > 0.003) and (categorical_conv4depth_6 > 0.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd > -0.002) and (categorical_version_v1 > 0.003) and (categorical_conv4depth_6 <= 0.007)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd > -0.002) and (categorical_version_v1 <= 0.003) and (categorical_optimizer_rmsprop > 0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd > -0.002) and (categorical_version_v1 <= 0.003) and (categorical_optimizer_rmsprop <= 0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd <= -0.002) and (categorical_conv3depth_8 > 0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 > -0.005) and (categorical_version_v2 <= 0.991) and (categorical_optimizer_sgd <= -0.002) and (categorical_conv3depth_8 <= 0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 <= -0.005) and (categorical_conv4depth_36 > 0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 > -0.005) and (learning_rate <= 0.004) and (categorical_conv4depth_6 <= -0.005) and (categorical_conv4depth_36 <= 0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 <= -0.005) and (categorical_version_next > 0.493)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 <= -0.005) and (categorical_version_next <= 0.493) and (categorical_pooling_avg > 0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg > -0.007) and (categorical_conv4depth_23 <= 1.005) and (categorical_pooling_avg <= 0.008) and (categorical_pooling_max <= 1.007) and (categorical_version_v1 <= -0.005) and (categorical_version_next <= 0.493) and (categorical_pooling_avg <= 0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg <= -0.007) and (categorical_version_next > 0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_pooling_avg <= 0.5) and (categorical_conv4depth_6 <= 0.99) and (categorical_version_v1 <= 0.5) and (learning_rate <= 0.5) and (categorical_conv4depth_36 <= 0.5) and (categorical_pooling_avg <= -0.007) and (categorical_version_next <= 0.004)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > 0.999) and (categorical_optimizer_sgd > 0.997)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd > 0.5) and (categorical_pooling_avg > 0.5) and (categorical_conv4depth_6 > 0.5) and (categorical_version_v1 > 0.5) and (learning_rate > 0.5) and (categorical_conv3depth_4 > 0.5) and (categorical_version_v1 > 0.999) and (categorical_optimizer_sgd <= 0.997) and (categorical_conv4depth_36 > 0.006)
# if (categorical_optimizer_adam <= 0.5) and (categorical_optimizer_sgd <= 0.5) and (categorical_pooling_max <= 0.5) and (categorical_conv4depth_6 <= 0.5) and (categorical_version_v1 <= 0.009) and (learning_rate <= 0.009) and (categorical_conv4depth_36 <= 0.501) and (categorical_version_v2 <= 0.002) and (categorical_optimizer_adam <= -0.005)
# 1000

# %%
# from itertools import combinations

# # Given rule list
# rule_list = rules

# # Function to extract features from a rule
# def extract_features(rule):
#     features = set(rule.split("and"))
#     return features

# # Function to calculate Jaccard similarity between two rules
# def jaccard_similarity(rule1, rule2):
#     features1 = extract_features(rule1)
#     features2 = extract_features(rule2)
#     intersection = len(features1.intersection(features2))
#     union = len(features1.union(features2))
    
#     if union == 0:
#         return 0.0  # Handle the case where both sets are empty
#     else:
#         return intersection / union

# # Calculate Jaccard similarity between all pairs of rules and collect them
# similarities = []
# for rule1, rule2 in combinations(rule_list, 2):
#     similarity = jaccard_similarity(rule1, rule2)
#     similarities.append(similarity)

# # Calculate the mean Jaccard similarity for the entire rule set
# mean_similarity = sum(similarities) / len(similarities)

# print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

# %%
from skrules import SkopeRules
from sklearn.preprocessing import KBinsDiscretizer
yee = yee/np.max(yee)

# transform the dataset with KBinsDiscretizer
enc = KBinsDiscretizer(n_bins=2, encode="ordinal", strategy='kmeans')
Y_binned = enc.fit_transform(yee.reshape(-1, 1))

clf1 = SkopeRules(
    max_depth_duplication=3, max_depth=3, max_features=0.5,
    max_samples_features=0.5, random_state=0, n_estimators=20,
    feature_names=Xe.columns, recall_min=0.04, precision_min=0.6)

clf1.fit(samp, Y_binned)

p = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
clf_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(p, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (clf_count_within_bounds / len(p)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

print(len(clf1.rules_))
print(clf1.rules_)
# Out:
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning:A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Percentage of predictions within bounds: 1.0%
# 15
# [('categorical_optimizer_adam <= 0.500004664529115 and categorical_optimizer_rmsprop > 0.500069641508162', (0.98046875, 0.6151960784313726, 2)), ('categorical_optimizer_adam <= 0.500004664529115 and categorical_optimizer_sgd <= 0.9908458590507507 and categorical_version_v1 <= 1.0053718090057373', (0.9769230769230769, 0.6120481927710844, 2)), ('categorical_pooling_max <= 0.009910676628351212 and categorical_optimizer_adam <= 0.49997341027483344 and categorical_version_v1 <= 0.9945542216300964', (0.9953488372093023, 0.5206812652068127, 2)), ('categorical_pooling_max <= 0.9901527464389801 and categorical_optimizer_adam <= 0.49998806742951274 and categorical_conv4depth_23 <= 0.9918481707572937', (0.981042654028436, 0.5149253731343284, 2)), ('categorical_conv3depth_4 > -0.007674903608858585 and categorical_optimizer_rmsprop > 0.500069641508162 and categorical_conv4depth_23 <= 0.9987111985683441', (0.9895287958115183, 0.4725, 2)), ('categorical_version_v2 <= 0.9972409307956696 and categorical_pooling_max <= 0.49998910492286086 and categorical_version_next > -0.009576223324984312', (0.6324786324786325, 0.5260663507109005, 2)), ('categorical_pooling_avg > 0.00822452176362276 and categorical_optimizer_rmsprop > 0.500069641508162', (1.0, 0.37245870765487554, 4)), ('categorical_pooling_avg > 0.49998635053634644 and categorical_optimizer_rmsprop <= 0.500069641508162 and categorical_optimizer_sgd > 0.9900537133216858', (0.9215686274509803, 0.3389423076923077, 2)), ('categorical_pooling_avg > 0.00975616741925478 and categorical_optimizer_adam <= 0.49998806742951274 and categorical_optimizer_rmsprop <= 0.008028277894482017', (0.8923076923076924, 0.2885572139303483, 2)), ('categorical_conv3depth_4 > 0.0017698894953355193 and categorical_conv4depth_6 > 0.009343205019831657 and categorical_version_v1 <= 0.9932860434055328', (0.7933333333333333, 0.288135593220339, 2)), ('categorical_pooling_max > 0.49998910492286086 and categorical_optimizer_adam <= 0.5000077639706433 and categorical_version_v1 <= 0.990466982126236', (0.6459627329192547, 0.24644549763033174, 2)), ('categorical_conv3depth_4 <= 0.0007248554902616888 and categorical_optimizer_rmsprop > 0.500069641508162 and categorical_version_next > -0.009607060812413692', (0.9705882352941176, 0.16296296296296298, 2)), ('categorical_pooling_max > 0.9901527464389801 and categorical_optimizer_adam <= 0.49998806742951274 and categorical_conv4depth_6 > 0.009716061409562826', (0.7380952380952381, 0.15422885572139303, 2)), ('categorical_pooling_max <= 0.009910676628351212 and categorical_optimizer_adam <= 0.49997341027483344 and categorical_version_v1 > 0.9945542216300964', (0.8472222222222222, 0.14841849148418493, 2)), ('categorical_optimizer_rmsprop <= 0.9961378872394562 and categorical_optimizer_rmsprop > 0.5000595613382757 and categorical_conv4depth_6 <= 0.009343205019831657', (0.8918918918918919, 0.08168316831683169, 2))]
