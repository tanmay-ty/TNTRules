# %%
import pandas as pd

import numpy as np
import six
import sys
sys.modules['sklearn.externals.six'] = six
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import _tree
import random

from skopt.space import Real, Categorical, Integer
random.seed(42)

# %%
def _sample_search_space(param_space, categorical_columns, num_samples = 1000):
    """
        Uniformly sample the search space for generating explanation dataset. Maintains the original order of search space.
        Sensitive to order: place categoricals first and everything else later.

        Args:
        - param_space (param space): parameter space
        - categorical_columns (list): list of categorical variables
        - num_samples (int): number of generated samples

        Returns:
        - new_data (numpy array): the augmented dataset
        """
    samples = []
    
    for _ in range(num_samples):
        sample = [param.rvs() for param in param_space]
        samples.append(sample)
    
    # Create a DataFrame with the samples
    param_names = [param.name for param in param_space]
    df = pd.DataFrame(samples, columns=param_names)
    
    # One-hot encode categorical variables and add dynamic prefixes
    encoded_columns = []
    for col in categorical_columns:
        prefix = f'categorical_{col}'
        encoded = pd.get_dummies(df[col], prefix=prefix).astype(float)
        encoded_columns.extend(encoded.columns)
        df = pd.concat([df.drop(col, axis=1), encoded], axis=1)
    
    # Rearrange columns: categorical columns in front, followed by non-categorical columns
    ordered_columns = []
    for col in param_space:
        if col.name in categorical_columns:
            ordered_columns.extend([col_name for col_name in df.columns if col_name.startswith(f'categorical_{col.name}')])
        elif col.name in df.columns:
            ordered_columns.append(col.name)
    
    # Now you have the DataFrame with categorical variables in the front and non-categorical variables in their original order
    df = df[ordered_columns]
    
    # Convert numerical variables from lists to floats
    for col in param_names:
        if col not in categorical_columns:
            df[col] = df[col]
    df = df.to_numpy().astype(np.float32)
    return df

# %%
df = pd.read_csv('mnist_resnet_25.csv')
df = df.drop(columns=['training_epoch_accuracy','training_epoch_loss','validation_epoch_loss','validation_evaluation_accuracy_vs_iterations','validation_evaluation_loss_vs_iterations'])

# %%
ye = df['validation_epoch_accuracy']
y = ye.to_numpy()

Xe = df.drop(columns='validation_epoch_accuracy')
dum1 = pd.get_dummies(Xe['conv3_depth'],prefix = 'categorical_conv3depth')
dum2 = pd.get_dummies(Xe['optimizer'],prefix = 'categorical_optimizer')
dum3 = pd.get_dummies(Xe['conv4_depth'],prefix = 'categorical_conv4depth')
dum4 = pd.get_dummies(Xe['version'],prefix = 'categorical_version')
dum5 = pd.get_dummies(Xe['pooling'],prefix = 'categorical_pooling')
Xe = Xe.drop(columns = ['conv3_depth','optimizer','conv4_depth','version','pooling'])
Xe = pd.concat([dum1, dum2, dum3, dum4, dum5, Xe], axis=1)


param_space = [
    Categorical(categories=['4', '8'], name='conv3_depth'),
    Categorical(categories=['adam', 'sgd', 'rmsprop'], name='optimizer'),
    Categorical(categories=['6', '23', '36'], name='conv4_depth'),
    Categorical(categories=['v1','v2', 'next'], name='version'),
    Categorical(categories=['avg', 'max'], name='pooling'),
    Integer(low=0, high=1, name='learning_rate')
]

# Define the categorical columns
categorical_columns = ['conv3_depth','optimizer','conv4_depth','version','pooling']

print (Xe.iloc[np.argmin(ye.values)])
print (np.max(ye.values))
# Out:
# categorical_conv3depth_4         0.0
# categorical_conv3depth_8         1.0
# categorical_optimizer_adam       1.0
# categorical_optimizer_rmsprop    0.0
# categorical_optimizer_sgd        0.0
# categorical_conv4depth_6         0.0
# categorical_conv4depth_23        0.0
# categorical_conv4depth_36        1.0
# categorical_version_next         0.0
# categorical_version_v1           1.0
# categorical_version_v2           0.0
# categorical_pooling_avg          1.0
# categorical_pooling_max          0.0
# learning_rate                    0.1
# Name: 3, dtype: float64
# 0.989333332

# %%
import GPy

def _train_gp(x_train, y_train):
    """
        Train a GPR model from Gpy library.

        Args:
        - X_train (numpy array): input data
        - Y_train (numpy array): ground truth data
        - n_samples (int): number of times to sample the posterior of the trained gp
        - sample_points (numpy array): new input X locations where the posterior would be sampled

        Returns:
        - model (trained gp model): trained gp model
        - mean_y (numpy array): mean of the Y from the sampled posterior
        - std_y (numpy array): std dev of the Y from the sampled posterior
        - sum_log_likelihoods (numpy array): returns the likelihood of observing
          each input point given the trained model
    """
    kernel = GPy.kern.RBF(input_dim=x_train.shape[1])
    model = GPy.models.GPRegression(x_train, y_train, kernel)
    model.optimize()
    return model

def augment_with_noise(data, n_samples=1000):
    """
    Add noise to the input data to create new points and generate a new dataset
    with the desired number of samples.

    Args:
    - data (numpy array): the input data
    - num_samples (int): the number of samples to generate
    - noise_factor (float): the magnitude of the noise to add to the data (default: 0.01)

    Returns:
    - new_data (numpy array): the augmented dataset
    """
    n_points, n_dims = data.shape
    new_data = np.empty((n_samples, n_dims))  # Create a new array for the augmented data

    for i in range(n_samples):
        noise = np.random.uniform(low=-0.01, high=0.01, size=n_dims)
        new_data[i] = data[np.random.randint(n_points)] + noise

    return new_data
    
model = _train_gp(Xe.to_numpy(), y.reshape(-1, 1))
test_set = _sample_search_space(param_space, categorical_columns, num_samples = 100)
test_set = augment_with_noise(test_set)
mean_y, var_y = model.predict_noiseless(test_set, full_cov=False)
flattened_mean = [item for sublist in mean_y for item in sublist]
flattened_var = [item for sublist in var_y for item in sublist]
std = np.sqrt(flattened_var)

samp = _sample_search_space(param_space, categorical_columns, num_samples = 1000)
samp = augment_with_noise(samp)
yee, var = model.predict_noiseless(samp, full_cov=False)
yee = np.squeeze(yee, axis=1)

# %%
from rulekit import RuleKit
from rulekit.regression import RuleRegressor
from rulekit.params import Measures
RuleKit.init()

reg = RuleRegressor(
    induction_measure=Measures.C2,
    pruning_measure=Measures.C2,
    voting_measure=Measures.C2,
)
reg.fit(samp, yee)
predictions = reg.predict(test_set)

ru = []
for rule in reg.model.rules:
    ru.append(str(rule))
    print (rule)

print(len(ru))

from itertools import combinations

# Given rule list in the new representation
rule_list = ru

# Function to extract features from a rule
def extract_features(rule):
    # Extract only the part before "THEN" and split by "AND"
    features = set(rule.split('IF')[1].split(" THEN")[0].split(" AND"))
    return features

# Function to calculate Jaccard similarity between two rules
def jaccard_similarity(rule1, rule2):
    features1 = extract_features(rule1)
  
    features2 = extract_features(rule2)
   
    intersection = len(features1.intersection(features2))
    union = len(features1.union(features2))
    
    if union == 0:
        return 0.0  # Handle the case where both sets are empty
    else:
        return intersection / union

# Calculate Jaccard similarity between all pairs of rules and collect them
similarities = []
for rule1, rule2 in combinations(rule_list, 2):
    similarity = jaccard_similarity(rule1, rule2)
    similarities.append(similarity)

# Calculate the mean Jaccard similarity for the entire rule set
mean_similarity = sum(similarities) / len(similarities)

print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

## Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
# Initialize a count for predictions within bounds
count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(predictions, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (count_within_bounds / len(predictions)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")
# Out:
# IF att10 = <1.01, inf) THEN label = {0.84} [0.69,0.99]
# IF att9 = <0.0063, inf) AND att5 = <-0.0086, inf) AND att14 = <-0.0068, inf) AND att7 = <-0.0079, 0.0052) AND att2 = <-0.0081, 1.00) AND att11 = <-0.0082, inf) AND att1 = <0.0029, 1.00) AND att4 = (-inf, 0.008) AND att3 = <0.99, inf) AND att12 = <-0.0019, inf) THEN label = {0.12} [0.11,0.13]
# IF att6 = <-0.0054, inf) AND att8 = <0.99, 1.00) AND att7 = <-0.0063, 0.0082) AND att11 = <-0.0073, 1.00) AND att2 = <-0.0076, 1.00) AND att1 = (-inf, 1.00) AND att4 = (-inf, 0.0073) AND att3 = <0.99, inf) THEN label = {0.33} [0.29,0.37]
# IF att9 = <0.99, inf) AND att6 = (-inf, 1.00) AND att14 = <-0.0041, inf) AND att7 = <-0.0063, 0.0088) AND att11 = <-0.0095, inf) AND att2 = <-0.0067, 1.01) AND att1 = <-0.0028, 1.00) AND att4 = <-0.0082, inf) AND att3 = <0.99, inf) THEN label = {0.15} [0.13,0.18]
# IF att6 = (-inf, 1.01) AND att14 = <-0.0043, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.0055, 0.0084) AND att11 = <-0.0095, inf) AND att2 = <-0.0074, 1.01) AND att1 = <-0.0019, 1.01) AND att10 = <0.50, inf) AND att4 = <-0.0097, 0.008) AND att13 = <-0.0075, inf) AND att12 = <-0.0062, inf) AND att3 = <0.99, inf) THEN label = {0.24} [0.20,0.28]
# IF att6 = <-0.0053, 1.01) AND att14 = <-0.0068, inf) AND att8 = (-inf, 1.01) AND att7 = <-0.0084, 0.0093) AND att11 = (-inf, 1.00) AND att2 = <-0.0082, 1.01) AND att1 = <-0.0073, 1.01) AND att10 = (-inf, 1.00) AND att13 = <-0.009, inf) AND att4 = <-0.0062, 0.0079) AND att3 = <0.99, 1.01) AND att12 = <-0.0015, 1.01) THEN label = {0.21} [0.07,0.34]
# IF att5 = <-0.0075, inf) AND att8 = <-0.0028, inf) AND att7 = (-inf, 0.0093) AND att11 = (-inf, 1.00) AND att2 = <-0.0081, 1.00) AND att10 = (-inf, 1.01) AND att1 = <-0.0057, 1.00) AND att13 = <-0.0031, 1.01) AND att4 = <-0.0035, 0.0073) AND att12 = <-0.0068, inf) AND att3 = <1.00, 1.01) THEN label = {0.33} [0.24,0.41]
# IF att9 = (-inf, 1.01) AND att6 = <-0.0054, inf) AND att5 = <-0.0061, inf) AND att7 = <-0.0092, 0.0094) AND att11 = (-inf, 1.00) AND att2 = <-0.0075, 1.00) AND att10 = <-0.008, 1.00) AND att13 = <-0.0075, 1.01) AND att4 = <-0.0084, 0.0068) AND att12 = <-0.0053, 1.01) AND att3 = <1.00, inf) THEN label = {0.30} [0.16,0.43]
# IF att9 = <-0.0047, 1.01) AND att5 = <-0.009, inf) AND att8 = <0.0024, inf) AND att7 = <-0.0075, 0.0095) AND att11 = <-0.0094, 1.00) AND att2 = <-0.0088, 1.00) AND att10 = (-inf, 1.01) AND att1 = (-inf, 1.00) AND att4 = (-inf, 0.008) AND att13 = <-0.0062, 1.01) AND att3 = <0.99, inf) THEN label = {0.24} [0.074,0.41]
# IF att14 = <-0.0059, inf) AND att11 = (-inf, 0.99) AND att10 = (-inf, 1.00) AND att13 = <-0.0063, 1.01) AND att12 = <-0.0074, inf) AND att9 = <-0.0053, inf) AND att6 = <-0.0049, 1.00) AND att5 = <-0.0067, 0.008) AND att7 = (-inf, 0.0087) AND att2 = (-inf, 0.009) AND att1 = (-inf, 1.01) AND att4 = (-inf, 0.008) AND att3 = <0.99, inf) THEN label = {0.11} [0.073,0.15]
# IF att9 = (-inf, 1.00) AND att6 = (-inf, 1.00) AND att5 = <-0.0095, 0.008) AND att14 = <-0.003, 1.01) AND att8 = <-0.0076, 1.00) AND att7 = <-0.0084, 0.009) AND att2 = <0.0052, inf) AND att1 = <-0.0098, 1.00) AND att4 = <-1.3E-4, 0.008) AND att12 = <-0.0066, inf) THEN label = {0.24} [0.20,0.28]
# IF att6 = <-0.0054, 1.00) AND att5 = <-0.0095, inf) AND att14 = <-0.003, inf) AND att8 = <-0.0087, inf) AND att7 = <-0.0084, 0.008) AND att11 = <-0.0094, 1.00) AND att10 = (-inf, 1.01) AND att1 = <-0.0096, 1.00) AND att4 = (-inf, 0.008) AND att3 = <0.99, inf) AND att12 = <0.0045, inf) THEN label = {0.20} [0.062,0.35]
# IF att9 = <-0.0074, 0.50) AND att6 = <0.0029, inf) AND att5 = (-inf, 0.0092) AND att14 = <-0.0063, inf) AND att8 = (-inf, 1.00) AND att7 = (-inf, 0.0082) AND att11 = <-0.0072, inf) AND att2 = <-0.008, 1.00) AND att10 = <-0.0059, inf) AND att4 = (-inf, 0.0058) AND att12 = <-0.0046, 1.01) THEN label = {0.33} [0.19,0.46]
# IF att9 = <-0.0074, inf) AND att5 = <-0.0078, inf) AND att7 = <-0.0082, 0.0088) AND att2 = <-0.0085, 1.00) AND att11 = <-6.8E-5, 1.00) AND att1 = <-0.0021, 1.01) AND att10 = (-inf, 1.01) AND att13 = <-0.0081, inf) AND att4 = (-inf, 0.0068) AND att12 = <-0.0086, 1.01) AND att3 = <0.99, 1.01) THEN label = {0.24} [0.073,0.41]
# IF att9 = <-0.0047, inf) AND att14 = <-0.0091, 0.99) AND att8 = <-0.0073, inf) AND att7 = <-0.0092, 0.0094) AND att11 = <-0.0088, inf) AND att2 = <0.0073, inf) AND att1 = <-0.0023, inf) AND att10 = (-inf, 1.00) AND att4 = <-0.0083, 0.0077) AND att12 = <-0.0053, inf) AND att3 = <1.00, 1.01) THEN label = {0.61} [0.38,0.84]
# IF att9 = <-0.0064, inf) AND att5 = <-0.0068, 0.0092) AND att8 = (-inf, 1.00) AND att7 = <-0.0089, 0.0035) AND att11 = <-0.0066, 1.00) AND att2 = (-inf, 1.00) AND att4 = (-inf, 0.0083) AND att12 = (-inf, 1.01) THEN label = {0.24} [0.074,0.40]
# IF att9 = (-inf, 0.99) AND att6 = <-0.0057, 1.01) AND att5 = <-0.0067, 0.0092) AND att8 = <-0.0028, 1.00) AND att7 = <-0.0072, 0.0065) AND att2 = <-0.0026, 1.01) AND att10 = <-0.0072, 1.01) AND att1 = (-inf, 1.01) AND att13 = <-0.0062, 1.01) AND att4 = (-inf, 0.0056) AND att3 = <0.99, inf) THEN label = {0.60} [0.39,0.81]
# IF att6 = (-inf, 1.01) AND att5 = <-0.0095, 0.0081) AND att14 = <-0.0053, inf) AND att8 = <-0.0026, inf) AND att7 = <-0.0085, 0.0095) AND att2 = <-0.0058, 1.01) AND att11 = <-0.0051, 1.00) AND att1 = <-0.0044, 1.01) AND att4 = <-0.0097, 0.0037) AND att13 = <-0.0075, 1.01) AND att3 = <0.99, 1.00) THEN label = {0.20} [0.073,0.32]
# IF att9 = <-0.0066, 1.00) AND att5 = <-0.0025, inf) AND att14 = (-inf, 1.00) AND att8 = (-inf, 1.01) AND att7 = <-0.005, 0.0071) AND att2 = <-0.0089, 1.00) AND att1 = <-0.0096, 1.00) AND att10 = <-0.0076, 1.00) AND att4 = (-inf, 0.0084) AND att13 = <-0.0066, inf) AND att3 = <0.99, 1.01) AND att12 = (-inf, 1.01) THEN label = {0.41} [0.21,0.61]
# IF att14 = <-0.0087, inf) AND att11 = (-inf, 1.00) AND att10 = (-inf, 1.00) AND att13 = <-0.004, inf) AND att12 = <-0.0086, inf) AND att9 = (-inf, 1.01) AND att6 = (-inf, 1.00) AND att8 = (-inf, 1.01) AND att7 = <-0.0092, 0.0088) AND att2 = <0.0071, 1.01) AND att1 = (-inf, 1.00) AND att4 = <-0.008, 0.0038) AND att3 = <1.00, 1.01) THEN label = {0.34} [0.24,0.45]
# IF att9 = <-0.0076, inf) AND att5 = (-inf, 0.0089) AND att8 = <-0.0045, inf) AND att7 = <-0.0057, 0.0088) AND att11 = (-inf, 1.00) AND att2 = <-0.0031, inf) AND att1 = <-0.0059, 0.99) AND att4 = (-inf, 0.0084) AND att13 = <0.003, inf) AND att12 = <-0.0048, inf) AND att3 = <1.00, 1.01) THEN label = {0.39} [0.33,0.46]
# IF att9 = (-inf, 1.00) AND att5 = (-inf, 0.0095) AND att14 = <0.0019, inf) AND att8 = <-0.0078, inf) AND att7 = <-0.0054, 0.005) AND att11 = <-0.0033, 1.00) AND att2 = <-0.0065, 1.01) AND att1 = <-0.0084, 1.00) AND att13 = <-1.2E-4, 1.01) AND att4 = <-0.0063, inf) AND att12 = <-0.0086, inf) AND att3 = <0.99, 1.01) THEN label = {0.42} [0.25,0.58]
# IF att14 = <-0.0088, inf) AND att11 = <-0.0077, 1.00) AND att10 = <-0.0049, inf) AND att13 = <-0.0031, inf) AND att12 = (-inf, 1.00) AND att6 = <-0.0056, inf) AND att5 = (-inf, 0.0052) AND att8 = <-0.007, inf) AND att7 = <-0.0085, 0.0093) AND att2 = (-inf, 1.01) AND att1 = <-0.0011, 1.01) AND att4 = <-0.0093, inf) AND att3 = <0.99, 1.01) THEN label = {0.20} [0.069,0.33]
# IF att9 = <-0.0073, 1.01) AND att6 = (-inf, 1.00) AND att7 = (-inf, 0.0044) AND att11 = (-inf, 1.00) AND att2 = <-0.0081, 1.00) AND att1 = <0.0036, 1.01) AND att10 = (-inf, 1.00) AND att4 = <-0.0079, 0.0036) AND att13 = (-inf, 1.01) AND att3 = <1.00, inf) THEN label = {0.24} [0.088,0.39]
# IF att9 = <-0.0071, inf) AND att14 = (-inf, 1.01) AND att5 = <-0.004, 0.0046) AND att8 = <0.0016, 1.00) AND att7 = (-inf, 0.0094) AND att11 = (-inf, 1.00) AND att2 = <-0.0021, 1.01) AND att4 = <-0.008, 0.007) AND att13 = (-inf, 1.01) AND att3 = (-inf, 1.01) THEN label = {0.39} [0.20,0.58]
# IF att9 = <-0.0065, 1.00) AND att6 = (-inf, 0.99) AND att7 = (-inf, 0.0095) AND att2 = <-0.0079, inf) AND att11 = <-0.0056, inf) AND att1 = (-inf, 1.01) AND att10 = <-0.0011, 1.00) AND att4 = <2.1E-4, 0.0092) AND att13 = <-8.2E-4, 1.00) AND att3 = <1.00, inf) THEN label = {0.44} [0.24,0.63]
# IF att6 = <-0.0043, 1.00) AND att5 = <-0.0095, inf) AND att8 = <-0.0025, inf) AND att7 = <-0.0024, 0.0095) AND att11 = <-0.0095, 1.00) AND att2 = <-0.0031, 1.01) AND att10 = (-inf, 1.01) AND att1 = (-inf, 1.01) AND att4 = <-0.0038, inf) AND att12 = <-0.0086, inf) AND att3 = <0.99, 1.01) THEN label = {0.16} [0.023,0.29]
# IF att9 = <-0.0064, 0.99) AND att6 = (-inf, 1.00) AND att14 = <-0.0072, inf) AND att7 = <-0.0056, 0.0093) AND att11 = (-inf, 1.00) AND att2 = <0.0026, 1.00) AND att1 = <-0.0019, 1.01) AND att13 = (-inf, 1.01) AND att3 = <0.99, inf) AND att12 = <0.0047, inf) THEN label = {0.12} [-0.061,0.29]
# IF att6 = <-0.0023, 1.01) AND att5 = <-0.0078, 0.0091) AND att14 = <0.005, inf) AND att8 = <-0.0032, 1.00) AND att7 = (-inf, 0.0093) AND att2 = <-0.0016, inf) AND att11 = <-0.0046, inf) AND att10 = (-inf, 1.01) AND att3 = <0.99, 1.00) THEN label = {0.15} [-0.071,0.38]
# IF att9 = <-0.0074, 1.00) AND att6 = <-0.0054, inf) AND att14 = (-inf, 1.00) AND att5 = (-inf, 0.0025) AND att8 = <0.0021, 1.00) AND att7 = <-0.0081, 0.0094) AND att2 = <-0.0052, 1.01) AND att1 = <-0.0055, 1.00) AND att13 = <-0.0073, inf) AND att4 = (-inf, 0.0065) AND att12 = <-0.0034, inf) AND att3 = <0.99, inf) THEN label = {0.33} [0.081,0.58]
# IF att9 = (-inf, 0.50) AND att5 = <-0.0053, 0.0093) AND att8 = <-0.0089, inf) AND att7 = <-0.0049, 0.0085) AND att2 = <-0.0071, 1.00) AND att11 = <0.0014, inf) AND att1 = <-0.006, 1.01) AND att13 = <-0.0052, inf) AND att4 = (-inf, 0.0075) AND att12 = <-0.0069, inf) THEN label = {0.36} [0.18,0.55]
# IF att9 = (-inf, 0.0028) AND att6 = <-0.0018, inf) AND att5 = (-inf, 0.0091) AND att14 = (-inf, 1.01) AND att8 = (-inf, 1.00) AND att7 = (-inf, 0.0057) AND att2 = <-0.0059, 1.00) AND att11 = <0.50, inf) AND att10 = <-0.006, inf) AND att4 = (-inf, 0.0073) AND att12 = <-0.0071, inf) AND att3 = (-inf, 1.01) THEN label = {0.61} [0.47,0.75]
# IF att14 = <-0.0085, inf) AND att11 = <-0.0095, 1.00) AND att13 = <-0.0068, inf) AND att12 = <0.0038, 1.01) AND att9 = <-0.0074, inf) AND att6 = <-0.0032, 1.01) AND att5 = <-0.0092, inf) AND att8 = <-0.0055, 1.01) AND att7 = <-0.0075, 0.50) AND att2 = <-0.0075, 1.00) AND att1 = <-0.0056, 1.00) AND att4 = <-0.0083, 0.0077) AND att3 = <0.99, 1.01) THEN label = {0.20} [0.06,0.35]
# IF att6 = <-0.0071, 1.01) AND att5 = <-0.0076, 0.0071) AND att14 = (-inf, 1.01) AND att8 = (-inf, 1.00) AND att7 = <-0.0016, inf) AND att2 = <-0.0089, inf) AND att11 = <3.8E-4, inf) AND att1 = <0.0039, 1.00) AND att10 = <-0.007, 1.00) AND att13 = (-inf, 1.01) AND att3 = <0.99, 1.01) THEN label = {0.42} [0.24,0.61]
# IF att9 = <0.0082, inf) AND att5 = (-inf, 0.0092) AND att8 = <-0.0073, inf) AND att11 = <-0.0098, inf) AND att2 = <-0.0045, inf) AND att10 = (-inf, 1.00) AND att1 = <0.50, inf) AND att12 = <-0.0069, 1.01) AND att3 = <0.99, inf) THEN label = {0.25} [0.069,0.43]
# IF att9 = <0.0087, inf) AND att8 = (-inf, 0.0062) AND att11 = (-inf, 0.0045) AND att2 = <-0.0074, 1.00) AND att10 = (-inf, 1.00) AND att4 = <-0.0024, 0.0074) AND att3 = <0.99, inf) THEN label = {0.42} [0.26,0.59]
# IF att9 = <0.0082, inf) AND att14 = <-0.0026, inf) AND att5 = (-inf, 0.009) AND att8 = <-0.0074, 0.0081) AND att7 = <0.99, inf) AND att11 = <-0.0089, inf) AND att4 = <-0.005, 0.0091) THEN label = {0.53} [0.38,0.67]
# IF att9 = <0.0068, inf) AND att6 = (-inf, 1.01) AND att11 = <-0.0082, inf) AND att2 = (-inf, 1.01) AND att1 = <-0.0051, inf) AND att10 = <-0.0059, inf) AND att13 = <-0.0042, inf) AND att12 = (-inf, 1.01) AND att3 = <0.99, 1.01) THEN label = {0.27} [0.064,0.47]
# IF att5 = <-0.0075, inf) AND att14 = <-0.0072, inf) AND att8 = <-0.0047, 0.0053) AND att7 = <-0.0071, inf) AND att11 = <-0.0092, 0.009) AND att2 = <1.1E-4, inf) AND att1 = (-inf, 1.00) AND att13 = <-0.003, 1.00) AND att4 = <-0.0087, inf) AND att3 = <0.99, 1.01) AND att12 = (-inf, 1.00) THEN label = {0.64} [0.42,0.86]
# IF att9 = (-inf, 0.009) AND att5 = (-inf, 0.0047) AND att8 = (-inf, 1.00) AND att7 = <-0.0081, 1.00) AND att11 = <-0.0088, 0.009) AND att2 = <-0.0074, 1.00) AND att1 = <-0.0081, 1.01) AND att10 = (-inf, 1.01) AND att4 = (-inf, 0.0073) THEN label = {0.39} [0.20,0.58]
# IF att6 = <-0.004, 0.50) AND att5 = (-inf, 0.0055) AND att8 = (-inf, 1.00) AND att2 = <-0.0033, 1.00) AND att11 = <-0.0089, 0.007) AND att1 = <-0.0049, 1.01) AND att13 = <-0.0066, inf) AND att4 = <-0.0059, inf) AND att12 = (-inf, 1.01) AND att3 = <0.99, inf) THEN label = {0.41} [0.27,0.56]
# IF att9 = <-0.0077, inf) AND att6 = <-0.005, inf) AND att5 = (-inf, 0.0058) AND att7 = <0.50, inf) AND att11 = (-inf, 0.0079) AND att1 = <-0.005, inf) AND att10 = <-0.0046, inf) AND att13 = (-inf, 1.01) AND att3 = <1.00, inf) AND att12 = <-0.005, inf) THEN label = {0.50} [0.40,0.60]
# IF att6 = (-inf, 1.00) AND att5 = (-inf, 0.0069) AND att8 = <-0.0079, 1.00) AND att7 = <0.0067, inf) AND att11 = (-inf, 0.99) AND att2 = <-0.0054, 1.00) AND att1 = (-inf, 1.01) AND att4 = <-0.0084, 0.0072) AND att3 = <0.99, 1.01) AND att12 = <-8.1E-4, inf) THEN label = {0.55} [0.39,0.71]
# IF att11 = (-inf, 0.99) AND att1 = <-0.0097, inf) AND att10 = (-inf, 0.99) AND att3 = <0.99, inf) THEN label = {0.25} [0.034,0.47]
# IF att9 = <-0.0056, 0.50) AND att6 = (-inf, 0.99) AND att14 = <-0.0031, inf) AND att8 = (-inf, 0.99) AND att2 = <-0.0084, 1.00) AND att11 = <-0.0039, inf) AND att1 = <-0.0028, 1.00) AND att10 = (-inf, 1.00) AND att13 = <-0.0044, 1.01) AND att4 = <-0.0081, 0.0068) AND att3 = <0.99, inf) THEN label = {0.66} [0.55,0.76]
# IF att11 = <-0.005, inf) AND att10 = (-inf, 1.01) AND att13 = <-0.0095, inf) AND att12 = <-0.0068, 1.01) AND att9 = (-inf, 1.00) AND att6 = (-inf, 0.99) AND att5 = (-inf, 0.0093) AND att8 = <-0.0087, 0.50) AND att7 = (-inf, 1.00) AND att2 = <-0.0042, 0.99) AND att1 = <0.0061, 1.01) AND att4 = <-0.0027, inf) AND att3 = <0.99, inf) THEN label = {0.72} [0.46,0.97]
# IF att6 = (-inf, 1.00) AND att14 = <8.3E-4, inf) AND att11 = (-inf, 1.00) AND att1 = <-5.5E-5, inf) AND att13 = <-0.0075, inf) AND att3 = <0.99, inf) THEN label = {0.24} [0.03,0.45]
# IF att9 = <-0.0095, inf) AND att6 = (-inf, 0.99) AND att14 = <-0.002, inf) AND att8 = <-0.0044, inf) AND att7 = <0.0089, inf) AND att2 = <-0.0063, 1.00) AND att11 = <-4.3E-4, inf) AND att1 = (-inf, 1.00) AND att3 = <0.99, 1.01) AND att12 = <0.0032, 1.00) THEN label = {0.73} [0.51,0.96]
# IF att9 = <-0.0056, inf) AND att8 = <0.0031, inf) AND att7 = (-inf, 1.00) AND att11 = <-0.0049, 1.01) AND att2 = (-inf, 1.00) AND att1 = <-0.0018, 1.01) AND att10 = <-0.0081, inf) AND att13 = <-0.0069, inf) AND att3 = <0.0099, inf) AND att12 = (-inf, 1.01) THEN label = {0.24} [0.064,0.42]
# IF att9 = <-0.005, inf) AND att6 = (-inf, 1.01) AND att5 = <-0.0046, inf) AND att8 = <-0.0079, 1.01) AND att11 = <-0.0049, 1.01) AND att2 = (-inf, 1.01) AND att1 = <-0.005, inf) AND att10 = (-inf, 1.00) AND att4 = <-0.0068, inf) AND att13 = <0.0018, inf) AND att3 = (-inf, 1.00) THEN label = {0.83} [0.64,1.02]
# IF att9 = (-inf, -0.0098) THEN label = {0.87} [0.69,1.04]
# IF att13 = (-inf, -0.0099) THEN label = {0.78} [0.68,0.88]
# IF att5 = <-0.0027, inf) AND att7 = (-inf, 0.0094) AND att2 = <-0.0051, inf) AND att1 = <-0.0048, 1.00) AND att3 = <0.0096, 0.99) THEN label = {0.70} [0.53,0.87]
# IF att14 = (-inf, 1.00) AND att7 = <1.01, inf) AND att2 = <-0.0069, inf) AND att3 = (-inf, 0.0015) THEN label = {1.05} [1.02,1.09]
# IF att6 = (-inf, 1.00) AND att14 = (-inf, 0.0088) AND att5 = <0.0095, 1.00) AND att7 = <0.0067, 1.01) AND att11 = <0.0097, inf) AND att2 = <0.0068, inf) AND att10 = (-inf, 0.51) AND att4 = <-0.0069, inf) AND att3 = <-0.0071, inf) THEN label = {1.00} [1.00,1.00]
# IF att5 = <0.009, 1.00) AND att14 = (-inf, 0.0093) AND att7 = <0.0067, inf) AND att2 = (-inf, 1.00) AND att3 = <-0.0077, inf) THEN label = {0.98} [0.86,1.10]
# IF att9 = (-inf, 1.00) AND att5 = <0.0096, inf) AND att14 = <-0.0059, 0.0081) AND att1 = <-0.0058, 1.00) AND att10 = <-0.0039, inf) AND att13 = <-0.0051, inf) AND att4 = <-0.0084, 0.0057) AND att12 = (-inf, 1.00) THEN label = {0.95} [0.82,1.09]
# IF att9 = <6.8E-4, 1.00) AND att5 = <0.009, inf) AND att14 = <-0.0022, 0.0065) AND att8 = (-inf, 1.01) AND att7 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att1 = (-inf, 1.01) AND att4 = <-0.0089, inf) AND att3 = <-0.006, inf) AND att12 = (-inf, 1.00) THEN label = {0.95} [0.77,1.13]
# IF att9 = (-inf, 1.01) AND att6 = <-0.009, 0.0013) AND att14 = (-inf, 0.0088) AND att5 = <0.99, inf) AND att8 = <-0.0091, inf) AND att7 = <0.0067, inf) AND att2 = <-0.0061, 1.00) AND att11 = <-0.0075, inf) AND att1 = (-inf, 1.01) AND att4 = (-inf, 0.0098) AND att13 = <-0.0078, inf) AND att12 = (-inf, 1.00) THEN label = {0.97} [0.86,1.09]
# IF att14 = (-inf, 0.0087) AND att5 = <0.0096, 1.01) AND att7 = (-inf, 1.00) AND att2 = <-0.0088, inf) AND att11 = <-0.0087, 1.00) AND att10 = <-0.0022, inf) AND att3 = <-0.0038, inf) THEN label = {0.88} [0.74,1.02]
# IF att6 = <-1.6E-4, 1.00) AND att14 = (-inf, 0.0093) AND att8 = (-inf, 0.0073) AND att7 = (-inf, 1.01) AND att2 = <-0.004, inf) AND att11 = <-0.0036, inf) AND att10 = (-inf, 1.00) AND att4 = <-0.0067, 0.50) AND att3 = (-inf, 0.0053) THEN label = {0.96} [0.91,1.01]
# IF att9 = (-inf, 1.01) AND att6 = <0.0042, inf) AND att14 = (-inf, 0.0093) AND att8 = <-0.0083, 0.0073) AND att1 = (-inf, 1.00) AND att13 = (-inf, 1.00) AND att4 = (-inf, 6.1E-4) AND att12 = <-0.0069, inf) AND att3 = (-inf, 0.0054) THEN label = {0.98} [0.91,1.04]
# IF att6 = <0.99, inf) AND att5 = <0.009, inf) AND att14 = (-inf, 0.0093) AND att7 = (-inf, 0.0042) AND att11 = (-inf, 0.50) AND att1 = (-inf, 1.01) AND att4 = (-inf, 0.0088) THEN label = {0.96} [0.77,1.14]
# IF att9 = (-inf, 1.00) AND att6 = <-0.0022, inf) AND att14 = <-0.0073, 0.0093) AND att8 = <-0.0039, 1.01) AND att7 = (-inf, 0.50) AND att2 = <-0.0039, 1.00) AND att10 = (-inf, 1.00) AND att4 = <-0.004, inf) AND att12 = (-inf, 0.50) THEN label = {0.95} [0.77,1.13]
# IF att9 = (-inf, 1.01) AND att6 = <-0.0075, inf) AND att14 = (-inf, 0.0087) AND att5 = (-inf, 1.01) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att10 = (-inf, 1.00) AND att1 = <-0.0013, 1.01) AND att13 = <-5.1E-4, inf) AND att4 = (-inf, 0.50) AND att12 = <-0.0034, inf) AND att3 = <-0.0066, 0.0072) THEN label = {0.95} [0.88,1.01]
# IF att6 = (-inf, 1.00) AND att5 = <0.009, inf) AND att14 = <-0.0082, inf) AND att8 = <-0.0084, 1.00) AND att7 = <-0.0087, 0.99) AND att2 = <0.002, inf) AND att10 = <-0.0086, 1.00) AND att1 = (-inf, 1.01) AND att13 = (-inf, -0.0041) AND att12 = (-inf, 1.01) AND att3 = (-inf, 0.0079) THEN label = {0.71} [0.59,0.83]
# IF att6 = <-0.0014, inf) AND att14 = <0.0082, 0.50) AND att10 = <-0.0059, inf) AND att4 = (-inf, 0.51) AND att13 = (-inf, 1.00) AND att3 = (-inf, 1.00) THEN label = {0.96} [0.90,1.01]
# IF att9 = <-0.0091, inf) AND att5 = <0.009, 1.01) AND att14 = <-0.0068, 0.99) AND att7 = <-0.0095, inf) AND att11 = (-inf, 1.00) AND att2 = <-0.0069, 1.00) AND att1 = (-inf, 1.01) AND att10 = (-inf, 1.01) AND att13 = <-0.0031, inf) AND att4 = <-0.0083, 0.0093) AND att3 = <-0.0096, 1.00) AND att12 = <-0.0042, inf) THEN label = {0.93} [0.75,1.11]
# IF att6 = <-0.008, inf) AND att14 = <0.50, inf) AND att8 = (-inf, 1.00) AND att7 = <0.0056, 1.01) AND att2 = <-0.0069, inf) AND att10 = <-0.005, inf) AND att3 = (-inf, 0.0085) THEN label = {0.75} [0.68,0.81]
# IF att14 = <-0.0081, 0.99) AND att11 = <-0.0093, inf) AND att10 = <-0.0078, 1.00) AND att13 = (-inf, 1.01) AND att12 = (-inf, 1.00) AND att9 = (-inf, 1.01) AND att6 = <-0.0093, 1.00) AND att5 = <0.009, 1.01) AND att8 = <-0.0087, inf) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att1 = (-inf, 1.01) AND att4 = <-0.0065, 1.00) AND att3 = <-0.0086, inf) THEN label = {0.93} [0.76,1.10]
# IF att5 = <0.99, inf) AND att14 = <0.50, inf) AND att8 = <-0.0048, 1.01) AND att7 = (-inf, 1.01) AND att2 = <-0.0072, 1.00) AND att11 = <-0.0042, 1.00) AND att10 = (-inf, 1.00) AND att1 = <-0.0071, inf) AND att4 = <-0.0073, 0.0057) AND att12 = (-inf, 1.00) THEN label = {0.73} [0.64,0.83]
# IF att9 = <-9.0E-4, 1.01) AND att6 = <-0.0075, inf) AND att5 = <0.009, 1.00) AND att7 = <-0.0075, inf) AND att11 = <-0.0098, inf) AND att2 = (-inf, 0.007) AND att1 = <0.99, inf) AND att13 = (-inf, -1.1E-4) AND att4 = (-inf, 0.51) THEN label = {0.91} [0.84,0.98]
# IF att5 = <0.009, inf) AND att14 = <1.00, inf) AND att7 = (-inf, 1.00) AND att10 = <-0.0077, inf) AND att1 = <0.99, 1.00) AND att4 = <-0.0059, 0.0028) AND att3 = <-0.0091, inf) THEN label = {0.72} [0.68,0.75]
# IF att6 = <-0.0083, inf) AND att5 = <0.009, 1.01) AND att14 = <1.00, inf) AND att7 = (-inf, 1.01) AND att2 = <-0.0048, inf) AND att10 = <-0.0098, inf) AND att1 = <0.99, inf) AND att3 = <-0.0031, inf) THEN label = {0.73} [0.69,0.77]
# IF att9 = <-0.009, inf) AND att6 = (-inf, 0.99) AND att5 = <0.009, 1.00) AND att14 = <1.00, inf) AND att8 = (-inf, 1.00) AND att2 = (-inf, 0.0021) AND att1 = (-inf, 1.00) AND att13 = (-inf, 1.01) AND att12 = <-0.0081, inf) THEN label = {0.77} [0.68,0.86]
# IF att9 = (-inf, 0.0097) AND att6 = <-0.009, 1.00) AND att5 = <0.009, inf) AND att14 = (-inf, 1.00) AND att11 = (-inf, 1.01) AND att1 = <0.99, 1.01) AND att10 = <-0.0013, 1.01) THEN label = {0.86} [0.72,1.01]
# IF att9 = (-inf, 1.01) AND att5 = <0.009, 1.01) AND att14 = <1.00, 1.01) AND att2 = <-0.0093, 0.0072) AND att11 = <-0.0076, inf) AND att10 = (-inf, 1.01) AND att1 = <0.99, inf) AND att4 = <-0.0064, inf) AND att13 = <-5.5E-5, inf) AND att3 = (-inf, 1.01) AND att12 = (-inf, 1.01) THEN label = {0.73} [0.69,0.77]
# IF att9 = <-0.0045, inf) AND att6 = <0.50, inf) AND att5 = <0.009, inf) AND att8 = <-0.0052, inf) AND att10 = <0.99, inf) AND att13 = <0.99, inf) AND att4 = (-inf, 0.0076) AND att3 = <-0.006, inf) THEN label = {0.87} [0.86,0.87]
# IF att9 = <-0.0067, 1.01) AND att5 = <0.009, inf) AND att8 = <-0.0052, 0.0081) AND att2 = <-0.0017, 1.00) AND att11 = (-inf, 0.0086) AND att10 = (-inf, 1.00) AND att1 = <-0.0039, inf) AND att13 = <-0.0033, inf) AND att12 = <-0.0063, 1.00) AND att3 = <-0.0075, 0.0079) THEN label = {0.77} [0.67,0.87]
# IF att9 = <0.0036, inf) AND att6 = <-0.009, inf) AND att14 = <0.99, inf) AND att5 = (-inf, 1.00) AND att8 = (-inf, 0.99) AND att7 = <-0.008, inf) AND att11 = <-0.0079, inf) AND att10 = (-inf, 1.01) AND att1 = (-inf, 0.50) AND att13 = <-0.0029, 1.01) AND att3 = (-inf, 1.00) AND att12 = (-inf, 1.01) THEN label = {0.62} [0.49,0.75]
# IF att9 = <-0.0059, inf) AND att6 = <0.0034, 0.007) AND att5 = <0.009, 1.01) AND att10 = <-0.0095, inf) AND att1 = (-inf, 0.0028) AND att4 = <-0.0075, inf) THEN label = {0.51} [0.36,0.66]
# IF att6 = <5.5E-5, 1.01) AND att5 = <0.009, inf) AND att14 = <0.99, inf) AND att8 = <0.0067, 1.01) AND att7 = (-inf, 0.51) AND att11 = <-0.0091, 1.01) AND att10 = (-inf, 1.01) AND att1 = (-inf, 1.00) AND att4 = (-inf, 0.0077) AND att12 = (-inf, 1.00) AND att3 = <-0.009, inf) THEN label = {0.65} [0.54,0.77]
# IF att6 = <0.0017, inf) AND att8 = <1.01, inf) AND att2 = (-inf, 1.00) AND att10 = (-inf, 1.01) AND att1 = (-inf, 0.51) THEN label = {0.51} [0.47,0.54]
# IF att6 = (-inf, 0.0069) AND att5 = <0.009, inf) AND att14 = <0.99, inf) AND att7 = (-inf, 0.50) AND att11 = <-0.0072, inf) AND att10 = <-0.0092, 0.50) AND att1 = <-0.0044, 0.51) THEN label = {0.49} [0.44,0.54]
# IF att6 = (-inf, 0.0085) AND att5 = <0.009, inf) AND att14 = <0.99, inf) AND att8 = <0.99, inf) AND att7 = <-0.0025, inf) AND att1 = <-0.0073, inf) AND att10 = <7.4E-4, inf) AND att4 = <-0.0061, inf) AND att12 = (-inf, 1.01) AND att3 = <-0.0056, inf) THEN label = {0.56} [0.41,0.70]
# IF att9 = <-0.0092, inf) AND att7 = <1.01, inf) AND att1 = <-0.0031, inf) AND att4 = <-0.0043, inf) AND att12 = (-inf, 1.00) THEN label = {0.90} [0.74,1.05]
# IF att6 = (-inf, 1.00) AND att5 = <0.0087, 1.00) AND att14 = (-inf, 0.99) AND att8 = (-inf, 1.00) AND att2 = <-0.0018, 1.00) AND att1 = (-inf, 1.01) AND att4 = <0.0016, inf) AND att3 = <-0.0056, 0.0066) AND att12 = <-0.0026, 1.00) THEN label = {0.98} [0.82,1.13]
# IF att9 = <-0.007, inf) AND att6 = <-0.0075, inf) AND att14 = <-0.0089, 1.01) AND att5 = <-0.0083, 0.0094) AND att8 = <0.0064, inf) AND att7 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att2 = (-inf, 1.01) AND att1 = <-0.0024, 1.00) AND att13 = <-0.0073, inf) AND att12 = (-inf, 1.01) AND att3 = (-inf, 0.50) THEN label = {0.75} [0.62,0.87]
# IF att9 = <-0.0086, 1.01) AND att5 = <0.0084, 1.00) AND att14 = <-0.005, inf) AND att8 = <-0.0078, 1.01) AND att2 = (-inf, 1.00) AND att11 = <-0.0068, 1.01) AND att10 = <-0.0095, inf) AND att1 = (-inf, 1.00) AND att4 = <-0.0038, inf) AND att12 = <-0.0063, 1.00) AND att3 = <-0.0061, 0.0031) THEN label = {0.77} [0.63,0.91]
# IF att14 = <0.99, 1.01) AND att11 = (-inf, 0.0086) AND att10 = (-inf, 1.01) AND att13 = <-0.006, inf) AND att12 = (-inf, 1.01) AND att9 = (-inf, 1.00) AND att5 = (-inf, 1.00) AND att8 = <-0.0088, inf) AND att7 = <-2.1E-4, inf) AND att2 = <-0.0071, 1.00) AND att1 = <-9.8E-4, 1.01) AND att4 = <-0.0047, 1.01) AND att3 = <-0.0056, 1.00) THEN label = {0.70} [0.53,0.86]
# IF att9 = (-inf, 1.00) AND att6 = <-5.8E-4, inf) AND att14 = <0.99, 1.01) AND att5 = <-0.0083, 0.50) AND att11 = (-inf, 0.0086) AND att2 = <-0.0078, 0.0082) AND att1 = <0.99, inf) AND att4 = (-inf, 1.01) AND att13 = <-0.0098, inf) AND att3 = <-0.006, 1.00) THEN label = {0.70} [0.53,0.87]
# IF att9 = <-0.0097, 1.00) AND att14 = <0.99, inf) AND att5 = <5.9E-4, 0.0089) AND att8 = (-inf, 1.00) AND att7 = <-0.0093, 1.00) AND att2 = <-0.0017, inf) AND att11 = (-inf, 0.0078) AND att10 = (-inf, 1.01) AND att4 = (-inf, 1.01) AND att12 = (-inf, 1.01) AND att3 = <-0.0082, 0.50) THEN label = {0.65} [0.59,0.71]
# IF att9 = (-inf, 1.00) AND att6 = <-0.008, inf) AND att14 = <0.99, inf) AND att5 = (-inf, 1.00) AND att7 = (-inf, 0.0045) AND att11 = (-inf, 0.0086) AND att10 = (-inf, 1.01) AND att1 = <-0.0058, 1.00) AND att4 = <2.1E-4, inf) AND att3 = (-inf, 1.00) AND att12 = (-inf, 1.01) THEN label = {0.63} [0.48,0.77]
# IF att9 = <-0.007, 1.00) AND att6 = (-inf, 1.00) AND att14 = <0.99, inf) AND att5 = (-inf, 0.0078) AND att11 = <-0.005, 0.0086) AND att1 = <-0.0068, 1.00) AND att10 = (-inf, 1.01) AND att13 = <-0.0097, inf) AND att4 = (-inf, 1.01) AND att12 = <-0.0083, 1.01) AND att3 = (-inf, 0.0055) THEN label = {0.69} [0.62,0.75]
# IF att9 = <-0.0078, inf) AND att6 = (-inf, 1.00) AND att14 = <0.99, 1.01) AND att5 = (-inf, 0.99) AND att11 = <-9.1E-4, 0.99) AND att10 = <-0.0049, 1.00) AND att1 = (-inf, 0.99) AND att4 = <4.8E-4, 1.00) AND att13 = (-inf, 1.00) AND att3 = <-0.0074, 0.50) THEN label = {0.73} [0.56,0.89]
# IF att9 = (-inf, 0.99) AND att6 = (-inf, 1.01) AND att14 = <0.99, 1.01) AND att5 = <-0.0066, 0.007) AND att11 = <-0.0042, 1.01) AND att10 = (-inf, 0.50) AND att4 = (-inf, 1.00) AND att3 = (-inf, 0.50) THEN label = {0.75} [0.69,0.80]
# IF att9 = <-0.0054, 1.00) AND att6 = <-6.4E-4, 1.01) AND att5 = <-0.0084, 0.0049) AND att14 = <0.99, inf) AND att7 = (-inf, 0.0096) AND att11 = (-inf, 1.00) AND att2 = <0.0081, inf) AND att10 = <-0.0038, inf) AND att3 = <-0.0096, 0.0049) THEN label = {0.70} [0.62,0.78]
# IF att14 = <0.50, inf) AND att5 = (-inf, 0.009) AND att8 = <-0.0087, inf) AND att7 = (-inf, 0.50) AND att11 = (-inf, 0.0088) AND att1 = <-0.0034, inf) AND att10 = (-inf, 1.00) AND att4 = <0.009, inf) AND att12 = (-inf, 1.01) AND att3 = <-0.0097, 1.00) THEN label = {0.63} [0.51,0.74]
# IF att9 = (-inf, 0.99) AND att5 = <-0.0094, inf) AND att14 = <0.99, inf) AND att7 = (-inf, 1.00) AND att2 = <-0.0021, 1.01) AND att4 = <0.99, inf) THEN label = {0.71} [0.62,0.79]
# IF att14 = <0.99, inf) AND att11 = (-inf, 1.00) AND att10 = <-0.0084, inf) AND att13 = <-0.0022, inf) AND att9 = <-0.0075, 1.01) AND att6 = (-inf, 1.00) AND att5 = (-inf, 0.0069) AND att8 = <-0.0025, inf) AND att7 = <-0.0046, 0.0088) AND att2 = <-0.0014, inf) AND att1 = (-inf, 1.00) AND att4 = <0.009, inf) AND att3 = (-inf, 1.00) THEN label = {0.58} [0.40,0.76]
# IF att9 = (-inf, 1.01) AND att6 = (-inf, 1.01) AND att5 = <-0.0093, 0.0069) AND att14 = <-0.0079, inf) AND att8 = <-0.0074, inf) AND att11 = <-0.0085, 0.0072) AND att1 = <-0.0056, inf) AND att13 = (-inf, 1.01) AND att3 = <0.0088, 1.01) AND att12 = <-0.0089, 1.01) THEN label = {0.20} [-0.06,0.47]
# IF att14 = (-inf, 0.50) AND att11 = (-inf, 0.0037) AND att4 = <1.01, inf) THEN label = {0.74} [0.64,0.85]
# IF att6 = (-inf, 1.01) AND att5 = (-inf, 0.0027) AND att7 = <-0.0089, inf) AND att11 = <-0.007, 1.00) AND att2 = <-0.0069, inf) AND att4 = <1.01, 1.01) AND att12 = (-inf, 1.00) THEN label = {0.82} [0.74,0.91]
# IF att9 = (-inf, 1.01) AND att14 = <0.0079, 0.50) AND att5 = <-0.0071, 0.0075) AND att7 = (-inf, 1.01) AND att2 = <-0.0038, inf) AND att13 = <-0.0061, inf) AND att4 = <0.0083, 1.01) AND att12 = (-inf, 1.01) THEN label = {1.04} [0.94,1.14]
# IF att9 = <-0.0061, inf) AND att6 = <-0.0064, inf) AND att14 = (-inf, 0.0087) AND att5 = (-inf, 0.0077) AND att8 = <-0.0049, 0.0094) AND att11 = <-0.0012, 1.01) AND att2 = (-inf, 1.00) AND att10 = <-0.0018, inf) AND att13 = <-0.0065, inf) AND att4 = (-inf, 1.01) AND att3 = <-0.0054, 0.50) THEN label = {0.99} [0.94,1.04]
# IF att9 = (-inf, 0.0098) AND att6 = (-inf, 1.00) AND att14 = (-inf, 0.0098) AND att5 = (-inf, 1.00) AND att8 = (-inf, 0.50) AND att11 = <0.0073, 1.01) AND att2 = <-0.001, inf) AND att13 = (-inf, 1.00) AND att3 = (-inf, 0.0031) THEN label = {1.05} [1.05,1.05]
# IF att5 = <-0.0067, 0.0041) AND att14 = (-inf, 0.0086) AND att8 = (-inf, 0.0092) AND att7 = <-0.0066, inf) AND att11 = <0.0054, 1.01) AND att1 = (-inf, 1.00) AND att10 = <-0.0084, inf) AND att4 = (-inf, 1.01) AND att13 = (-inf, 1.00) AND att3 = (-inf, 0.0086) AND att12 = (-inf, 1.00) THEN label = {1.04} [1.02,1.06]
# IF att9 = (-inf, 0.01) AND att14 = (-inf, 0.0098) AND att5 = <-0.0052, 0.0082) AND att8 = (-inf, 0.50) AND att7 = <-7.4E-5, 1.01) AND att2 = <7.1E-4, 1.00) AND att1 = <-0.0073, 1.00) AND att13 = (-inf, 1.00) AND att4 = <0.99, inf) AND att3 = <-0.0072, 0.0054) THEN label = {1.03} [0.98,1.07]
# IF att14 = (-inf, 0.0089) AND att11 = (-inf, 1.01) AND att13 = (-inf, 1.01) AND att12 = (-inf, 1.01) AND att9 = <-0.0062, 0.01) AND att6 = <-0.0095, 1.01) AND att5 = <-0.0068, 1.00) AND att8 = (-inf, 0.0099) AND att7 = <-0.0073, inf) AND att2 = <-0.0098, 1.00) AND att1 = (-inf, 1.01) AND att4 = <0.0028, 1.01) AND att3 = (-inf, 0.99) THEN label = {0.99} [0.89,1.09]
# IF att9 = (-inf, 1.00) AND att6 = <-4.7E-4, inf) AND att14 = (-inf, 0.0098) AND att5 = <-0.0083, 1.00) AND att8 = (-inf, 0.50) AND att11 = (-inf, 0.50) AND att1 = <0.99, inf) AND att3 = <-0.0069, 0.99) THEN label = {0.94} [0.89,0.98]
# IF att14 = (-inf, 0.0098) AND att7 = <-0.006, inf) AND att2 = <-0.0036, inf) AND att11 = (-inf, -0.0033) AND att1 = <1.9E-4, inf) AND att13 = <-0.0071, inf) AND att4 = <0.50, 1.00) AND att3 = (-inf, -0.0012) AND att12 = (-inf, 1.00) THEN label = {0.94} [0.85,1.03]
# IF att6 = <0.0062, inf) AND att14 = (-inf, 0.0082) AND att5 = <-0.006, inf) AND att8 = <-0.007, 0.0095) AND att1 = (-inf, 1.00) AND att10 = <-0.0017, inf) AND att13 = (-inf, 1.00) AND att4 = <0.99, inf) AND att12 = (-inf, 1.01) AND att3 = <-0.0067, inf) THEN label = {0.94} [0.83,1.04]
# IF att6 = <-0.0067, inf) AND att14 = (-inf, 0.0098) AND att5 = (-inf, -4.1E-4) AND att7 = <-0.0072, 0.50) AND att10 = (-inf, 0.0075) AND att3 = (-inf, 0.0018) AND att12 = <0.0046, inf) THEN label = {0.93} [0.86,1.00]
# IF att9 = <-0.005, inf) AND att14 = (-inf, 0.0067) AND att8 = <0.50, inf) AND att11 = <0.0077, inf) AND att10 = <-0.0084, inf) AND att1 = (-inf, 0.50) AND att3 = <-0.0064, 0.0086) THEN label = {0.84} [0.76,0.93]
# IF att9 = (-inf, 1.01) AND att6 = <-0.0075, inf) AND att5 = <-0.0079, inf) AND att8 = <0.0089, 1.00) AND att11 = (-inf, 1.00) AND att1 = <-0.0077, 1.00) AND att4 = <0.99, 1.01) AND att3 = <-0.0065, 0.0058) AND att12 = <-0.0021, inf) THEN label = {0.64} [0.54,0.74]
# IF att9 = (-inf, 1.01) AND att6 = (-inf, 0.0084) AND att14 = (-inf, 0.009) AND att7 = <-0.0082, 0.008) AND att11 = (-inf, 0.0034) AND att2 = (-inf, 1.00) AND att1 = (-inf, 1.01) AND att10 = (-inf, 1.01) AND att4 = <0.50, 1.00) AND att12 = (-inf, 1.01) THEN label = {0.79} [0.73,0.84]
# IF att6 = <-0.0088, inf) AND att14 = (-inf, 0.0091) AND att8 = <1.00, inf) AND att2 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att4 = (-inf, 1.01) AND att13 = (-inf, 1.00) AND att3 = <-0.0053, 0.99) AND att12 = <2.9E-4, 1.01) THEN label = {0.79} [0.61,0.97]
# 117
# Mean Jaccard Similarity for the Rule Set: 0.01
# Percentage of predictions within bounds: 0.861%

# %%
clf = DecisionTreeRegressor(random_state=0)
clf.fit(samp, yee)
pred = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
pr_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(pred, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (pr_count_within_bounds / len(pred)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        #rule += " then "
        if class_names is None:
            s = 1
            #rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        #rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules
rules = get_rules(clf, Xe.columns, None)
for r in rules:
    print(r)
len(rules)
# Out:
# Percentage of predictions within bounds: 0.972%
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 > 0.99) and (categorical_version_v2 > 0.992) and (learning_rate > 0.007) and (categorical_conv3depth_4 > 0.993) and (categorical_conv3depth_4 > 0.996) and (categorical_pooling_avg > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 > 0.997) and (categorical_optimizer_sgd > 0.499) and (categorical_conv4depth_36 <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg <= 0.501) and (categorical_conv3depth_8 > 0.003) and (categorical_optimizer_rmsprop > 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg <= 0.501) and (categorical_conv3depth_8 > 0.003) and (categorical_optimizer_rmsprop <= 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg <= 0.501) and (categorical_conv3depth_8 <= 0.003) and (categorical_conv4depth_36 > 1.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg <= 0.501) and (categorical_conv3depth_8 <= 0.003) and (categorical_conv4depth_36 <= 1.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 > -0.004) and (categorical_pooling_max > 0.999)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 > -0.004) and (categorical_pooling_max <= 0.999) and (categorical_optimizer_rmsprop > 0.5)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 > -0.004) and (categorical_pooling_max <= 0.999) and (categorical_optimizer_rmsprop <= 0.5) and (categorical_pooling_max > 0.996)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 > -0.004) and (categorical_pooling_max <= 0.999) and (categorical_optimizer_rmsprop <= 0.5) and (categorical_pooling_max <= 0.996)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 <= -0.004) and (categorical_conv3depth_8 > -0.003) and (categorical_conv4depth_23 > -0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 <= -0.004) and (categorical_conv3depth_8 > -0.003) and (categorical_conv4depth_23 <= -0.005) and (categorical_conv3depth_4 > 0.999)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 <= -0.004) and (categorical_conv3depth_8 > -0.003) and (categorical_conv4depth_23 <= -0.005) and (categorical_conv3depth_4 <= 0.999)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 <= 0.499) and (categorical_conv4depth_23 <= -0.004) and (categorical_conv3depth_8 <= -0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 > 0.997) and (categorical_optimizer_sgd > 0.499) and (categorical_conv4depth_36 > 0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 > 0.997) and (categorical_optimizer_sgd <= 0.499) and (categorical_optimizer_adam > -0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next <= 0.008) and (categorical_version_next <= 0.006) and (categorical_pooling_avg <= -0.001) and (categorical_version_v1 > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 > 0.997) and (categorical_optimizer_sgd <= 0.499) and (categorical_optimizer_adam <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 <= 0.997) and (categorical_conv4depth_36 > 0.497) and (categorical_pooling_max > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 <= 0.997) and (categorical_conv4depth_36 > 0.497) and (categorical_pooling_max <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next > 0.994) and (categorical_conv4depth_6 <= 0.997) and (categorical_conv4depth_36 <= 0.497)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg > 0.992) and (categorical_optimizer_rmsprop > 1.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg > 0.992) and (categorical_optimizer_rmsprop <= 1.004) and (categorical_optimizer_rmsprop > 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg > 0.992) and (categorical_optimizer_rmsprop <= 1.004) and (categorical_optimizer_rmsprop <= 0.998) and (categorical_optimizer_adam > 0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg > 0.992) and (categorical_optimizer_rmsprop <= 1.004) and (categorical_optimizer_rmsprop <= 0.998) and (categorical_optimizer_adam <= 0.005) and (categorical_conv4depth_23 > 0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg > 0.992) and (categorical_optimizer_rmsprop <= 1.004) and (categorical_optimizer_rmsprop <= 0.998) and (categorical_optimizer_adam <= 0.005) and (categorical_conv4depth_23 <= 0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next > 0.008) and (categorical_conv4depth_23 > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next > 0.008) and (categorical_conv4depth_23 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next <= 0.008) and (categorical_version_next > 0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next <= 0.008) and (categorical_version_next <= 0.006) and (categorical_pooling_avg > -0.001) and (categorical_pooling_max > 0.499)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg <= 0.998) and (categorical_version_v2 <= 0.002) and (learning_rate <= 1.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg <= 0.998) and (categorical_version_v2 <= 0.002) and (learning_rate > 1.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg <= 0.998) and (categorical_version_v2 > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd <= 0.994) and (categorical_version_v2 <= 0.007) and (categorical_pooling_avg <= 1.008) and (categorical_version_v2 <= -0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max > 1.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max <= 1.006) and (categorical_version_v1 > 0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max <= 1.006) and (categorical_version_v1 <= 0.005) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_4 > 1.001) and (categorical_version_v1 > -0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max <= 1.006) and (categorical_version_v1 <= 0.005) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_4 > 1.001) and (categorical_version_v1 <= -0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max <= 1.006) and (categorical_version_v1 <= 0.005) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_4 <= 1.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max > 0.493) and (categorical_pooling_max <= 1.006) and (categorical_version_v1 <= 0.005) and (categorical_conv4depth_23 <= -0.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next > 1.003) and (categorical_version_v2 <= 0.008) and (categorical_conv4depth_6 <= 0.002) and (categorical_pooling_max <= 0.493)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg > 0.003) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_8 > -0.005) and (categorical_conv3depth_8 > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg > 0.003) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_8 > -0.005) and (categorical_conv3depth_8 <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg > 0.003) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_8 <= -0.005) and (categorical_conv4depth_6 > 1.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg > 0.003) and (categorical_conv4depth_23 > -0.004) and (categorical_conv3depth_8 <= -0.005) and (categorical_conv4depth_6 <= 1.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg > 0.003) and (categorical_conv4depth_23 <= -0.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next > 0.5) and (categorical_conv3depth_4 > 0.998) and (categorical_pooling_max > 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next > 0.5) and (categorical_conv3depth_4 > 0.998) and (categorical_pooling_max <= 0.997) and (categorical_version_next > 0.999)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next > 0.5) and (categorical_conv3depth_4 > 0.998) and (categorical_pooling_max <= 0.997) and (categorical_version_next <= 0.999)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next > 0.5) and (categorical_conv3depth_4 <= 0.998) and (categorical_version_v1 > 0.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next > 0.5) and (categorical_conv3depth_4 <= 0.998) and (categorical_version_v1 <= 0.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next <= 0.5) and (categorical_optimizer_sgd > 1.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop > -0.009) and (categorical_pooling_avg <= 0.003) and (categorical_version_next <= 0.5) and (categorical_optimizer_sgd <= 1.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop <= -0.009) and (categorical_conv3depth_4 > 0.996)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd > 1.001) and (categorical_optimizer_rmsprop <= -0.009) and (categorical_conv3depth_4 <= 0.996)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd > 0.994) and (categorical_pooling_avg > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd > 0.994) and (categorical_pooling_avg <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd <= 0.994) and (categorical_version_v2 > 0.007) and (learning_rate > 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd <= 0.994) and (categorical_version_v2 > 0.007) and (learning_rate <= 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd <= 0.994) and (categorical_version_v2 <= 0.007) and (categorical_pooling_avg > 1.008)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 > 0.993) and (categorical_version_v1 > 0.499) and (categorical_pooling_avg > 0.501) and (categorical_pooling_avg > 0.998) and (categorical_optimizer_sgd <= 0.994) and (categorical_version_v2 <= 0.007) and (categorical_pooling_avg <= 1.008) and (categorical_version_v2 > -0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next <= 0.008) and (categorical_version_next <= 0.006) and (categorical_pooling_avg > -0.001) and (categorical_pooling_max <= 0.499)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 > -0.001) and (categorical_pooling_avg <= 0.992) and (categorical_version_next <= 0.008) and (categorical_version_next <= 0.006) and (categorical_pooling_avg <= -0.001) and (categorical_version_v1 <= 1.002)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 > 0.99) and (categorical_version_v2 > 0.992) and (learning_rate > 0.007) and (categorical_conv3depth_4 > 0.993) and (categorical_conv3depth_4 > 0.996) and (categorical_pooling_avg <= 1.002) and (learning_rate > 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 > 0.502) and (categorical_conv4depth_6 <= -0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 > 0.999) and (categorical_pooling_max <= -0.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 <= 0.999) and (categorical_conv3depth_8 > 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 <= 0.999) and (categorical_conv3depth_8 <= 0.998)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next <= 0.501) and (categorical_version_v1 > 0.003) and (categorical_optimizer_sgd > 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next <= 0.501) and (categorical_version_v1 > 0.003) and (categorical_optimizer_sgd <= 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next <= 0.501) and (categorical_version_v1 <= 0.003) and (categorical_optimizer_sgd > 0.997) and (categorical_pooling_max > 0.008)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next <= 0.501) and (categorical_version_v1 <= 0.003) and (categorical_optimizer_sgd > 0.997) and (categorical_pooling_max <= 0.008)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next <= 0.501) and (categorical_version_v1 <= 0.003) and (categorical_optimizer_sgd <= 0.997)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next > 0.502) and (categorical_conv4depth_23 > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next > 0.502) and (categorical_conv4depth_23 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 > 1.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 > 0.502) and (categorical_conv4depth_6 > -0.003) and (categorical_optimizer_rmsprop > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 > 0.502) and (categorical_conv4depth_6 > -0.003) and (categorical_optimizer_rmsprop <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 <= 0.502) and (categorical_conv3depth_8 > 1.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 <= -0.001) and (categorical_optimizer_sgd > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 <= 0.502) and (categorical_conv3depth_8 <= 1.005) and (categorical_optimizer_rmsprop > 0.494) and (categorical_conv4depth_6 > -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 <= 0.502) and (categorical_conv3depth_8 <= 1.005) and (categorical_optimizer_rmsprop > 0.494) and (categorical_conv4depth_6 <= -0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg <= 0.5) and (categorical_version_next <= 0.502) and (categorical_version_v1 <= 1.003) and (categorical_version_v1 <= 0.502) and (categorical_conv3depth_8 <= 1.005) and (categorical_optimizer_rmsprop <= 0.494)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg > 0.501) and (categorical_optimizer_rmsprop > 0.504)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg > 0.501) and (categorical_optimizer_rmsprop <= 0.504) and (categorical_conv4depth_6 > -0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg > 0.501) and (categorical_optimizer_rmsprop <= 0.504) and (categorical_conv4depth_6 <= -0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max > 1.002) and (categorical_version_v1 > 0.994) and (categorical_version_next > -0.003) and (categorical_optimizer_adam > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max > 1.002) and (categorical_version_v1 > 0.994) and (categorical_version_next > -0.003) and (categorical_optimizer_adam <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max > 1.002) and (categorical_version_v1 > 0.994) and (categorical_version_next <= -0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max > 1.002) and (categorical_version_v1 <= 0.994) and (categorical_version_v1 > 0.992)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max > 1.002) and (categorical_version_v1 <= 0.994) and (categorical_version_v1 <= 0.992)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max <= 1.002) and (categorical_version_v1 > 1.006) and (categorical_version_next > 0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 <= 0.992) and (categorical_version_v1 > 0.007) and (categorical_pooling_avg <= 0.501) and (categorical_pooling_max <= 1.002) and (categorical_version_v1 > 1.006) and (categorical_version_next <= 0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 > 0.999) and (categorical_pooling_max > -0.004) and (categorical_conv3depth_4 <= 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 > 0.999) and (categorical_pooling_max > -0.004) and (categorical_conv3depth_4 > 0.001) and (categorical_optimizer_rmsprop <= -0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate <= -0.001) and (categorical_conv4depth_36 > 0.999) and (categorical_pooling_max > -0.004) and (categorical_conv3depth_4 > 0.001) and (categorical_optimizer_rmsprop > -0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 <= 0.501) and (categorical_version_next > 0.501) and (categorical_optimizer_rmsprop <= 0.501) and (learning_rate > -0.001) and (categorical_version_v1 <= -0.004) and (categorical_optimizer_sgd <= 1.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop > 0.005) and (categorical_version_v1 <= -0.001) and (categorical_optimizer_sgd <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop <= 0.005) and (categorical_version_v2 > -0.006) and (categorical_version_v2 > -0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop <= 0.005) and (categorical_version_v2 > -0.006) and (categorical_version_v2 <= -0.005)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 <= 0.009) and (categorical_conv3depth_8 <= 0.991) and (categorical_version_v2 <= 0.01) and (categorical_version_next <= 1.003) and (categorical_optimizer_sgd <= 1.001) and (categorical_conv4depth_36 <= 0.993) and (categorical_version_next <= 0.994) and (categorical_optimizer_rmsprop <= 0.005) and (categorical_version_v2 <= -0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop > 1.003) and (categorical_optimizer_adam > 0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop > 1.003) and (categorical_optimizer_adam <= 0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop <= 1.003) and (categorical_optimizer_sgd > 0.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop <= 1.003) and (categorical_optimizer_sgd <= 0.001) and (categorical_version_v1 > 0.994) and (categorical_optimizer_sgd > -0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop <= 1.003) and (categorical_optimizer_sgd <= 0.001) and (categorical_version_v1 > 0.994) and (categorical_optimizer_sgd <= -0.003)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 > 1.003) and (categorical_optimizer_rmsprop <= 1.003) and (categorical_optimizer_sgd <= 0.001) and (categorical_version_v1 <= 0.994)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 > 0.99) and (categorical_conv3depth_8 > 0.992) and (categorical_pooling_avg > 0.5) and (categorical_version_v1 > 0.501) and (categorical_optimizer_rmsprop > 0.5) and (categorical_conv4depth_36 <= 1.003) and (categorical_optimizer_adam > -0.006) and (categorical_pooling_max > 0.0) and (categorical_conv3depth_8 > 1.006)
# ...
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd <= 0.5) and (categorical_version_next <= 1.004) and (categorical_conv4depth_36 > -0.004) and (categorical_optimizer_rmsprop <= 1.005) and (categorical_pooling_avg <= 0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd <= 0.5) and (categorical_version_next <= 1.004) and (categorical_conv4depth_36 <= -0.004) and (categorical_pooling_avg > -0.0) and (categorical_pooling_avg > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd <= 0.5) and (categorical_version_next <= 1.004) and (categorical_conv4depth_36 <= -0.004) and (categorical_pooling_avg > -0.0) and (categorical_pooling_avg <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd <= 0.5) and (categorical_version_next <= 1.004) and (categorical_conv4depth_36 <= -0.004) and (categorical_pooling_avg <= -0.0)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next <= 0.009) and (categorical_version_v1 > 0.995) and (categorical_pooling_avg > 0.005) and (categorical_conv3depth_4 > 0.008) and (categorical_pooling_avg > 0.009) and (categorical_conv3depth_8 > 0.509)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next <= 0.009) and (categorical_version_v1 > 0.995) and (categorical_pooling_avg > 0.005) and (categorical_conv3depth_4 > 0.008) and (categorical_pooling_avg > 0.009) and (categorical_conv3depth_8 <= 0.509) and (categorical_optimizer_sgd > 0.501) and (learning_rate > 0.998) and (categorical_conv3depth_4 > 0.995) and (categorical_conv4depth_23 > 0.997) and (categorical_conv4depth_23 > 1.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next <= 0.009) and (categorical_version_v1 > 0.995) and (categorical_pooling_avg > 0.005) and (categorical_conv3depth_4 > 0.008) and (categorical_pooling_avg > 0.009) and (categorical_conv3depth_8 <= 0.509) and (categorical_optimizer_sgd > 0.501) and (learning_rate > 0.998) and (categorical_conv3depth_4 > 0.995) and (categorical_conv4depth_23 > 0.997) and (categorical_conv4depth_23 <= 1.004)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next <= 0.009) and (categorical_version_v1 > 0.995) and (categorical_pooling_avg > 0.005) and (categorical_conv3depth_4 > 0.008) and (categorical_pooling_avg > 0.009) and (categorical_conv3depth_8 <= 0.509) and (categorical_optimizer_sgd > 0.501) and (learning_rate > 0.998) and (categorical_conv3depth_4 > 0.995) and (categorical_conv4depth_23 <= 0.997) and (categorical_conv4depth_23 > 0.991)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next <= 0.009) and (categorical_version_v1 > 0.995) and (categorical_pooling_avg > 0.005) and (categorical_conv3depth_4 > 0.008) and (categorical_pooling_avg > 0.009) and (categorical_conv3depth_8 <= 0.509) and (categorical_optimizer_sgd > 0.501) and (learning_rate > 0.998) and (categorical_conv3depth_4 > 0.995) and (categorical_conv4depth_23 <= 0.997) and (categorical_conv4depth_23 <= 0.991)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd > 0.5) and (categorical_conv3depth_8 > 0.5) and (categorical_optimizer_rmsprop <= -0.005) and (categorical_version_v1 > 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg <= 0.501) and (categorical_optimizer_sgd > 0.5) and (categorical_conv3depth_8 > 0.5) and (categorical_optimizer_rmsprop > -0.005) and (categorical_pooling_avg > -0.002)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg > 0.492) and (categorical_pooling_max > 0.001) and (categorical_conv4depth_23 > 0.0) and (categorical_pooling_max <= 0.006)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 <= 0.499) and (categorical_optimizer_sgd <= 0.005) and (categorical_optimizer_rmsprop <= 1.003)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg > 0.492) and (categorical_pooling_max > 0.001) and (categorical_conv4depth_23 <= 0.0) and (categorical_pooling_max > 0.009)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg > 0.492) and (categorical_pooling_max > 0.001) and (categorical_conv4depth_23 <= 0.0) and (categorical_pooling_max <= 0.009)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg > 0.492) and (categorical_pooling_max <= 0.001)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg <= 0.492) and (categorical_version_next > -0.005)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam > 0.994) and (categorical_pooling_avg <= 0.492) and (categorical_version_next <= -0.005)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 > 0.006) and (categorical_optimizer_adam <= 0.994)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd > -0.004) and (learning_rate > -0.004) and (categorical_conv3depth_4 > -0.003)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd > -0.004) and (learning_rate > -0.004) and (categorical_conv3depth_4 <= -0.003)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd > -0.004) and (learning_rate <= -0.004)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd <= -0.004) and (categorical_version_v2 > 0.002) and (categorical_conv4depth_6 > 0.997)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd <= -0.004) and (categorical_version_v2 > 0.002) and (categorical_conv4depth_6 <= 0.997)
# if (categorical_optimizer_adam > 0.5) and (categorical_conv4depth_23 <= 0.99) and (categorical_version_v2 <= 0.5) and (learning_rate <= 0.992) and (categorical_conv4depth_36 <= 0.5) and (categorical_version_next <= 0.009) and (categorical_conv3depth_4 <= 0.006) and (categorical_optimizer_sgd <= -0.004) and (categorical_version_v2 <= 0.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 > 1.008)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam > -0.007) and (categorical_version_v2 > -0.005) and (categorical_pooling_avg > 0.994)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam > -0.007) and (categorical_version_v2 > -0.005) and (categorical_pooling_avg <= 0.994)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam > -0.007) and (categorical_version_v2 <= -0.005) and (categorical_version_next > 1.009)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam > -0.007) and (categorical_version_v2 <= -0.005) and (categorical_version_next <= 1.009)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam <= -0.007) and (categorical_version_v1 > 0.498)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop > 0.006) and (categorical_conv3depth_8 <= 1.008) and (categorical_optimizer_adam <= -0.007) and (categorical_version_v1 <= 0.498)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop <= 0.006) and (categorical_conv4depth_23 > 1.001) and (categorical_version_next > 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop <= 0.006) and (categorical_conv4depth_23 > 1.001) and (categorical_version_next <= 1.002)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop <= 0.006) and (categorical_conv4depth_23 <= 1.001) and (categorical_version_next > 0.994)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 > 0.499) and (categorical_optimizer_rmsprop <= 0.006) and (categorical_conv4depth_23 <= 1.001) and (categorical_version_next <= 0.994)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 <= 0.499) and (categorical_optimizer_sgd > 0.005) and (categorical_pooling_max > -0.007)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 <= 0.499) and (categorical_optimizer_sgd > 0.005) and (categorical_pooling_max <= -0.007)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 <= 0.499) and (categorical_optimizer_sgd <= 0.005) and (categorical_optimizer_rmsprop > 1.003) and (categorical_conv3depth_4 > 1.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate > 0.01) and (categorical_conv4depth_23 > 0.009) and (categorical_version_next > 0.009) and (categorical_pooling_avg > 0.501) and (categorical_conv3depth_8 <= 0.499) and (categorical_optimizer_sgd <= 0.005) and (categorical_optimizer_rmsprop > 1.003) and (categorical_conv3depth_4 <= 1.001)
# if (categorical_optimizer_adam <= 0.5) and (learning_rate <= 0.01) and (categorical_conv4depth_36 <= 0.99) and (categorical_version_next <= 0.5) and (categorical_version_v1 <= 0.993) and (categorical_pooling_avg <= 0.009) and (categorical_conv3depth_4 <= 0.009) and (categorical_version_v1 <= 0.993) and (categorical_optimizer_rmsprop <= 0.992) and (categorical_conv4depth_6 <= -0.007)
# 1000

# %%
# from itertools import combinations

# # Given rule list
# rule_list = rules

# # Function to extract features from a rule
# def extract_features(rule):
#     features = set(rule.split("and"))
#     return features

# # Function to calculate Jaccard similarity between two rules
# def jaccard_similarity(rule1, rule2):
#     features1 = extract_features(rule1)
#     features2 = extract_features(rule2)
#     intersection = len(features1.intersection(features2))
#     union = len(features1.union(features2))
    
#     if union == 0:
#         return 0.0  # Handle the case where both sets are empty
#     else:
#         return intersection / union

# # Calculate Jaccard similarity between all pairs of rules and collect them
# similarities = []
# for rule1, rule2 in combinations(rule_list, 2):
#     similarity = jaccard_similarity(rule1, rule2)
#     similarities.append(similarity)

# # Calculate the mean Jaccard similarity for the entire rule set
# mean_similarity = sum(similarities) / len(similarities)

# print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

# %%
from skrules import SkopeRules
from sklearn.preprocessing import KBinsDiscretizer
yee = yee/np.max(yee)

# transform the dataset with KBinsDiscretizer
enc = KBinsDiscretizer(n_bins=2, encode="ordinal", strategy='kmeans')
Y_binned = enc.fit_transform(yee.reshape(-1, 1))

clf1 = SkopeRules(
    max_depth_duplication=3, max_depth=3, max_features=0.5,
    max_samples_features=0.5, random_state=0, n_estimators=20,
    feature_names=Xe.columns, recall_min=0.04, precision_min=0.6)

clf1.fit(samp, Y_binned)

p = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
clf_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(p, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (clf_count_within_bounds / len(p)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

print(len(clf1.rules_))
print(clf1.rules_)
# Out:
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning:A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Percentage of predictions within bounds: 0.972%
# 19
# [('categorical_conv3depth_8 <= 1.009646713733673 and categorical_optimizer_adam <= 0.5000374629162252 and categorical_version_v1 <= 1.0092248320579529', (0.9866666666666667, 0.8794567062818336, 2)), ('categorical_optimizer_adam <= 0.500089259352535 and categorical_conv4depth_36 <= 0.9917858242988586', (1.0, 0.6488294314381271, 2)), ('categorical_pooling_avg <= 0.9902397990226746 and categorical_optimizer_adam <= 0.500089259352535', (1.0, 0.5, 2)), ('categorical_optimizer_sgd > 0.9900659322738647 and categorical_conv4depth_6 > -0.009492157492786646 and categorical_conv4depth_23 > -0.009982461109757423', (0.9885496183206107, 0.4397283531409168, 2)), ('categorical_optimizer_rmsprop <= 0.009539392776787281 and categorical_optimizer_sgd > 0.009854401927441359 and categorical_conv4depth_23 > -0.009982461109757423', (0.9847328244274809, 0.431438127090301, 2)), ('categorical_optimizer_rmsprop > 0.9931654334068298 and categorical_optimizer_sgd <= 0.9901181757450104', (0.9956140350877193, 0.3853989813242784, 2)), ('categorical_conv3depth_8 <= 1.0087355375289917 and categorical_optimizer_rmsprop > 0.009539392776787281 and categorical_conv4depth_36 <= 0.9954506456851959', (0.9954954954954955, 0.3733108108108108, 2)), ('categorical_optimizer_sgd <= 0.9901181757450104 and categorical_conv4depth_36 <= 0.5001236787065864 and categorical_version_next <= 0.9933600127696991', (0.869198312236287, 0.346218487394958, 2)), ('categorical_version_v2 <= 0.9921869933605194 and categorical_conv4depth_23 <= 0.9900875389575958 and categorical_version_next <= 1.0082955360412598', (0.6135770234986945, 0.40308747855917665, 2)), ('categorical_optimizer_adam <= 0.4999525551684201 and categorical_optimizer_sgd <= 0.009697187691926956 and categorical_conv4depth_36 <= 0.9914449751377106', (1.0, 0.31534569983136596, 2)), ('categorical_optimizer_adam <= 0.500089259352535 and categorical_conv4depth_23 > -0.009982461109757423 and categorical_conv4depth_36 > 0.9917858242988586', (0.954248366013072, 0.24414715719063546, 2)), ('categorical_pooling_max > 0.006183952791616321 and categorical_optimizer_adam <= 0.5000374629162252 and categorical_conv4depth_36 > 0.9901913404464722', (1.0, 0.19561551433389546, 2)), ('categorical_version_v2 > 0.009857486002147198 and categorical_optimizer_rmsprop <= 0.009539392776787281 and categorical_conv4depth_36 <= 0.9901913404464722', (0.9217391304347826, 0.17905405405405406, 2)), ('categorical_conv3depth_8 <= 1.0087034702301025 and categorical_optimizer_rmsprop > 0.009539392776787281 and categorical_conv4depth_36 > 0.9914449751377106', (0.9436619718309859, 0.11375212224108659, 2)), ('categorical_pooling_max <= 0.006183952791616321 and categorical_optimizer_adam <= 0.5000374629162252 and categorical_conv4depth_36 > 0.9901913404464722', (0.8333333333333334, 0.08431703204047218, 2)), ('categorical_optimizer_adam > 0.5000374629162252 and categorical_optimizer_rmsprop <= 0.007357382215559483 and categorical_conv4depth_23 > 0.9903590083122253', (0.6338028169014085, 0.07563025210084033, 2)), ('categorical_optimizer_rmsprop <= 0.9931654334068298 and categorical_optimizer_rmsprop > 0.4999162908643484 and categorical_optimizer_sgd <= 0.9901181757450104', (0.9090909090909091, 0.06791171477079797, 2)), ('learning_rate <= 0.006713066482916474 and categorical_optimizer_adam > 0.49995863856747746 and categorical_conv4depth_36 <= 0.9901913404464722', (0.7090909090909091, 0.0657672849915683, 2)), ('categorical_optimizer_adam > 0.9913201034069061 and categorical_conv4depth_23 > 0.9900875389575958 and categorical_version_next <= 0.009004194289445877', (0.8571428571428571, 0.051457975986277875, 2))]
