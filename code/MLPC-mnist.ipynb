# %%
import pandas as pd

import numpy as np
import six
import sys
sys.modules['sklearn.externals.six'] = six
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import _tree
from skopt.space import Real, Categorical, Integer

import random
random.seed(42)

# %%
def _sample_search_space(param_space, categorical_columns, num_samples = 1000):
    """
        Uniformly sample the search space for generating explanation dataset. Maintains the original order of search space.
        Sensitive to order: place categoricals first and everything else later.

        Args:
        - param_space (param space): parameter space
        - categorical_columns (list): list of categorical variables
        - num_samples (int): number of generated samples

        Returns:
        - new_data (numpy array): the augmented dataset
        """
    samples = []
    
    for _ in range(num_samples):
        sample = [param.rvs() for param in param_space]
        samples.append(sample)
    
    # Create a DataFrame with the samples
    param_names = [param.name for param in param_space]
    df = pd.DataFrame(samples, columns=param_names)
    
    # One-hot encode categorical variables and add dynamic prefixes
    encoded_columns = []
    for col in categorical_columns:
        prefix = f'categorical_{col}'
        encoded = pd.get_dummies(df[col], prefix=prefix).astype(float)
        encoded_columns.extend(encoded.columns)
        df = pd.concat([df.drop(col, axis=1), encoded], axis=1)
    
    # Rearrange columns: categorical columns in front, followed by non-categorical columns
    ordered_columns = []
    for col in param_space:
        if col.name in categorical_columns:
            ordered_columns.extend([col_name for col_name in df.columns if col_name.startswith(f'categorical_{col.name}')])
        elif col.name in df.columns:
            ordered_columns.append(col.name)
    
    # Now you have the DataFrame with categorical variables in the front and non-categorical variables in their original order
    df = df[ordered_columns]
    
    # Convert numerical variables from lists to floats
    for col in param_names:
        if col not in categorical_columns:
            df[col] = df[col]
    df = df.to_numpy().astype(np.float32)
    return df

# %%
df = pd.read_csv('mnist_MLPC.csv', index_col=0)
ye = df['0']
ye = (ye - np.min(ye)) / (np.max(ye) - np.min(ye))
y = ye.to_numpy()

Xe = df.drop(columns='0')
dum1 = pd.get_dummies(Xe['optimizer'],prefix = 'categorical_optimizer')
dum2 = pd.get_dummies(Xe['activation'],prefix = 'categorical_activation')
dum3 = pd.get_dummies(Xe['batch_size'],prefix = 'categorical_batchsize')
Xe = Xe.drop(columns = ['optimizer','activation','batch_size'])
Xe = pd.concat([dum1, dum2, dum3, Xe], axis=1)


param_space = [
    Categorical(categories=['adam', 'rmsprop', 'sgd'], name='optimizer'),
    Categorical(categories=['relu', 'tanh'], name='activation'),
    Categorical(categories=[16, 32, 64], name='batch_size'),
    Integer(low=20, high=50, name='epochs'),
    Integer(low=10, high=100, name='neurons'),
    Integer(low=3, high=20, name='patience')
]

# Define the categorical columns
categorical_columns = ['optimizer', 'activation', 'batch_size']


print (Xe.iloc[np.argmin(ye.values)])
print (np.max(ye.values))
# Out:
# categorical_optimizer_adam        0
# categorical_optimizer_rmsprop     0
# categorical_optimizer_sgd         1
# categorical_activation_relu       0
# categorical_activation_tanh       1
# categorical_batchsize_16          0
# categorical_batchsize_32          0
# categorical_batchsize_64          1
# epochs                           24
# neurons                          14
# patience                          8
# Name: 5, dtype: int64
# 1.0

# %%
import GPy

def _train_gp(x_train, y_train):
    """
        Train a GPR model from Gpy library.

        Args:
        - X_train (numpy array): input data
        - Y_train (numpy array): ground truth data
        - n_samples (int): number of times to sample the posterior of the trained gp
        - sample_points (numpy array): new input X locations where the posterior would be sampled

        Returns:
        - model (trained gp model): trained gp model
        - mean_y (numpy array): mean of the Y from the sampled posterior
        - std_y (numpy array): std dev of the Y from the sampled posterior
        - sum_log_likelihoods (numpy array): returns the likelihood of observing
          each input point given the trained model
    """
    kernel = GPy.kern.RBF(input_dim=x_train.shape[1])
    model = GPy.models.GPRegression(x_train, y_train, kernel)
    model.optimize()
    return model

def augment_with_noise(data, n_samples=1000):
    """
    Add noise to the input data to create new points and generate a new dataset
    with the desired number of samples.

    Args:
    - data (numpy array): the input data
    - num_samples (int): the number of samples to generate
    - noise_factor (float): the magnitude of the noise to add to the data (default: 0.01)

    Returns:
    - new_data (numpy array): the augmented dataset
    """
    n_points, n_dims = data.shape
    new_data = np.empty((n_samples, n_dims))  # Create a new array for the augmented data

    for i in range(n_samples):
        noise = np.random.uniform(low=-0.001, high=0.001, size=n_dims)
        new_data[i] = data[np.random.randint(n_points)] + noise

    return new_data
    
model = _train_gp(Xe.to_numpy(), y.reshape(-1, 1))
test_set = _sample_search_space(param_space, categorical_columns, num_samples = 100)
test_set = augment_with_noise(test_set)
mean_y, var_y = model.predict_noiseless(test_set, full_cov=False)
flattened_mean = [item for sublist in mean_y for item in sublist]
flattened_var = [item for sublist in var_y for item in sublist]
std = np.sqrt(flattened_var)

samp = _sample_search_space(param_space, categorical_columns, num_samples = 1000)
samp = augment_with_noise(samp)
yee, var = model.predict_noiseless(samp, full_cov=False)
yee = np.squeeze(yee, axis=1)

# %%
from rulekit import RuleKit
from rulekit.regression import RuleRegressor
from rulekit.params import Measures
RuleKit.init()

reg = RuleRegressor(
    induction_measure=Measures.C2,
    pruning_measure=Measures.C2,
    voting_measure=Measures.C2,
)
reg.fit(samp, yee)
predictions = reg.predict(test_set)
ru = []
for rule in reg.model.rules:
    ru.append(str(rule))
    print (rule)

print(len(ru))

from itertools import combinations

# Given rule list in the new representation
rule_list = ru

# Function to extract features from a rule
def extract_features(rule):
    # Extract only the part before "THEN" and split by "AND"
    features = set(rule.split('IF')[1].split(" THEN")[0].split(" AND"))
    return features

# Function to calculate Jaccard similarity between two rules
def jaccard_similarity(rule1, rule2):
    features1 = extract_features(rule1)
  
    features2 = extract_features(rule2)
   
    intersection = len(features1.intersection(features2))
    union = len(features1.union(features2))
    
    if union == 0:
        return 0.0  # Handle the case where both sets are empty
    else:
        return intersection / union

# Calculate Jaccard similarity between all pairs of rules and collect them
similarities = []
for rule1, rule2 in combinations(rule_list, 2):
    similarity = jaccard_similarity(rule1, rule2)
    similarities.append(similarity)

# Calculate the mean Jaccard similarity for the entire rule set
mean_similarity = sum(similarities) / len(similarities)

print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

## Define your bounds




lower_bounds = [flattened_mean[i] -  0.000000005  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] +  0.000000005  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(predictions, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (count_within_bounds / len(predictions)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")
# Out:
# IF att8 = <9.8E-4, inf) AND att11 = (-inf, 3.00) AND att10 = <49.50, inf) AND att1 = <2.8E-4, inf) THEN label = {8.8E-26} [5.5E-26,1.2E-25]
# IF att9 = <45.50, inf) AND att6 = <-3.9E-4, inf) AND att8 = <9.8E-4, inf) AND att11 = <9.00, inf) AND att10 = <49.50, inf) AND att1 = <4.8E-4, inf) THEN label = {2.3E-43} [1.3E-43,3.2E-43]
# IF att10 = <59.00, 73.50) THEN label = {1.6E-55} [-2.1E-10,2.1E-10]
# IF att6 = <-3.9E-4, 1.00) AND att5 = <-9.7E-4, inf) AND att7 = <-6.1E-4, inf) AND att10 = <49.50, inf) AND att1 = <1.00, inf) AND att4 = <-7.7E-4, inf) THEN label = {5.0E-36} [-3.4E-14,3.4E-14]
# IF att8 = <9.8E-4, inf) THEN label = {2.2E-33} [-2.7E-4,2.7E-4]
# IF att9 = <29.50, inf) AND att5 = <-8.8E-4, inf) AND att8 = (-inf, 6.8E-4) AND att11 = (-inf, 4.00) AND att1 = <5.7E-4, 1.00) THEN label = {3.4E-46} [-2.0E-30,2.0E-30]
# IF att8 = (-inf, 0.50) AND att11 = (-inf, 6.00) AND att1 = <8.6E-4, inf) AND att10 = (-inf, 25.50) AND att3 = <-8.9E-4, inf) THEN label = {7.6E-11} [3.9E-11,1.1E-10]
# IF att6 = (-inf, -2.3E-4) AND att8 = (-inf, 9.4E-4) AND att2 = (-inf, 9.3E-4) AND att11 = (-inf, 6.00) AND att10 = <19.00, 67.00) AND att1 = <-1.6E-4, 1.00) AND att3 = <-8.9E-4, inf) THEN label = {2.1E-10} [1.3E-10,2.8E-10]
# IF att9 = <34.00, inf) AND att6 = <-8.9E-4, inf) AND att8 = (-inf, 9.4E-4) AND att11 = (-inf, 6.00) AND att10 = <25.50, inf) AND att1 = <9.4E-4, inf) THEN label = {9.9E-35} [-7.2E-14,7.2E-14]
# IF att9 = (-inf, 29.50) AND att8 = (-inf, 9.4E-4) AND att7 = <-7.1E-6, inf) AND att2 = (-inf, 7.8E-4) AND att11 = (-inf, 5.00) AND att1 = <-1.9E-4, 8.3E-4) THEN label = {3.5E-15} [2.2E-15,4.8E-15]
# IF att5 = <5.7E-4, inf) AND att8 = (-inf, 9.0E-4) AND att11 = (-inf, 6.00) AND att2 = <-9.8E-4, 7.6E-4) AND att10 = (-inf, 89.50) AND att4 = (-inf, 1.00) AND att3 = <1.00, inf) THEN label = {1.0E-59} [-9.1E-36,9.1E-36]
# IF att9 = <41.00, inf) AND att6 = <1.00, inf) AND att11 = (-inf, 6.00) AND att1 = (-inf, 4.8E-4) AND att3 = <1.00, inf) THEN label = {8.8E-28} [5.3E-28,1.2E-27]
# IF att9 = (-inf, 36.00) AND att8 = (-inf, 9.5E-4) AND att7 = (-inf, 1.00) AND att11 = (-inf, 6.00) AND att10 = <55.50, 96.00) THEN label = {4.5E-47} [-3.8E-32,3.8E-32]
# IF att8 = <-9.0E-4, inf) AND att11 = (-inf, 4.00) AND att2 = <-2.5E-4, inf) AND att1 = (-inf, 3.7E-4) AND att4 = (-inf, 1.00) THEN label = {4.5E-47} [-1.1E-15,1.1E-15]
# IF att7 = (-inf, 1.00) AND att11 = (-inf, 6.00) AND att1 = <-4.8E-4, inf) THEN label = {2.2E-35} [-3.4E-8,3.4E-8]
# IF att5 = <-6.9E-5, inf) AND att7 = <1.00, inf) AND att11 = (-inf, 6.00) AND att2 = <-6.3E-4, inf) AND att10 = <49.50, inf) AND att1 = (-inf, 8.5E-4) THEN label = {2.3E-48} [-8.8E-24,8.8E-24]
# IF att9 = <27.50, inf) AND att2 = <-6.7E-4, 1.00) AND att1 = <-8.9E-4, -5.2E-4) AND att4 = <-6.3E-4, 1.00) THEN label = {5.4E-34} [-2.1E-8,2.1E-8]
# IF att6 = (-inf, 0.50) AND att5 = (-inf, -3.9E-6) AND att7 = <-5.8E-4, inf) AND att2 = (-inf, 1.00) AND att10 = <50.00, inf) AND att3 = <-6.5E-4, 1.00) THEN label = {4.9E-39} [-6.7E-10,6.7E-10]
# IF att7 = <1.00, inf) AND att11 = (-inf, 6.00) AND att2 = <0.50, inf) AND att1 = <-6.6E-4, inf) AND att4 = <-1.6E-4, inf) AND att3 = <-9.0E-4, inf) THEN label = {2.3E-7} [1.3E-7,3.3E-7]
# IF att11 = <5.50, 7.00) AND att2 = <-2.6E-5, inf) AND att1 = <-4.1E-4, 4.7E-4) AND att4 = <-4.1E-4, inf) AND att3 = <-1.9E-4, inf) THEN label = {1.5E-37} [-1.9E-29,1.9E-29]
# IF att6 = <-4.0E-4, inf) AND att11 = <5.00, 7.00) AND att1 = <-2.2E-5, inf) AND att4 = (-inf, 1.00) THEN label = {1.5E-37} [-5.8E-15,5.8E-15]
# IF att6 = (-inf, 0.50) AND att5 = (-inf, 4.4E-4) AND att7 = <-7.5E-4, 1.00) AND att11 = (-inf, 7.00) AND att2 = <-6.7E-4, inf) AND att4 = <1.00, 1.00) AND att3 = <7.1E-5, 1.00) THEN label = {6.1E-38} [-9.6E-14,9.6E-14]
# IF att11 = (-inf, 7.00) THEN label = {3.7E-35} [-1.9E-4,1.9E-4]
# IF att6 = <-8.9E-4, inf) AND att2 = <-5.9E-4, 1.00) AND att1 = (-inf, 1.00) AND att4 = (-inf, 1.00) THEN label = {4.9E-33} [-7.6E-4,7.6E-4]
# IF att9 = (-inf, 43.00) AND att6 = (-inf, 1.00) AND att5 = <-7.8E-4, inf) AND att8 = <-9.0E-4, 9.0E-4) AND att7 = <-4.4E-4, inf) AND att11 = <5.00, inf) AND att10 = (-inf, 77.00) AND att1 = <-2.4E-4, 2.1E-4) THEN label = {7.0E-52} [-4.0E-23,4.0E-23]
# IF att8 = (-inf, 9.8E-4) AND att10 = <49.50, 74.00) THEN label = {1.6E-55} [-1.2E-7,1.2E-7]
# IF att5 = <-7.0E-4, inf) AND att8 = <-8.9E-4, 1.00) AND att1 = (-inf, -1.0E-4) AND att10 = (-inf, 74.00) THEN label = {1.3E-35} [-8.2E-6,8.2E-6]
# IF att6 = (-inf, 0.50) AND att5 = <-6.9E-4, inf) AND att8 = <-6.3E-4, 4.6E-4) AND att7 = (-inf, 1.00) AND att2 = <-5.4E-4, 1.00) AND att1 = (-inf, 2.3E-4) AND att3 = <-4.1E-4, inf) THEN label = {2.7E-34} [-4.7E-12,4.7E-12]
# IF att9 = (-inf, 44.50) AND att5 = <-5.6E-4, inf) AND att8 = (-inf, 8.5E-4) AND att7 = <-1.7E-4, inf) AND att1 = (-inf, 2.3E-4) AND att10 = <27.00, inf) AND att4 = <-2.3E-4, inf) AND att3 = <-4.6E-4, inf) THEN label = {5.3E-33} [-2.4E-6,2.4E-6]
# IF att6 = <6.3E-4, inf) AND att5 = <-3.9E-4, inf) AND att4 = (-inf, 1.00) THEN label = {2.6E-32} [-2.3E-4,2.3E-4]
# IF att9 = (-inf, 48.50) AND att6 = (-inf, 1.00) AND att5 = <-9.6E-4, 4.7E-4) AND att8 = (-inf, 1.00) AND att7 = <4.5E-4, inf) AND att2 = <-7.7E-4, inf) AND att1 = <-8.1E-4, 1.6E-4) AND att10 = <20.50, inf) AND att4 = <1.00, inf) AND att3 = <-8.0E-4, 1.00) THEN label = {2.7E-34} [-0.003,0.003]
# IF att9 = <25.00, inf) AND att6 = <-8.7E-4, 1.00) AND att8 = <-7.6E-4, 1.00) AND att1 = <7.0E-4, inf) AND att4 = <-5.8E-5, 1.00) AND att3 = <-5.5E-4, inf) THEN label = {2.5E-35} [-7.9E-10,7.9E-10]
# IF att9 = (-inf, 45.00) AND att5 = <1.00, 1.00) AND att8 = (-inf, 2.3E-4) AND att7 = (-inf, 1.00) AND att1 = <6.1E-5, inf) AND att4 = (-inf, 7.0E-4) AND att3 = (-inf, 1.00) THEN label = {7.3E-34} [-4.5E-15,4.5E-15]
# IF att6 = (-inf, 6.0E-4) AND att7 = (-inf, 1.00) AND att2 = <-9.5E-4, inf) AND att1 = <3.7E-4, 1.00) AND att4 = <-8.8E-4, 6.5E-4) AND att3 = <-6.9E-4, 1.00) THEN label = {6.9E-33} [-5.6E-5,5.6E-5]
# IF att2 = <-7.9E-4, inf) AND att1 = <5.9E-4, inf) AND att4 = <1.00, inf) AND att3 = <-7.7E-4, 4.4E-5) THEN label = {7.9E-29} [-6.8E-11,6.8E-11]
# IF att9 = <30.50, inf) AND att7 = <-5.4E-4, 5.3E-4) AND att4 = <1.00, inf) AND att3 = <-1.2E-4, 1.00) THEN label = {8.7E-26} [-2.4E-14,2.4E-14]
# IF att6 = (-inf, 1.00) AND att5 = (-inf, 1.00) AND att7 = <-8.0E-4, inf) AND att2 = <-9.9E-4, 9.8E-4) AND att1 = <4.6E-4, 1.00) AND att4 = <-9.5E-4, 7.5E-4) AND att3 = (-inf, 1.00) THEN label = {5.0E-36} [-5.6E-5,5.6E-5]
# IF att9 = (-inf, 40.50) AND att7 = <1.00, inf) AND att1 = <8.4E-6, 7.5E-4) THEN label = {6.6E-30} [-6.8E-13,6.8E-13]
# IF att7 = <1.00, inf) AND att1 = <-4.0E-4, inf) AND att3 = (-inf, 9.3E-4) THEN label = {2.4E-27} [-3.6E-6,3.6E-6]
# IF att5 = <-8.3E-4, inf) AND att3 = <7.0E-4, 1.00) THEN label = {9.8E-35} [-9.4E-4,9.4E-4]
# IF att2 = <3.5E-4, inf) AND att1 = <3.3E-4, inf) AND att4 = (-inf, 1.00) THEN label = {2.7E-34} [-6.9E-4,6.9E-4]
# IF att5 = <-7.2E-4, inf) AND att8 = (-inf, 8.5E-4) AND att7 = <-7.2E-4, 1.00) THEN label = {1.5E-30} [-0.0034,0.0034]
# 42
# Mean Jaccard Similarity for the Rule Set: 0.01
# Percentage of predictions within bounds: 0.917%

# %%
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(predictions, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (count_within_bounds / len(predictions)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")
# Out:
# Percentage of predictions within bounds: 0.01%

# %%
clf = DecisionTreeRegressor(random_state=0)
clf.fit(samp, yee)
pred = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
pr_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(pred, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (pr_count_within_bounds / len(pred)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")


def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "
        if class_names is None:
            rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules
rules = get_rules(clf, Xe.columns, None)
for r in rules:
    print(r)
len(rules)
# Out:
# Percentage of predictions within bounds: 0.02%
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons > 18.5) then response: 0.0 | based on 315 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs > 22.001) and (epochs > 23.5) then response: 0.0 | based on 96 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh <= 1.001) and (neurons > 15.5) and (neurons > 16.0) then response: 0.0 | based on 93 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu <= 1.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.001) then response: 0.0 | based on 79 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd > 1.0) and (neurons > 20.5) and (categorical_batchsize_32 > -0.001) then response: 0.0 | based on 63 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh <= 1.001) and (epochs <= 41.501) then response: 0.0 | based on 44 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu > 0.0) and (epochs <= 43.5) then response: 0.0 | based on 35 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience <= 14.5) and (categorical_activation_relu <= 1.0) and (epochs <= 49.501) then response: 0.0 | based on 23 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs > 27.501) then response: 0.0 | based on 21 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 > 1.001) and (categorical_batchsize_64 > 1.001) then response: 0.0 | based on 15 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 <= 0.5) then response: 0.0 | based on 12 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons <= 91.001) and (epochs > 27.0) then response: 0.0 | based on 8 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh <= 1.001) and (epochs > 41.501) and (epochs > 44.0) then response: 0.0 | based on 8 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons <= 14.5) and (categorical_activation_relu > 0.0) then response: 0.0 | based on 8 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience > 5.999) and (categorical_optimizer_rmsprop <= 1.0) and (categorical_optimizer_sgd > -0.001) then response: 0.0 | based on 8 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu > 1.001) and (categorical_activation_relu > 1.001) then response: 0.0 | based on 7 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience > 19.0) and (categorical_optimizer_sgd <= 0.999) then response: 0.0 | based on 7 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu > 1.0) and (patience <= 5.5) then response: 0.0 | based on 7 samples
# if (neurons <= 90.001) and (neurons <= 10.5) and (categorical_batchsize_16 <= 0.5) and (epochs > 28.0) then response: 0.0 | based on 5 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu <= 0.0) and (categorical_activation_relu <= 0.0) and (epochs <= 41.0) then response: 0.0 | based on 5 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons <= 90.999) and (categorical_activation_tanh <= 1.0) and (epochs > 30.499) then response: 0.0 | based on 5 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu <= 1.0) and (categorical_activation_relu <= -0.001) and (categorical_optimizer_adam > -0.0) then response: 0.0 | based on 5 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs <= 22.001) and (epochs <= 21.999) and (categorical_activation_tanh > 0.5) then response: 0.0 | based on 4 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh > 1.001) and (categorical_activation_tanh > 1.001) then response: 0.0 | based on 4 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd > 1.0) and (neurons <= 20.5) and (neurons <= 20.0) and (epochs > 23.5) then response: 0.0 | based on 4 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh > 1.001) and (patience <= 13.5) and (categorical_activation_tanh > 1.001) then response: 0.0 | based on 3 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd > 1.001) and (categorical_batchsize_16 > -0.001) then response: 0.0 | based on 3 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.0) and (categorical_activation_tanh > -0.0) and (categorical_optimizer_rmsprop <= 1.0) and (categorical_optimizer_rmsprop <= 0.5) and (categorical_activation_relu > 0.001) then response: 0.0 | based on 3 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs <= 22.001) and (epochs > 21.999) and (categorical_batchsize_32 <= 0.0) and (categorical_batchsize_32 <= -0.001) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu <= 0.0) and (categorical_activation_relu <= 0.0) and (epochs > 41.0) and (categorical_activation_tanh > 1.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu > 0.0) and (epochs > 43.5) and (neurons <= 77.5) then response: 0.0 | based on 2 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs <= 22.001) and (epochs > 21.999) and (categorical_batchsize_32 <= 0.0) and (categorical_batchsize_32 > -0.001) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd > 1.0) and (neurons <= 20.5) and (neurons <= 20.0) and (epochs <= 23.5) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam > 1.001) and (categorical_optimizer_sgd > -0.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 > 1.0) and (epochs > 25.499) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 > 0.5) and (categorical_batchsize_64 <= 1.0) and (neurons <= 15.5) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience > 5.999) and (categorical_optimizer_rmsprop <= 1.0) and (categorical_optimizer_sgd <= -0.001) then response: 0.0 | based on 2 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs > 22.001) and (epochs <= 23.5) and (categorical_batchsize_32 > -0.001) and (categorical_batchsize_32 <= 0.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh <= 1.001) and (neurons <= 15.5) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons <= 15.0) and (epochs > 42.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons <= 10.5) and (categorical_batchsize_16 <= 0.5) and (epochs <= 28.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.0) and (categorical_activation_tanh > -0.0) and (categorical_optimizer_rmsprop <= 1.0) and (categorical_optimizer_rmsprop <= 0.5) and (categorical_activation_relu <= 0.001) then response: 0.0 | based on 2 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs <= 22.001) and (epochs <= 21.999) and (categorical_activation_tanh <= 0.5) then response: 0.0 | based on 2 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 <= -0.001) and (patience <= 16.501) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs <= 27.501) and (epochs <= 23.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh <= 1.001) and (epochs > 41.501) and (epochs <= 44.0) then response: 0.0 | based on 2 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 > -0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh <= 1.001) and (neurons > 15.5) and (neurons <= 16.0) and (categorical_optimizer_rmsprop > -0.0) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons <= 91.001) and (epochs <= 27.0) and (patience <= 16.0) then response: 0.024 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh > 1.001) and (categorical_activation_tanh <= 1.001) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons <= 90.999) and (categorical_activation_tanh > 1.0) then response: 0.067 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd > 1.001) and (categorical_batchsize_16 <= -0.001) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons <= 90.999) and (categorical_activation_tanh <= 1.0) and (epochs <= 30.499) then response: 0.024 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu <= -0.001) and (neurons > 81.0) and (categorical_activation_tanh > 1.0) and (categorical_activation_relu <= -0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu <= 1.0) and (categorical_activation_relu <= -0.001) and (categorical_optimizer_adam <= -0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd > -0.001) and (categorical_activation_tanh <= 1.001) and (neurons > 15.5) and (neurons <= 16.0) and (categorical_optimizer_rmsprop <= -0.0) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs > 22.001) and (epochs <= 23.5) and (categorical_batchsize_32 <= -0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu <= 1.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs <= 27.501) and (epochs > 23.0) and (categorical_optimizer_sgd > 0.0) then response: 0.003 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience <= 5.999) and (categorical_activation_relu > 1.0) and (patience > 5.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs <= 27.501) and (epochs > 23.0) and (categorical_optimizer_sgd <= 0.0) and (categorical_optimizer_sgd > -0.0) then response: 0.003 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs <= 27.501) and (epochs > 23.0) and (categorical_optimizer_sgd <= 0.0) and (categorical_optimizer_sgd <= -0.0) and (categorical_batchsize_32 > 0.0) then response: 0.003 | based on 1 samples
# if (neurons > 90.001) and (neurons <= 90.001) then response: 0.067 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 <= -0.001) and (categorical_batchsize_16 <= -0.001) and (categorical_optimizer_sgd <= 1.001) and (categorical_optimizer_sgd <= -0.001) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons <= 91.001) and (epochs <= 27.0) and (patience > 16.0) then response: 0.025 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd <= -0.001) and (categorical_optimizer_adam <= 0.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons <= 10.5) and (categorical_batchsize_16 > 0.5) and (categorical_activation_tanh <= -0.0) and (epochs <= 44.001) then response: 0.009 | based on 1 samples
# if (neurons <= 90.001) and (neurons <= 10.5) and (categorical_batchsize_16 > 0.5) and (categorical_activation_tanh <= -0.0) and (epochs > 44.001) then response: 0.009 | based on 1 samples
# if (neurons <= 90.001) and (neurons <= 10.5) and (categorical_batchsize_16 > 0.5) and (categorical_activation_tanh > -0.0) then response: 0.009 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 <= -0.001) and (patience > 16.501) then response: 0.005 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience <= 14.5) and (categorical_activation_relu <= 1.0) and (epochs > 49.501) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience <= 14.5) and (categorical_activation_relu > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience > 14.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 <= 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience > 14.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu <= 1.001) and (patience > 14.5) and (categorical_batchsize_64 > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu > 1.001) and (categorical_optimizer_adam <= -0.0) then response: 0.003 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd <= 1.001) and (categorical_activation_relu > 1.001) and (categorical_optimizer_adam > -0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience <= 18.0) and (categorical_optimizer_sgd > 1.001) then response: 0.003 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons <= 13.999) and (patience > 18.0) then response: 0.011 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons <= 14.5) and (categorical_activation_relu <= 0.0) and (categorical_batchsize_32 <= 0.0) then response: 0.001 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons <= 14.5) and (categorical_activation_relu <= 0.0) and (categorical_batchsize_32 > 0.0) then response: 0.001 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience <= 6.0) and (patience > 5.999) and (categorical_optimizer_rmsprop > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons <= 15.0) and (epochs <= 42.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd <= -0.001) and (categorical_optimizer_adam > 0.5) then response: 0.0 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs > 22.001) and (epochs <= 23.5) and (categorical_batchsize_32 > -0.001) and (categorical_batchsize_32 > 0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons <= 75.999) and (categorical_optimizer_rmsprop <= 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons <= 75.999) and (categorical_optimizer_rmsprop > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience > 18.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu <= 0.0) and (categorical_activation_relu <= 0.0) and (epochs > 41.0) and (categorical_activation_tanh <= 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh > 1.001) and (patience > 13.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu <= 0.0) and (categorical_activation_relu > 0.0) and (epochs <= 41.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu <= 0.0) and (categorical_activation_relu > 0.0) and (epochs > 41.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience <= 19.0) and (patience <= 18.5) and (categorical_activation_tanh > 1.001) and (patience <= 13.5) and (categorical_activation_tanh <= 1.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh <= 1.001) and (categorical_activation_relu > 0.0) and (epochs > 43.5) and (neurons > 77.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh > 1.001) and (categorical_batchsize_64 <= 0.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons > 75.999) and (neurons > 75.999) and (categorical_activation_tanh > 1.001) and (categorical_batchsize_64 > 0.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu > 1.001) and (categorical_activation_relu <= 1.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu <= -0.001) and (neurons > 81.0) and (categorical_activation_tanh > 1.0) and (categorical_activation_relu > -0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons <= 80.0) then response: 0.001 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu <= -0.001) and (neurons <= 81.0) then response: 0.001 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons > 75.999) and (neurons <= 75.999) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd > 1.0) and (neurons > 20.5) and (categorical_batchsize_32 <= -0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu <= -0.001) and (neurons > 81.0) and (categorical_activation_tanh <= 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 <= 1.0) and (patience > 19.0) and (categorical_optimizer_sgd > 0.999) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons > 88.999) and (epochs <= 27.501) and (epochs > 23.0) and (categorical_optimizer_sgd <= 0.0) and (categorical_optimizer_sgd <= -0.0) and (categorical_batchsize_32 <= 0.0) then response: 0.003 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop > 1.001) and (categorical_optimizer_adam > -0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 > 0.5) and (categorical_batchsize_64 <= 1.0) and (neurons > 15.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 <= 1.0) and (categorical_batchsize_64 > 0.5) and (categorical_batchsize_64 > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 <= 1.001) and (neurons > 15.0) and (neurons <= 18.5) and (categorical_batchsize_64 > 1.0) and (epochs <= 25.499) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop > 1.001) and (categorical_optimizer_adam <= -0.0) then response: 0.002 | based on 1 samples
# if (neurons > 90.001) and (neurons > 90.001) and (neurons > 90.999) and (neurons > 91.001) and (categorical_batchsize_64 > -0.001) and (epochs <= 22.001) and (epochs > 21.999) and (categorical_batchsize_32 > 0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons <= 75.0) and (categorical_optimizer_sgd > -0.001) and (categorical_batchsize_64 > 1.001) and (categorical_batchsize_64 <= 1.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.0) and (categorical_activation_tanh > -0.0) and (categorical_optimizer_rmsprop > 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons > 75.0) and (categorical_activation_tanh <= 0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam <= 1.001) and (neurons > 75.0) and (categorical_activation_tanh > 0.001) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd <= 1.0) and (categorical_optimizer_adam > 1.001) and (categorical_optimizer_sgd <= -0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.0) and (categorical_activation_tanh > -0.0) and (categorical_optimizer_rmsprop <= 1.0) and (categorical_optimizer_rmsprop > 0.5) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd <= 1.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons > 79.999) and (neurons > 80.0) and (categorical_activation_relu > -0.001) and (categorical_batchsize_32 > 1.0) and (categorical_activation_tanh <= -0.0) then response: 0.0 | based on 1 samples
# if (neurons <= 90.001) and (neurons > 10.5) and (neurons > 13.999) and (neurons <= 88.999) and (categorical_optimizer_rmsprop <= 1.001) and (neurons > 14.5) and (neurons <= 79.999) and (categorical_activation_relu <= 1.001) and (neurons <= 75.999) and (categorical_batchsize_16 > -0.001) and (patience > 6.0) and (categorical_optimizer_sgd > 1.0) and (categorical_optimizer_sgd > 1.0) and (neurons <= 20.5) and (neurons > 20.0) then response: 0.0 | based on 1 samples
# 120

# %%
from skrules import SkopeRules
from sklearn.preprocessing import KBinsDiscretizer
yee = yee/np.max(yee)

# transform the dataset with KBinsDiscretizer
enc = KBinsDiscretizer(n_bins=2, encode="ordinal", strategy='kmeans')
Y_binned = enc.fit_transform(yee.reshape(-1, 1))

clf1 = SkopeRules(
    max_depth_duplication=3, max_depth=3, max_features=0.5,
    max_samples_features=0.5, random_state=0, n_estimators=20,
    feature_names=Xe.columns, recall_min=0.04, precision_min=0.6)

clf1.fit(samp, Y_binned)

p = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
clf_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(p, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (clf_count_within_bounds / len(p)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

print(len(clf1.rules_))
print(clf1.rules_)
# Out:
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning:A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Percentage of predictions within bounds: 0.02%
# 2
# [('epochs <= 25.999730110168457 and neurons <= 90.50019454956055 and neurons > 90.00040054321289', (1.0, 1.0, 2)), ('categorical_optimizer_adam <= 0.00019527627591742203 and neurons <= 90.50046920776367 and neurons > 90.0005111694336', (1.0, 1.0, 2))]
