# %%
import pandas as pd

import numpy as np
import six
import sys
sys.modules['sklearn.externals.six'] = six
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import _tree
import random

from skopt.space import Real, Categorical, Integer
random.seed(42)

# %%
def _sample_search_space(param_space, categorical_columns, num_samples = 1000):
    """
        Uniformly sample the search space for generating explanation dataset. Maintains the original order of search space.
        Sensitive to order: place categoricals first and everything else later.

        Args:
        - param_space (param space): parameter space
        - categorical_columns (list): list of categorical variables
        - num_samples (int): number of generated samples

        Returns:
        - new_data (numpy array): the augmented dataset
        """
    samples = []
    
    for _ in range(num_samples):
        sample = [param.rvs() for param in param_space]
        samples.append(sample)
    
    # Create a DataFrame with the samples
    param_names = [param.name for param in param_space]
    df = pd.DataFrame(samples, columns=param_names)
    
    # One-hot encode categorical variables and add dynamic prefixes
    encoded_columns = []
    for col in categorical_columns:
        prefix = f'categorical_{col}'
        encoded = pd.get_dummies(df[col], prefix=prefix).astype(float)
        encoded_columns.extend(encoded.columns)
        df = pd.concat([df.drop(col, axis=1), encoded], axis=1)
    
    # Rearrange columns: categorical columns in front, followed by non-categorical columns
    ordered_columns = []
    for col in param_space:
        if col.name in categorical_columns:
            ordered_columns.extend([col_name for col_name in df.columns if col_name.startswith(f'categorical_{col.name}')])
        elif col.name in df.columns:
            ordered_columns.append(col.name)
    
    # Now you have the DataFrame with categorical variables in the front and non-categorical variables in their original order
    df = df[ordered_columns]
    
    # Convert numerical variables from lists to floats
    for col in param_names:
        if col not in categorical_columns:
            df[col] = df[col]
    df = df.to_numpy().astype(np.float32)
    return df

# %%
df = pd.read_csv('cifar10_xception_25.csv')
df = df.drop(columns=['training_epoch_accuracy','training_epoch_loss','validation_epoch_loss','validation_evaluation_accuracy_vs_iterations','validation_evaluation_loss_vs_iterations'])

# %%
ye = df['validation_epoch_accuracy']
y = ye.to_numpy()

Xe = df.drop(columns='validation_epoch_accuracy')
dum1 = pd.get_dummies(Xe['conv2d_num_filters'],prefix = 'categorical_conv2dnumfilters')
dum2 = pd.get_dummies(Xe['activation'],prefix = 'categorical_activation')
dum3 = pd.get_dummies(Xe['pooling'],prefix = 'categorical_pooling')
dum4 = pd.get_dummies(Xe['kernel_size'],prefix = 'categorical_kernelsize')
dum5 = pd.get_dummies(Xe['dense_use_bn'],prefix = 'categorical_denseusebn')
Xe = Xe.drop(columns = ['conv2d_num_filters','activation','pooling','kernel_size','dense_use_bn'])
Xe = pd.concat([dum1, dum2, dum3, dum4, dum5, Xe], axis=1)

param_space = [
    Categorical(categories=['64','32', '128'], name='conv2d_num_filters'),
    Categorical(categories=['relu', 'selu'], name='activation'),
    Categorical(categories=['flatten', 'avg', 'max'], name='pooling'),
    Categorical(categories=['5','3'], name='kernel_size'),
    Categorical(categories=['1', '0'], name='dense_use_bn'),
    Integer(low=128, high=768, name='sep_num_filters'),
    Integer(low=0, high=1, name='dropout_rate'),
    Integer(low=1, high=5, name='num_dense_layers'),
    Integer(low=1, high=8, name='num_residual_blocks'),
    Integer(low=0, high=1, name='learning_rate'),
    Integer(low=2, high=4, name='initial_strides'),
]

# Define the categorical columns
categorical_columns = ['conv2d_num_filters','activation','pooling','kernel_size','dense_use_bn']

print (Xe.iloc[np.argmin(ye.values)])
print (np.max(ye.values))
# Out:
# categorical_conv2dnumfilters_32       1.0000
# categorical_conv2dnumfilters_64       0.0000
# categorical_conv2dnumfilters_128      0.0000
# categorical_activation_relu           1.0000
# categorical_activation_selu           0.0000
# categorical_pooling_avg               0.0000
# categorical_pooling_flatten           1.0000
# categorical_pooling_max               0.0000
# categorical_kernelsize_3              1.0000
# categorical_kernelsize_5              0.0000
# categorical_denseusebn_0              1.0000
# categorical_denseusebn_1              0.0000
# sep_num_filters                     128.0000
# dropout_rate                          0.1000
# num_dense_layers                      3.0000
# num_residual_blocks                   5.0000
# learning_rate                         0.0001
# initial_strides                       2.0000
# Name: 3, dtype: float64
# 0.777999997

# %%
import GPy

def _train_gp(x_train, y_train):
    """
        Train a GPR model from Gpy library.

        Args:
        - X_train (numpy array): input data
        - Y_train (numpy array): ground truth data
        - n_samples (int): number of times to sample the posterior of the trained gp
        - sample_points (numpy array): new input X locations where the posterior would be sampled

        Returns:
        - model (trained gp model): trained gp model
        - mean_y (numpy array): mean of the Y from the sampled posterior
        - std_y (numpy array): std dev of the Y from the sampled posterior
        - sum_log_likelihoods (numpy array): returns the likelihood of observing
          each input point given the trained model
    """
    kernel = GPy.kern.RBF(input_dim=x_train.shape[1])
    model = GPy.models.GPRegression(x_train, y_train, kernel)
    model.optimize()
    return model

def augment_with_noise(data, n_samples=1000):
    """
    Add noise to the input data to create new points and generate a new dataset
    with the desired number of samples.

    Args:
    - data (numpy array): the input data
    - num_samples (int): the number of samples to generate
    - noise_factor (float): the magnitude of the noise to add to the data (default: 0.01)

    Returns:
    - new_data (numpy array): the augmented dataset
    """
    n_points, n_dims = data.shape
    new_data = np.empty((n_samples, n_dims))  # Create a new array for the augmented data

    for i in range(n_samples):
        noise = np.random.uniform(low=-0.01, high=0.01, size=n_dims)
        new_data[i] = data[np.random.randint(n_points)] + noise

    return new_data
    
model = _train_gp(Xe.to_numpy(), y.reshape(-1, 1))
test_set = _sample_search_space(param_space, categorical_columns, num_samples = 100)
test_set = augment_with_noise(test_set)
mean_y, var_y = model.predict_noiseless(test_set, full_cov=False)
flattened_mean = [item for sublist in mean_y for item in sublist]
flattened_var = [item for sublist in var_y for item in sublist]
std = np.sqrt(flattened_var)

samp = _sample_search_space(param_space, categorical_columns, num_samples = 1000)
samp = augment_with_noise(samp)
yee, var = model.predict_noiseless(samp, full_cov=False)
yee = np.squeeze(yee, axis=1)

# %%
from rulekit import RuleKit
from rulekit.regression import RuleRegressor
from rulekit.params import Measures
RuleKit.init()

reg = RuleRegressor(
    induction_measure=Measures.C2,
    pruning_measure=Measures.C2,
    voting_measure=Measures.C2,
)
reg.fit(samp, yee)
predictions = reg.predict(test_set)

ru = []
for rule in reg.model.rules:
    ru.append(str(rule))
    print (rule)

print(len(ru))

from itertools import combinations

# Given rule list in the new representation
rule_list = ru

# Function to extract features from a rule
def extract_features(rule):
    # Extract only the part before "THEN" and split by "AND"
    features = set(rule.split('IF')[1].split(" THEN")[0].split(" AND"))
    return features

# Function to calculate Jaccard similarity between two rules
def jaccard_similarity(rule1, rule2):
    features1 = extract_features(rule1)
  
    features2 = extract_features(rule2)
   
    intersection = len(features1.intersection(features2))
    union = len(features1.union(features2))
    
    if union == 0:
        return 0.0  # Handle the case where both sets are empty
    else:
        return intersection / union

# Calculate Jaccard similarity between all pairs of rules and collect them
similarities = []
for rule1, rule2 in combinations(rule_list, 2):
    similarity = jaccard_similarity(rule1, rule2)
    similarities.append(similarity)

# Calculate the mean Jaccard similarity for the entire rule set
mean_similarity = sum(similarities) / len(similarities)

print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

## Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(predictions, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (count_within_bounds / len(predictions)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")
# Out:
# IF att18 = <2.00, inf) AND att10 = (-inf, 0.0074) AND att13 = (-inf, 138.99) THEN label = {0.29} [0.28,0.31]
# IF att1 = (-inf, 1.00) AND att13 = (-inf, 138.99) AND att4 = <0.99, inf) THEN label = {0.26} [0.24,0.27]
# IF att13 = <761.00, inf) THEN label = {0.69} [0.67,0.71]
# IF att2 = (-inf, 0.99) AND att13 = (-inf, 140.50) AND att3 = <-0.0024, inf) THEN label = {0.26} [0.22,0.30]
# IF att16 = (-inf, 3.01) AND att13 = <664.50, 677.00) AND att3 = <-0.0046, inf) THEN label = {0.036} [0.035,0.037]
# IF att16 = (-inf, 3.01) AND att1 = <6.7E-5, 0.99) AND att13 = <675.00, 722.00) AND att3 = <-0.0081, 1.01) THEN label = {2.4E-4} [-0.0011,0.0016]
# IF att18 = (-inf, 4.01) AND att16 = (-inf, 3.01) AND att7 = <-0.0079, inf) AND att2 = (-inf, 0.50) AND att1 = <-0.0014, inf) AND att13 = <675.00, 728.50) AND att4 = (-inf, 1.01) AND att3 = <-0.0035, 1.01) THEN label = {1.2E-4} [-0.0013,0.0015]
# IF att6 = (-inf, 0.51) AND att16 = (-inf, 3.01) AND att2 = <-0.0055, inf) AND att1 = <-0.0057, inf) AND att13 = <675.00, 729.51) AND att4 = (-inf, 1.01) THEN label = {6.6E-4} [-0.0065,0.0078]
# IF att5 = <0.0069, inf) AND att1 = (-inf, 0.0023) AND att13 = <677.00, inf) THEN label = {0.0015} [-0.11,0.11]
# IF att5 = (-inf, 1.00) AND att16 = (-inf, 3.01) AND att2 = (-inf, 1.00) AND att1 = <-0.0019, 1.01) AND att13 = <677.00, 738.00) AND att4 = <4.3E-4, inf) AND att3 = <-0.0096, inf) THEN label = {0.016} [-5.8E-4,0.032]
# IF att9 = <-0.0039, inf) AND att18 = (-inf, 4.00) AND att15 = (-inf, 2.51) AND att16 = (-inf, 3.01) AND att7 = <-0.0085, inf) AND att2 = <4.0E-4, inf) AND att1 = <-0.0042, inf) AND att13 = <677.00, inf) AND att4 = <-0.0068, inf) AND att3 = <-0.0082, 0.99) THEN label = {0.075} [0.056,0.094]
# IF att18 = <2.00, 4.00) AND att9 = <0.005, inf) AND att15 = (-inf, 5.00) AND att6 = <-0.0018, inf) AND att14 = (-inf, 1.01) AND att8 = (-inf, 1.01) AND att7 = <-0.009, inf) AND att16 = <1.01, inf) AND att11 = (-inf, 1.01) AND att2 = (-inf, 1.00) AND att13 = <664.50, inf) AND att4 = <-0.0057, inf) THEN label = {4.3E-4} [-0.084,0.084]
# IF att18 = <2.00, inf) AND att16 = (-inf, 4.00) AND att13 = <664.50, inf) THEN label = {0.0049} [-0.082,0.092]
# IF att13 = <664.50, 670.50) THEN label = {0.083} [0.076,0.09]
# IF att14 = (-inf, 0.0033) AND att13 = <672.49, inf) THEN label = {0.005} [-0.12,0.13]
# IF att7 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att13 = <664.50, inf) AND att4 = (-inf, 1.01) THEN label = {0.0081} [-0.12,0.13]
# IF att14 = <-0.0059, inf) AND att2 = <-0.0041, inf) AND att1 = (-inf, 1.01) AND att10 = (-inf, 1.01) AND att13 = <672.50, 756.00) AND att4 = <0.0034, inf) AND att3 = <-0.0089, 1.01) AND att12 = (-inf, 1.01) THEN label = {0.0075} [-0.061,0.076]
# IF att5 = (-inf, 1.01) AND att13 = <664.50, inf) AND att4 = (-inf, 1.01) THEN label = {0.0078} [-0.14,0.15]
# IF att11 = (-inf, 0.0093) AND att1 = (-inf, 1.00) AND att13 = (-inf, 144.00) THEN label = {0.16} [0.12,0.21]
# IF att9 = (-inf, 1.00) AND att6 = <0.0055, 1.00) AND att15 = (-inf, 2.51) AND att2 = <-0.0069, 0.0088) AND att1 = <-0.0059, 0.99) AND att10 = <-0.0061, 1.01) AND att13 = <657.50, inf) AND att3 = (-inf, 1.01) THEN label = {0.38} [0.28,0.49]
# IF att5 = (-inf, 1.00) AND att1 = <1.01, inf) AND att10 = (-inf, 0.0056) THEN label = {0.18} [0.023,0.34]
# IF att6 = <-0.0043, inf) AND att1 = <1.01, inf) AND att3 = <-0.0036, inf) THEN label = {2.9E-4} [-0.0016,0.0022]
# IF att2 = (-inf, 0.99) AND att10 = <1.01, inf) AND att3 = (-inf, 1.00) THEN label = {0.14} [0.079,0.20]
# IF att13 = <156.50, 159.50) AND att4 = <3.5E-5, inf) THEN label = {0.023} [0.022,0.023]
# IF att13 = <156.50, 163.00) THEN label = {0.023} [0.019,0.026]
# IF att17 = <1.00, inf) AND att2 = <-0.0072, inf) AND att13 = <145.50, 158.01) AND att3 = (-inf, 0.51) THEN label = {0.089} [0.073,0.10]
# IF att7 = <-0.0044, 0.51) AND att13 = <130.99, 150.50) THEN label = {0.13} [0.069,0.19]
# IF att9 = <-0.0082, inf) AND att17 = (-inf, 1.01) AND att8 = <0.0013, inf) AND att7 = (-inf, 0.0067) AND att16 = <3.00, inf) AND att1 = <-0.001, 1.00) AND att13 = (-inf, 163.00) AND att3 = (-inf, 0.99) THEN label = {0.055} [0.032,0.077]
# IF att9 = <-0.0072, inf) AND att2 = (-inf, 0.0087) AND att13 = <130.99, 155.00) THEN label = {0.10} [0.031,0.18]
# IF att18 = (-inf, 4.00) AND att5 = <-0.0063, inf) AND att8 = <-0.0011, inf) AND att7 = <-0.0049, inf) AND att10 = <-0.0057, 1.00) AND att1 = (-inf, 0.50) AND att13 = (-inf, 167.50) THEN label = {0.026} [-0.013,0.065]
# IF att5 = (-inf, 1.00) AND att8 = <-0.0042, 1.00) AND att16 = (-inf, 0.99) THEN label = {6.7E-5} [1.3E-5,1.2E-4]
# IF att9 = <-0.0077, inf) AND att5 = (-inf, 1.01) AND att16 = (-inf, 0.99) AND att1 = <-0.0016, inf) THEN label = {0.006} [-0.032,0.044]
# IF att5 = <0.0065, inf) AND att11 = <-0.0095, inf) AND att1 = (-inf, 0.0066) AND att13 = <656.00, 675.00) AND att3 = <-0.0084, inf) THEN label = {0.38} [0.28,0.48]
# IF att2 = (-inf, -0.0095) THEN label = {6.3E-4} [-0.25,0.25]
# IF att6 = <-0.0042, inf) AND att10 = <-0.0097, -0.0092) THEN label = {5.6E-4} [-0.0014,0.0025]
# IF att13 = <223.00, 230.00) THEN label = {0.069} [0.057,0.081]
# IF att13 = <164.00, 230.00) AND att4 = (-inf, -0.0062) AND att3 = <-0.0071, inf) THEN label = {0.002} [1.3E-5,0.0039]
# IF att16 = (-inf, 6.50) AND att10 = <1.01, 1.01) AND att1 = <-0.0077, inf) AND att13 = (-inf, 230.00) THEN label = {4.9E-4} [5.1E-5,9.3E-4]
# IF att9 = (-inf, 1.00) AND att13 = <173.00, 215.01) THEN label = {4.7E-4} [-5.0E-4,0.0014]
# IF att5 = (-inf, 1.00) AND att16 = (-inf, 4.50) AND att7 = <-0.0041, inf) AND att1 = (-inf, 1.00) AND att13 = <173.00, 215.01) THEN label = {3.5E-5} [-7.0E-5,1.4E-4]
# IF att5 = <-0.0074, inf) AND att7 = <-0.0065, inf) AND att2 = (-inf, 1.00) AND att1 = <-0.0068, 1.00) AND att13 = <173.00, 215.01) AND att4 = <-0.0053, 1.00) AND att12 = <-0.0054, inf) AND att3 = (-inf, 0.51) THEN label = {9.1E-5} [-0.0018,0.002]
# IF att18 = (-inf, 3.50) AND att6 = <-0.0012, inf) AND att1 = (-inf, 1.01) AND att13 = <160.00, 215.01) AND att4 = <-0.0046, inf) AND att3 = <0.0015, inf) THEN label = {0.0011} [-3.9E-4,0.0025]
# IF att15 = (-inf, 2.99) AND att16 = <1.01, inf) AND att2 = (-inf, 0.99) AND att13 = <173.00, 230.00) AND att4 = <0.50, inf) AND att3 = (-inf, 1.00) AND att12 = <0.0044, inf) THEN label = {0.011} [0.007,0.016]
# IF att15 = (-inf, 3.99) AND att6 = (-inf, 0.50) AND att5 = <-0.0041, inf) AND att8 = <-0.0066, inf) AND att17 = <0.50, inf) AND att7 = (-inf, 1.01) AND att1 = (-inf, 1.00) AND att13 = <161.00, 230.00) AND att4 = (-inf, 1.01) AND att3 = (-inf, 0.0079) THEN label = {0.011} [0.0074,0.015]
# IF att5 = (-inf, 0.99) AND att8 = <-0.0049, inf) AND att16 = <2.00, inf) AND att7 = <0.0013, inf) AND att2 = <-0.006, 0.0091) AND att1 = <0.0047, inf) AND att13 = <156.50, 226.99) AND att4 = (-inf, 1.00) AND att3 = <-0.009, inf) THEN label = {0.023} [0.007,0.04]
# IF att11 = (-inf, -0.0099) THEN label = {8.5E-4} [-0.10,0.11]
# IF att2 = <-0.008, inf) AND att10 = (-inf, 1.01) AND att13 = <221.50, 234.00) THEN label = {0.075} [0.032,0.12]
# IF att6 = (-inf, 1.00) AND att2 = (-inf, 1.01) AND att1 = <-0.0079, 0.51) AND att13 = <655.00, 667.50) AND att4 = <-0.0033, inf) AND att12 = <-0.0051, inf) THEN label = {0.46} [0.42,0.50]
# IF att16 = (-inf, 1.00) AND att2 = (-inf, 0.0039) AND att1 = (-inf, 1.01) AND att10 = (-inf, 1.01) AND att12 = <0.0041, inf) THEN label = {0.024} [-0.013,0.062]
# IF att15 = <3.00, inf) AND att5 = (-inf, 1.00) AND att8 = (-inf, 0.99) AND att16 = (-inf, 1.00) AND att4 = <-0.0017, inf) AND att13 = (-inf, 717.50) THEN label = {4.0E-5} [-1.4E-4,2.2E-4]
# IF att5 = <-0.0071, inf) AND att16 = (-inf, 1.00) AND att7 = <-0.0089, inf) AND att11 = (-inf, 1.00) AND att2 = <-0.0053, inf) AND att1 = <-0.0035, 1.01) AND att10 = (-inf, 1.01) THEN label = {0.006} [-0.16,0.17]
# IF att6 = (-inf, 1.01) AND att5 = (-inf, 1.01) AND att17 = (-inf, 1.00) AND att8 = (-inf, 1.00) AND att7 = <-0.0083, inf) AND att2 = (-inf, 1.00) AND att11 = (-inf, 1.01) AND att10 = (-inf, 0.99) AND att4 = (-inf, 1.01) AND att3 = <-0.0036, inf) THEN label = {0.03} [-0.20,0.26]
# IF att16 = <8.01, inf) AND att1 = (-inf, 1.00) THEN label = {0.55} [0.29,0.81]
# IF att2 = <2.2E-4, inf) AND att10 = (-inf, -0.0089) AND att1 = <-0.0073, 1.01) AND att4 = <-0.0057, inf) THEN label = {0.013} [-0.21,0.23]
# IF att14 = (-inf, 0.50) AND att17 = <1.01, inf) THEN label = {0.14} [8.5E-4,0.28]
# IF att9 = <0.008, inf) AND att14 = <0.50, inf) AND att17 = <1.01, inf) AND att11 = (-inf, 1.00) AND att3 = <-0.0062, inf) THEN label = {3.5E-5} [-5.6E-4,6.3E-4]
# IF att9 = (-inf, 0.99) AND att16 = (-inf, 1.00) AND att2 = <-0.0036, inf) AND att1 = <7.4E-4, 1.00) AND att4 = <0.0033, inf) AND att3 = (-inf, 1.01) THEN label = {0.14} [-0.072,0.35]
# IF att18 = <4.01, inf) AND att10 = <-0.0025, inf) THEN label = {0.42} [0.16,0.68]
# IF att6 = <1.01, inf) AND att1 = <-0.0051, inf) THEN label = {0.0015} [-0.08,0.083]
# IF att1 = (-inf, 0.0044) AND att13 = <242.50, 251.00) THEN label = {0.60} [0.57,0.62]
# IF att13 = <238.00, 251.00) THEN label = {0.57} [0.46,0.69]
# IF att8 = <-9.6E-4, inf) AND att10 = <0.99, inf) AND att1 = <-0.0088, inf) AND att13 = <221.99, 251.00) THEN label = {0.17} [0.021,0.31]
# IF att7 = <1.01, inf) AND att16 = (-inf, 4.50) THEN label = {0.0021} [-0.19,0.20]
# IF att5 = <-0.01, -0.0097) THEN label = {0.10} [-0.011,0.22]
# IF att13 = <654.50, 667.50) AND att4 = (-inf, 1.01) THEN label = {0.43} [0.34,0.51]
# IF att15 = <3.00, inf) AND att14 = (-inf, 0.50) AND att16 = (-inf, 1.00) AND att7 = (-inf, -0.0045) THEN label = {0.57} [0.34,0.81]
# IF att15 = (-inf, 1.00) AND att16 = (-inf, 2.99) THEN label = {0.012} [-0.15,0.17]
# IF att15 = (-inf, 1.00) AND att7 = <-0.0093, inf) AND att11 = (-inf, 1.00) AND att13 = (-inf, 353.50) AND att3 = (-inf, 1.00) AND att12 = (-inf, 1.00) THEN label = {2.0E-4} [-0.0034,0.0038]
# IF att15 = (-inf, 1.00) AND att5 = <1.00, inf) AND att3 = (-inf, 1.00) THEN label = {0.012} [-0.008,0.032]
# IF att15 = (-inf, 1.00) AND att6 = (-inf, 1.00) AND att5 = <-0.009, inf) AND att17 = <1.00, inf) AND att2 = <-0.0063, inf) AND att1 = (-inf, 1.00) AND att12 = <-0.0047, inf) AND att3 = (-inf, 1.00) THEN label = {0.0011} [-0.041,0.043]
# IF att6 = <-0.007, inf) AND att5 = <-0.009, inf) AND att17 = <1.00, inf) AND att7 = <-0.0071, inf) AND att2 = <-0.0079, 0.50) AND att11 = (-inf, 1.01) AND att1 = <-0.0015, inf) AND att4 = <0.50, inf) AND att3 = <-0.0079, 1.00) THEN label = {0.05} [-0.18,0.28]
# IF att15 = (-inf, 1.00) AND att1 = (-inf, 1.00) AND att3 = <-0.0062, 0.0016) THEN label = {0.0078} [-0.19,0.20]
# IF att18 = <2.00, inf) AND att15 = (-inf, 1.00) AND att14 = <-0.0012, inf) AND att5 = (-inf, 1.00) AND att16 = <3.49, inf) AND att7 = <-0.0098, inf) AND att2 = <-0.0044, inf) AND att1 = <0.0057, inf) AND att13 = <341.00, inf) AND att3 = <-0.0021, inf) THEN label = {0.46} [0.28,0.65]
# IF att9 = (-inf, 1.00) AND att15 = (-inf, 0.99) AND att5 = (-inf, 1.00) AND att17 = <-0.0039, inf) AND att16 = (-inf, 5.01) AND att1 = (-inf, 0.0092) AND att12 = (-inf, 1.01) THEN label = {0.41} [0.24,0.57]
# IF att6 = (-inf, -0.0098) AND att15 = <1.00, inf) THEN label = {0.51} [0.22,0.80]
# IF att6 = (-inf, 1.00) AND att16 = (-inf, 1.01) AND att11 = (-inf, 1.00) AND att4 = <-0.0063, inf) AND att3 = <-0.0071, inf) THEN label = {0.014} [-0.12,0.15]
# IF att5 = <0.0042, inf) AND att8 = <1.01, inf) AND att2 = <-2.1E-4, inf) AND att13 = (-inf, 361.00) THEN label = {0.0024} [-0.014,0.019]
# IF att5 = <-0.005, inf) AND att13 = <354.01, 361.00) THEN label = {0.15} [0.12,0.18]
# IF att18 = (-inf, 4.00) AND att6 = (-inf, 1.00) AND att7 = <0.003, inf) AND att2 = <-0.008, 1.01) AND att11 = (-inf, 0.50) AND att1 = (-inf, 1.00) AND att13 = <288.00, 342.50) AND att4 = (-inf, 1.00) THEN label = {9.0E-4} [5.8E-4,0.0012]
# IF att6 = <-0.0077, 1.01) AND att5 = <-0.0086, inf) AND att14 = <-0.0088, inf) AND att8 = <-0.0094, inf) AND att7 = <-0.0082, inf) AND att2 = <-0.0059, inf) AND att1 = <-0.0043, 1.00) AND att10 = (-inf, 1.01) AND att13 = <288.00, 342.50) AND att4 = (-inf, 1.01) AND att3 = <-0.0077, inf) THEN label = {8.5E-4} [-0.007,0.0087]
# IF att6 = <-0.0079, inf) AND att5 = <-0.0079, inf) AND att7 = (-inf, 1.00) AND att2 = <0.0027, inf) AND att10 = (-inf, 1.01) AND att1 = (-inf, 0.0087) AND att13 = <288.00, 342.50) AND att3 = <-0.0073, inf) AND att12 = (-inf, 1.01) THEN label = {6.2E-4} [-0.0076,0.0088]
# IF att9 = (-inf, 1.01) AND att6 = <-0.0077, 1.01) AND att15 = <0.99, inf) AND att14 = <-0.0088, inf) AND att5 = (-inf, 1.00) AND att7 = (-inf, 1.01) AND att16 = <1.00, 8.00) AND att11 = <-0.0062, inf) AND att13 = <288.00, 339.00) AND att4 = <-0.0075, 1.01) AND att12 = (-inf, 1.00) THEN label = {8.5E-4} [-0.0071,0.0088]
# IF att18 = (-inf, 3.99) AND att6 = <-0.0073, 1.00) AND att5 = <-0.0079, 1.00) AND att17 = <0.49, inf) AND att7 = <-0.0097, 1.00) AND att2 = (-inf, 1.00) AND att1 = (-inf, 0.99) AND att10 = <0.0014, inf) AND att13 = <288.00, 342.50) AND att3 = <-0.0055, 1.01) AND att12 = (-inf, 1.01) THEN label = {0.02} [0.009,0.031]
# IF att7 = (-inf, 0.0083) AND att2 = <0.0034, inf) AND att1 = <-0.0084, inf) AND att13 = <300.01, 357.50) AND att4 = (-inf, 1.00) AND att3 = (-inf, 0.0032) THEN label = {0.0048} [-0.014,0.024]
# IF att18 = <2.01, inf) AND att6 = <-0.0028, inf) AND att17 = <1.00, inf) AND att8 = <-0.0095, 0.0042) AND att1 = <-0.0024, 1.00) AND att13 = <162.00, 361.00) AND att12 = (-inf, 1.00) THEN label = {0.40} [0.17,0.63]
# IF att6 = <-0.0032, inf) AND att17 = <1.00, 1.00) AND att1 = (-inf, 0.0034) AND att13 = (-inf, 361.00) THEN label = {0.60} [0.35,0.85]
# IF att15 = <2.00, inf) AND att6 = <-0.0094, 1.01) AND att8 = (-inf, 0.0015) AND att1 = <-0.0075, 0.0099) AND att10 = <-0.0055, inf) AND att13 = (-inf, 361.00) AND att4 = <1.00, 1.01) AND att3 = (-inf, 1.01) THEN label = {0.37} [0.086,0.65]
# IF att18 = (-inf, 4.00) AND att9 = (-inf, 1.00) AND att6 = <-0.0053, inf) AND att16 = <4.49, inf) AND att2 = <3.5E-4, inf) AND att1 = (-inf, 0.99) AND att13 = (-inf, 328.00) AND att4 = <1.00, 1.01) THEN label = {0.56} [0.28,0.83]
# IF att15 = <1.00, inf) AND att6 = <0.0032, inf) AND att5 = (-inf, 0.0055) AND att17 = <-0.0047, inf) AND att8 = (-inf, 1.01) AND att7 = <-0.0077, inf) AND att2 = <-0.0053, inf) AND att11 = <-0.004, inf) AND att1 = <-0.0014, 1.01) AND att13 = <234.00, 361.00) AND att4 = (-inf, 1.01) AND att3 = (-inf, 1.00) THEN label = {0.36} [0.08,0.65]
# IF att9 = (-inf, 0.50) AND att15 = (-inf, 5.00) AND att5 = (-inf, 0.0072) AND att7 = (-inf, 1.00) AND att2 = (-inf, 1.00) AND att11 = (-inf, 1.00) AND att1 = (-inf, 0.99) AND att13 = <216.00, 361.00) AND att4 = (-inf, 1.00) THEN label = {0.37} [0.18,0.56]
# IF att18 = (-inf, 4.01) AND att8 = <-0.0068, 1.00) AND att17 = (-inf, 1.00) AND att2 = <-0.0077, 0.50) AND att11 = <0.50, inf) AND att4 = (-inf, 9.4E-4) AND att13 = (-inf, 290.00) THEN label = {0.14} [-0.03,0.30]
# IF att6 = (-inf, 1.01) AND att5 = (-inf, 1.00) AND att14 = (-inf, 0.99) AND att17 = <0.0032, 1.01) AND att16 = (-inf, 7.00) AND att2 = <-0.0042, inf) AND att13 = <143.00, 290.00) AND att3 = <-0.0017, 1.00) AND att12 = <-0.0055, inf) THEN label = {0.56} [0.37,0.74]
# IF att9 = <-0.0073, inf) AND att17 = <3.2E-4, inf) AND att8 = <-0.0066, 1.00) AND att7 = <-0.0089, 1.01) AND att11 = (-inf, 1.00) AND att2 = <0.0025, 1.01) AND att13 = (-inf, 356.01) AND att4 = <-0.0091, 0.0017) AND att3 = (-inf, 0.0045) THEN label = {0.28} [0.073,0.48]
# IF att5 = (-inf, 1.00) AND att16 = (-inf, 1.99) AND att1 = <-6.9E-4, inf) THEN label = {0.0013} [-0.18,0.18]
# IF att8 = <-0.0076, 1.00) AND att16 = (-inf, 1.99) AND att1 = <-0.0071, inf) AND att12 = <0.0033, inf) THEN label = {0.014} [-0.18,0.20]
# IF att2 = <-0.0074, inf) AND att4 = <1.01, 1.01) THEN label = {0.023} [-0.14,0.18]
# IF att15 = <1.50, inf) AND att14 = (-inf, 1.00) AND att17 = <-0.0017, inf) AND att2 = (-inf, -0.0087) AND att11 = <0.0082, inf) AND att1 = (-inf, 1.01) AND att4 = <-0.008, inf) THEN label = {0.20} [0.10,0.31]
# IF att18 = (-inf, 3.99) AND att6 = <-0.0049, 1.00) AND att5 = (-inf, 1.00) AND att14 = (-inf, 1.01) AND att8 = <-0.0077, inf) AND att2 = <-0.0085, 1.01) AND att1 = <-0.0038, -3.2E-4) AND att13 = (-inf, 362.51) AND att4 = (-inf, 1.00) AND att3 = <-0.0095, 1.01) THEN label = {0.26} [0.097,0.42]
# IF att6 = (-inf, 1.00) AND att5 = <-0.0043, 1.00) AND att8 = <4.2E-4, inf) AND att2 = <-0.0063, 0.0077) AND att10 = <-0.0076, inf) AND att1 = (-inf, 0.0077) AND att4 = (-inf, 1.01) AND att3 = (-inf, 1.01) AND att12 = (-inf, 1.00) THEN label = {0.051} [-0.15,0.26]
# IF att7 = (-inf, 0.0037) AND att1 = (-inf, 0.0061) AND att3 = <1.01, inf) THEN label = {0.45} [0.22,0.67]
# IF att18 = <3.01, inf) AND att15 = (-inf, 1.00) AND att14 = <0.99, inf) AND att5 = <0.99, inf) AND att2 = (-inf, 1.01) AND att1 = <-0.0037, 0.99) AND att3 = (-inf, 1.01) THEN label = {0.20} [0.037,0.36]
# IF att18 = (-inf, 2.00) AND att6 = <-0.006, inf) AND att2 = (-inf, 0.50) AND att1 = (-inf, 1.01) AND att13 = (-inf, 634.01) THEN label = {0.074} [-0.16,0.30]
# IF att18 = (-inf, 2.00) AND att16 = <5.99, 7.50) AND att11 = (-inf, 0.0038) AND att1 = (-inf, 1.00) AND att3 = (-inf, 0.50) THEN label = {0.37} [0.16,0.57]
# IF att18 = (-inf, 2.00) AND att9 = <-0.0078, inf) AND att6 = (-inf, 0.0032) AND att15 = <1.51, inf) AND att14 = <-0.0061, inf) AND att16 = <4.00, inf) AND att7 = <-0.006, 1.01) AND att2 = (-inf, 1.00) AND att4 = <-0.0048, 1.00) THEN label = {0.14} [-0.02,0.30]
# IF att18 = (-inf, 2.00) AND att6 = (-inf, 1.00) AND att5 = <-0.0093, inf) AND att17 = (-inf, 1.01) AND att8 = <-0.0062, inf) AND att1 = <-0.0078, 1.00) AND att4 = (-inf, 1.00) AND att3 = (-inf, 1.00) THEN label = {0.015} [-0.23,0.26]
# IF att9 = (-inf, 1.00) AND att15 = <1.00, 1.00) AND att5 = <-0.0072, 1.01) AND att14 = <-0.0035, inf) AND att2 = <0.0019, inf) AND att1 = (-inf, 1.01) AND att4 = (-inf, 1.01) AND att12 = <-0.0065, inf) THEN label = {0.39} [0.22,0.57]
# IF att6 = (-inf, 0.0035) AND att5 = <-0.0067, 1.00) AND att8 = <-8.2E-4, 1.01) AND att16 = (-inf, 7.00) AND att7 = <-0.0051, 1.00) AND att2 = (-inf, 0.0084) AND att11 = (-inf, 1.00) AND att1 = <-0.003, 1.01) AND att13 = <405.01, 715.50) AND att3 = <0.0066, inf) THEN label = {0.025} [-0.12,0.17]
# IF att6 = <0.0027, inf) AND att17 = (-inf, 1.01) AND att2 = (-inf, -0.0081) AND att1 = <0.0054, inf) AND att13 = (-inf, 611.99) AND att3 = <-0.0062, inf) THEN label = {0.17} [0.011,0.33]
# IF att5 = <-0.0019, inf) AND att8 = <0.0058, inf) AND att16 = (-inf, 6.00) AND att2 = (-inf, 1.00) AND att1 = <-0.0089, inf) AND att13 = <177.50, inf) AND att4 = <0.0029, 1.00) THEN label = {0.0078} [-0.22,0.23]
# IF att13 = <646.50, 656.50) AND att3 = (-inf, 0.99) THEN label = {0.48} [0.42,0.53]
# IF att18 = <2.00, 2.00) AND att9 = <-0.0015, 1.01) AND att8 = (-inf, 1.01) AND att16 = <3.50, inf) AND att2 = <-0.0038, 0.0069) AND att1 = <-0.009, 1.00) AND att4 = <-0.0042, 1.00) THEN label = {0.56} [0.30,0.82]
# IF att9 = (-inf, 1.01) AND att5 = <-0.0055, 1.00) AND att8 = <-0.008, inf) AND att17 = <0.50, inf) AND att7 = <-0.0019, inf) AND att1 = <-7.8E-4, 1.00) AND att10 = (-inf, 1.00) AND att13 = <438.50, 635.50) AND att4 = <-0.0089, inf) AND att3 = (-inf, 1.00) THEN label = {0.045} [-0.17,0.26]
# IF att18 = <3.01, inf) AND att13 = <360.00, 370.01) THEN label = {0.41} [0.35,0.48]
# IF att18 = <2.01, inf) AND att14 = (-inf, 1.00) AND att16 = <1.99, 2.00) AND att11 = <-0.0054, inf) AND att13 = <414.50, inf) AND att4 = (-inf, 1.00) AND att3 = <-0.0095, inf) THEN label = {0.26} [0.14,0.37]
# IF att10 = <0.99, inf) AND att4 = <1.01, inf) AND att3 = <-0.0029, 1.00) THEN label = {0.0093} [-0.077,0.095]
# IF att9 = (-inf, 1.01) AND att6 = (-inf, 0.0094) AND att5 = <0.99, 1.01) AND att2 = (-inf, 1.01) AND att1 = <-0.0075, inf) AND att13 = <406.00, 461.50) AND att3 = (-inf, 1.01) THEN label = {2.4E-4} [-3.7E-4,8.4E-4]
# IF att9 = (-inf, 0.0084) AND att13 = <406.00, 481.01) THEN label = {0.0014} [-0.032,0.034]
# IF att9 = <0.0011, 1.00) AND att6 = (-inf, 1.01) AND att5 = <-0.0031, 1.00) AND att8 = (-inf, 1.00) AND att7 = (-inf, 1.01) AND att2 = <-0.0085, inf) AND att10 = <-0.009, inf) AND att1 = <-0.0056, 1.00) AND att13 = <406.00, inf) AND att4 = <-0.0087, inf) AND att3 = <-0.0077, 1.01) THEN label = {0.03} [-0.12,0.18]
# IF att9 = <-0.0061, inf) AND att5 = (-inf, -0.0051) AND att2 = <0.0046, 1.01) AND att11 = <-0.0068, 1.01) AND att1 = <-0.0056, 0.0079) AND att13 = <406.00, inf) AND att4 = (-inf, 1.01) AND att3 = <-0.0081, inf) THEN label = {0.38} [0.11,0.66]
# IF att9 = (-inf, 1.00) AND att15 = <1.00, 3.01) AND att6 = <-7.3E-4, inf) AND att14 = (-inf, -0.0026) AND att8 = (-inf, 0.99) AND att7 = <-0.0057, inf) AND att2 = <-0.0075, inf) AND att11 = (-inf, 1.01) AND att1 = (-inf, 1.01) AND att13 = <406.00, inf) AND att4 = (-inf, 1.00) THEN label = {0.47} [0.24,0.70]
# IF att18 = (-inf, 3.00) AND att15 = <4.00, inf) AND att5 = (-inf, 1.00) AND att7 = <0.99, 1.01) AND att2 = <-0.006, inf) AND att13 = <406.00, 695.00) THEN label = {0.26} [0.025,0.50]
# IF att17 = (-inf, 1.00) AND att16 = (-inf, 6.00) AND att7 = (-inf, 0.0042) AND att1 = <-0.0026, 1.00) AND att13 = <479.01, 516.01) THEN label = {0.20} [0.066,0.34]
# IF att9 = (-inf, 1.01) AND att2 = (-inf, 1.00) AND att13 = <544.51, 594.00) AND att4 = (-inf, 1.00) AND att3 = (-inf, 1.01) THEN label = {4.5E-4} [-0.0038,0.0047]
# IF att15 = (-inf, 4.00) AND att5 = (-inf, 1.00) AND att14 = <0.0083, inf) AND att2 = <0.008, inf) AND att1 = <-0.0032, inf) AND att13 = <522.00, 607.50) AND att4 = <-0.0054, 1.01) AND att12 = <-2.4E-4, inf) AND att3 = <-0.0092, inf) THEN label = {0.28} [0.15,0.42]
# IF att16 = <2.00, inf) AND att2 = (-inf, 1.00) AND att13 = <517.50, 538.50) AND att4 = <-0.006, inf) AND att3 = (-inf, 1.00) AND att12 = <0.99, inf) THEN label = {0.48} [0.33,0.62]
# IF att18 = (-inf, 3.99) AND att16 = (-inf, 8.00) AND att10 = <-0.0045, inf) AND att13 = <551.00, 661.50) AND att9 = <-0.0086, 1.01) AND att6 = <-0.0067, 0.50) AND att5 = <-0.0036, inf) AND att8 = <-0.0084, inf) AND att7 = <2.9E-4, inf) AND att2 = <-0.007, inf) AND att1 = <-0.0038, 1.00) AND att4 = <-0.0093, 1.00) AND att3 = <-0.0082, inf) THEN label = {0.80} [0.54,1.06]
# IF att18 = <3.00, inf) AND att14 = <-0.0048, 1.00) AND att17 = <-0.0078, inf) AND att10 = <-0.0029, inf) AND att13 = <405.00, inf) AND att12 = <-0.0031, 1.01) AND att6 = <-0.0035, 1.00) AND att5 = <0.0035, inf) AND att8 = (-inf, 1.00) AND att7 = <-0.0068, 1.00) AND att1 = (-inf, 1.01) AND att4 = <-0.0061, 1.00) AND att3 = (-inf, 1.00) THEN label = {0.47} [0.21,0.73]
# IF att18 = <2.00, inf) AND att9 = (-inf, 0.0085) AND att6 = <-0.0082, 0.0067) AND att14 = (-inf, 1.01) AND att5 = <-0.0082, inf) AND att17 = <-0.0062, inf) AND att8 = <-0.0076, inf) AND att1 = <0.50, inf) AND att13 = <302.50, 622.00) AND att4 = <-0.0041, 1.00) AND att3 = <-0.0078, inf) THEN label = {0.64} [0.36,0.91]
# IF att15 = (-inf, 5.00) AND att14 = <-0.0085, inf) AND att2 = <0.0019, inf) AND att10 = <0.99, inf) AND att1 = (-inf, 1.00) AND att13 = <351.50, 425.00) AND att3 = <-0.0073, inf) THEN label = {0.46} [0.25,0.68]
# IF att15 = <1.00, inf) AND att6 = (-inf, 1.00) AND att14 = <-0.0079, inf) AND att11 = (-inf, 1.01) AND att2 = <0.0038, inf) AND att10 = <-0.0067, 1.00) AND att1 = (-inf, 1.01) AND att13 = <361.00, 419.00) AND att3 = <-0.0072, 0.0084) AND att12 = (-inf, 1.00) THEN label = {0.83} [0.64,1.03]
# 130
# Mean Jaccard Similarity for the Rule Set: 0.01
# Percentage of predictions within bounds: 0.142%

# %%
clf = DecisionTreeRegressor(random_state=0)
clf.fit(samp, yee)
pred = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
pr_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(pred, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (pr_count_within_bounds / len(pred)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        #rule += " then "
        if class_names is None:
            s = 0
            #rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        #rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules
rules = get_rules(clf, Xe.columns, None)
for r in rules:
    print(r)
len(rules)
# Out:
# Percentage of predictions within bounds: 0.871%
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters > 559.502) and (sep_num_filters <= 589.005) and (categorical_pooling_avg <= 1.002) and (sep_num_filters <= 584.503) and (sep_num_filters > 567.499) and (sep_num_filters <= 582.5) and (num_dense_layers <= 2.0) and (categorical_activation_selu <= 0.006) and (categorical_conv2dnumfilters_32 <= 0.508) and (categorical_pooling_avg <= 0.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks <= 1.502) and (initial_strides > 2.498) and (sep_num_filters > 316.493) and (initial_strides > 3.495)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters > 559.502) and (sep_num_filters <= 589.005) and (categorical_pooling_avg <= 1.002) and (sep_num_filters <= 584.503) and (sep_num_filters > 567.499) and (sep_num_filters <= 582.5) and (num_dense_layers > 2.0) and (categorical_pooling_avg <= 0.994) and (categorical_pooling_flatten <= 0.007) and (categorical_pooling_flatten <= -0.001) and (categorical_activation_relu <= 1.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks <= 1.502) and (initial_strides <= 2.498)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters <= 453.499) and (num_dense_layers <= 3.0) and (sep_num_filters <= 450.0) and (categorical_activation_selu > 0.501)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters > 664.497) and (sep_num_filters <= 742.505) and (sep_num_filters > 672.499) and (sep_num_filters <= 736.001) and (sep_num_filters > 676.503) and (sep_num_filters <= 728.505) and (sep_num_filters > 680.002) and (sep_num_filters > 686.004) and (sep_num_filters <= 723.0) and (sep_num_filters > 690.004) and (sep_num_filters <= 718.505) and (sep_num_filters > 693.999) and (sep_num_filters <= 713.001) and (sep_num_filters > 699.5) and (sep_num_filters <= 709.001) and (categorical_conv2dnumfilters_32 > -0.0) and (categorical_pooling_max > -0.007) and (categorical_denseusebn_0 <= 0.499) and (categorical_kernelsize_5 <= 0.997) and (sep_num_filters <= 700.997)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks <= 1.502) and (initial_strides > 2.498) and (sep_num_filters <= 316.493)
# if (sep_num_filters <= 231.996) and (sep_num_filters > 145.503) and (sep_num_filters > 153.501) and (sep_num_filters <= 224.495) and (sep_num_filters <= 219.005) and (sep_num_filters > 163.002) and (sep_num_filters <= 211.504) and (sep_num_filters > 168.999) and (sep_num_filters > 173.001) and (sep_num_filters <= 206.499) and (sep_num_filters > 178.002) and (sep_num_filters <= 202.992) and (dropout_rate <= 1.006) and (num_residual_blocks <= 3.996) and (sep_num_filters > 185.002) and (sep_num_filters > 195.5) and (categorical_conv2dnumfilters_64 > 0.496) and (dropout_rate > -0.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters <= 453.499) and (num_dense_layers <= 3.0) and (sep_num_filters > 450.0) and (categorical_conv2dnumfilters_128 > 0.5)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters <= 453.499) and (num_dense_layers > 3.0) and (categorical_kernelsize_5 <= 0.499) and (categorical_conv2dnumfilters_64 > 0.497) and (sep_num_filters > 445.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters <= 453.499) and (num_dense_layers > 3.0) and (categorical_kernelsize_5 > 0.499) and (num_dense_layers <= 4.503) and (categorical_pooling_max <= 0.008)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters > 559.502) and (sep_num_filters <= 589.005) and (categorical_pooling_avg <= 1.002) and (sep_num_filters > 584.503) and (sep_num_filters > 586.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters > 453.499) and (num_residual_blocks <= 7.003) and (initial_strides <= 2.998) and (categorical_pooling_avg > 0.492) and (initial_strides <= 2.001)
# if (sep_num_filters <= 231.996) and (sep_num_filters > 145.503) and (sep_num_filters > 153.501) and (sep_num_filters <= 224.495) and (sep_num_filters <= 219.005) and (sep_num_filters > 163.002) and (sep_num_filters <= 211.504) and (sep_num_filters > 168.999) and (sep_num_filters > 173.001) and (sep_num_filters <= 206.499) and (sep_num_filters > 178.002) and (sep_num_filters <= 202.992) and (dropout_rate <= 1.006) and (num_residual_blocks <= 3.996) and (sep_num_filters > 185.002) and (sep_num_filters <= 195.5) and (categorical_denseusebn_1 > 0.003) and (categorical_pooling_max <= 0.507) and (num_dense_layers <= 2.009) and (categorical_conv2dnumfilters_128 <= 0.504) and (categorical_activation_relu > 0.502)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters > 559.502) and (sep_num_filters <= 589.005) and (categorical_pooling_avg <= 1.002) and (sep_num_filters <= 584.503) and (sep_num_filters > 567.499) and (sep_num_filters > 582.5) and (num_residual_blocks <= 0.996)
# if (sep_num_filters <= 231.996) and (sep_num_filters > 145.503) and (sep_num_filters > 153.501) and (sep_num_filters <= 224.495) and (sep_num_filters <= 219.005) and (sep_num_filters > 163.002) and (sep_num_filters <= 211.504) and (sep_num_filters > 168.999) and (sep_num_filters > 173.001) and (sep_num_filters <= 206.499) and (sep_num_filters > 178.002) and (sep_num_filters <= 202.992) and (dropout_rate <= 1.006) and (num_residual_blocks <= 3.996) and (sep_num_filters <= 185.002) and (learning_rate <= 1.008)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters > 664.497) and (sep_num_filters <= 742.505) and (sep_num_filters > 672.499) and (sep_num_filters <= 736.001) and (sep_num_filters > 676.503) and (sep_num_filters <= 728.505) and (sep_num_filters > 680.002) and (sep_num_filters > 686.004) and (sep_num_filters <= 723.0) and (sep_num_filters > 690.004) and (sep_num_filters <= 718.505) and (sep_num_filters > 693.999) and (sep_num_filters <= 713.001) and (sep_num_filters > 699.5) and (sep_num_filters <= 709.001) and (categorical_conv2dnumfilters_32 > -0.0) and (categorical_pooling_max > -0.007) and (categorical_denseusebn_0 <= 0.499) and (categorical_kernelsize_5 <= 0.997) and (sep_num_filters > 700.997) and (categorical_activation_selu > 0.497)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters <= 453.499) and (num_dense_layers <= 3.0) and (sep_num_filters <= 450.0) and (categorical_activation_selu <= 0.501) and (categorical_conv2dnumfilters_64 > 0.504)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg <= 0.505) and (initial_strides <= 3.998) and (categorical_pooling_max <= 0.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate > 1.002) and (categorical_conv2dnumfilters_128 > 0.5)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters > 664.497) and (sep_num_filters <= 742.505) and (sep_num_filters > 672.499) and (sep_num_filters <= 736.001) and (sep_num_filters > 676.503) and (sep_num_filters <= 728.505) and (sep_num_filters > 680.002) and (sep_num_filters > 686.004) and (sep_num_filters <= 723.0) and (sep_num_filters > 690.004) and (sep_num_filters <= 718.505) and (sep_num_filters > 693.999) and (sep_num_filters <= 713.001) and (sep_num_filters > 699.5) and (sep_num_filters <= 709.001) and (categorical_conv2dnumfilters_32 <= -0.0) and (sep_num_filters > 702.5) and (dropout_rate <= 0.006) and (categorical_kernelsize_3 > 0.998)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters <= 325.503) and (num_residual_blocks <= 3.499) and (categorical_activation_selu > 0.502)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters > 443.492) and (sep_num_filters > 453.499) and (num_residual_blocks <= 7.003) and (initial_strides <= 2.998) and (categorical_pooling_avg > 0.492) and (initial_strides > 2.001) and (categorical_kernelsize_3 <= 1.009)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters > 664.497) and (sep_num_filters <= 742.505) and (sep_num_filters > 672.499) and (sep_num_filters <= 736.001) and (sep_num_filters > 676.503) and (sep_num_filters <= 728.505) and (sep_num_filters > 680.002) and (sep_num_filters > 686.004) and (sep_num_filters <= 723.0) and (sep_num_filters > 690.004) and (sep_num_filters <= 718.505) and (sep_num_filters > 693.999) and (sep_num_filters <= 713.001) and (sep_num_filters > 699.5) and (sep_num_filters <= 709.001) and (categorical_conv2dnumfilters_32 > -0.0) and (categorical_pooling_max > -0.007) and (categorical_denseusebn_0 > 0.499) and (categorical_denseusebn_0 <= 1.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters <= 433.998) and (num_residual_blocks <= 4.507) and (sep_num_filters <= 430.992)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters <= 488.508) and (sep_num_filters > 412.501) and (sep_num_filters <= 481.006) and (sep_num_filters > 417.505) and (sep_num_filters <= 475.5) and (sep_num_filters > 421.5) and (sep_num_filters <= 471.506) and (sep_num_filters > 429.0) and (sep_num_filters <= 466.996) and (sep_num_filters > 433.998) and (sep_num_filters > 438.004) and (sep_num_filters <= 461.994) and (sep_num_filters <= 456.503) and (sep_num_filters <= 443.492) and (learning_rate <= 1.006) and (categorical_activation_selu <= 0.505)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg <= 0.502) and (categorical_conv2dnumfilters_32 > 0.503) and (categorical_activation_selu <= -0.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers <= 2.999) and (initial_strides <= 1.995)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg > 0.505) and (categorical_kernelsize_3 > 0.994)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg > 0.505) and (categorical_kernelsize_3 <= 0.994)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg <= 0.505) and (initial_strides > 3.998) and (categorical_pooling_max > 0.01)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg <= 0.505) and (initial_strides > 3.998) and (categorical_pooling_max <= 0.01)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters > 327.003) and (categorical_pooling_avg <= 0.505) and (initial_strides <= 3.998) and (categorical_pooling_max > 0.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks <= 4.999) and (categorical_denseusebn_0 > 1.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks > 4.999) and (initial_strides <= 2.498)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks > 4.999) and (initial_strides > 2.498) and (num_dense_layers <= 1.999)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate > 1.002) and (categorical_conv2dnumfilters_128 <= 0.5)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate > 1.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers <= 2.999) and (initial_strides > 1.995) and (sep_num_filters <= 333.003) and (categorical_pooling_flatten <= 1.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks > 4.999) and (initial_strides > 2.498) and (num_dense_layers > 1.999)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 > 0.997) and (learning_rate <= 0.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters > 325.503) and (categorical_denseusebn_1 > 0.498)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters > 325.503) and (categorical_denseusebn_1 <= 0.498) and (categorical_activation_selu > 0.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 > 0.997) and (learning_rate > 0.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate > 1.009)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters > 325.503) and (categorical_denseusebn_1 <= 0.498) and (categorical_activation_selu <= 0.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters > 349.5) and (sep_num_filters <= 352.498) and (sep_num_filters <= 350.499)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters > 349.5) and (sep_num_filters <= 352.498) and (sep_num_filters > 350.499) and (initial_strides <= 3.006) and (num_dense_layers <= 2.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters <= 325.503) and (num_residual_blocks > 3.499) and (categorical_activation_selu > 0.503)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks <= 4.999) and (categorical_denseusebn_0 <= 1.005) and (initial_strides > 4.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters > 343.499) and (dropout_rate <= 1.009) and (categorical_kernelsize_3 <= 0.997) and (num_residual_blocks <= 4.999) and (categorical_denseusebn_0 <= 1.005) and (initial_strides <= 4.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg <= 0.502) and (categorical_conv2dnumfilters_32 <= 0.503) and (sep_num_filters > 339.999)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers <= 2.999) and (initial_strides > 1.995) and (sep_num_filters <= 333.003) and (categorical_pooling_flatten > 1.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg <= 0.502) and (categorical_conv2dnumfilters_32 <= 0.503) and (sep_num_filters <= 339.999) and (initial_strides > 1.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg <= 0.502) and (categorical_conv2dnumfilters_32 > 0.503) and (categorical_activation_selu > -0.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg > 0.502) and (categorical_denseusebn_1 <= -0.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg <= 0.502) and (categorical_conv2dnumfilters_32 <= 0.503) and (sep_num_filters <= 339.999) and (initial_strides <= 1.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters > 335.002) and (categorical_denseusebn_1 > -0.003) and (categorical_activation_relu > 0.502) and (num_residual_blocks > 5.495) and (categorical_conv2dnumfilters_128 > -0.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters <= 341.007) and (categorical_pooling_avg > 0.502) and (categorical_denseusebn_1 > -0.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters > 335.002) and (categorical_denseusebn_1 > -0.003) and (categorical_activation_relu > 0.502) and (num_residual_blocks > 5.495) and (categorical_conv2dnumfilters_128 <= -0.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters > 335.002) and (categorical_denseusebn_1 > -0.003) and (categorical_activation_relu > 0.502) and (num_residual_blocks <= 5.495)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters > 341.007) and (categorical_activation_relu <= 0.498) and (initial_strides <= 3.997)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters > 341.007) and (categorical_activation_relu <= 0.498) and (initial_strides > 3.997)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters <= 325.503) and (num_residual_blocks > 3.499) and (categorical_activation_selu <= 0.503) and (categorical_kernelsize_5 > -0.006) and (num_dense_layers > 1.996) and (categorical_kernelsize_5 > 1.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters > 335.002) and (categorical_denseusebn_1 > -0.003) and (categorical_activation_relu <= 0.502)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters > 335.002) and (categorical_denseusebn_1 <= -0.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters > 341.007) and (categorical_activation_relu > 0.498) and (categorical_kernelsize_5 <= 0.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters > 333.503) and (learning_rate > 1.004) and (categorical_kernelsize_5 > 1.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters > 338.994) and (sep_num_filters > 341.007) and (categorical_activation_relu > 0.498) and (categorical_kernelsize_5 > 0.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters > 333.503) and (learning_rate > 1.004) and (categorical_kernelsize_5 <= 1.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters > 333.503) and (learning_rate <= 1.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers > 2.999) and (num_dense_layers > 4.997)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers > 2.999) and (num_dense_layers <= 4.997)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters > 330.005) and (sep_num_filters <= 333.503) and (num_dense_layers <= 2.999) and (initial_strides > 1.995) and (sep_num_filters > 333.003)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters > 752.5) and (sep_num_filters > 756.001) and (sep_num_filters > 761.001) and (categorical_conv2dnumfilters_64 > 0.498) and (num_residual_blocks > 5.51)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks <= 1.502) and (initial_strides > 2.498) and (sep_num_filters > 316.493) and (initial_strides <= 3.495) and (categorical_pooling_max <= -0.007)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters > 300.493) and (sep_num_filters <= 335.002) and (sep_num_filters > 305.005) and (sep_num_filters <= 330.005) and (sep_num_filters > 308.005) and (sep_num_filters <= 327.003) and (sep_num_filters > 313.0) and (num_residual_blocks > 1.502) and (learning_rate <= 1.002) and (dropout_rate <= 1.003) and (sep_num_filters <= 325.503) and (num_residual_blocks > 3.499) and (categorical_activation_selu <= 0.503) and (categorical_kernelsize_5 > -0.006) and (num_dense_layers > 1.996) and (categorical_kernelsize_5 <= 1.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters > 293.504) and (sep_num_filters <= 338.994) and (sep_num_filters <= 300.493) and (categorical_pooling_flatten <= 0.501) and (categorical_kernelsize_5 > 0.5) and (learning_rate <= 1.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters <= 293.504) and (categorical_activation_relu > 0.496) and (categorical_conv2dnumfilters_64 > -0.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters <= 293.504) and (categorical_activation_relu > 0.496) and (categorical_conv2dnumfilters_64 <= -0.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters > 289.508) and (sep_num_filters <= 343.499) and (sep_num_filters <= 293.504) and (categorical_activation_relu <= 0.496)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters > 286.5) and (num_residual_blocks > 4.996) and (categorical_activation_relu > 1.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters > 286.5) and (num_residual_blocks > 4.996) and (categorical_activation_relu <= 1.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters > 286.5) and (num_residual_blocks <= 4.996) and (num_residual_blocks > 4.499)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters > 286.5) and (num_residual_blocks <= 4.996) and (num_residual_blocks <= 4.499) and (categorical_denseusebn_0 > 0.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters > 286.5) and (num_residual_blocks <= 4.996) and (num_residual_blocks <= 4.499) and (categorical_denseusebn_0 <= 0.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters <= 355.508) and (sep_num_filters > 283.999) and (sep_num_filters <= 349.5) and (sep_num_filters <= 289.508) and (sep_num_filters <= 286.5) and (num_residual_blocks > 2.003) and (categorical_denseusebn_0 > -0.004)
# ...
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks <= 3.496) and (categorical_kernelsize_3 > 0.009) and (num_residual_blocks > 0.998) and (categorical_conv2dnumfilters_128 <= 0.494)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks <= 3.496) and (categorical_kernelsize_3 > 0.009) and (num_residual_blocks > 0.998) and (categorical_conv2dnumfilters_128 > 0.494)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters <= 559.502) and (sep_num_filters > 556.994) and (learning_rate <= 0.502) and (categorical_activation_selu <= 1.001) and (categorical_denseusebn_1 > 1.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters <= 559.502) and (sep_num_filters > 556.994) and (learning_rate <= 0.502) and (categorical_activation_selu <= 1.001) and (categorical_denseusebn_1 <= 1.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters <= 559.502) and (sep_num_filters <= 556.994) and (num_residual_blocks > 3.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters > 554.497) and (sep_num_filters <= 592.5) and (sep_num_filters <= 559.502) and (sep_num_filters <= 556.994) and (num_residual_blocks <= 3.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters <= 554.497) and (num_residual_blocks > 3.494) and (dropout_rate > 1.0) and (categorical_pooling_max > 0.504)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters <= 554.497) and (num_residual_blocks > 3.494) and (dropout_rate > 1.0) and (categorical_pooling_max <= 0.504)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters <= 554.497) and (num_residual_blocks > 3.494) and (dropout_rate <= 1.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters <= 554.497) and (num_residual_blocks <= 3.494) and (learning_rate > 0.502)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters > 547.999) and (sep_num_filters <= 596.999) and (sep_num_filters <= 554.497) and (num_residual_blocks <= 3.494) and (learning_rate <= 0.502)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters > 544.506) and (initial_strides > 2.504)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters > 544.506) and (initial_strides <= 2.504) and (initial_strides > 2.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters > 544.506) and (initial_strides <= 2.504) and (initial_strides <= 2.005)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters <= 544.506) and (categorical_kernelsize_5 > 1.0)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters <= 544.506) and (categorical_kernelsize_5 <= 1.0) and (categorical_pooling_flatten > 0.494) and (categorical_activation_relu > 1.006)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters <= 544.506) and (categorical_kernelsize_5 <= 1.0) and (categorical_pooling_flatten > 0.494) and (categorical_activation_relu <= 1.006)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters > 540.5) and (sep_num_filters <= 608.002) and (sep_num_filters <= 601.498) and (sep_num_filters <= 547.999) and (sep_num_filters <= 544.506) and (categorical_kernelsize_5 <= 1.0) and (categorical_pooling_flatten <= 0.494)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers > 1.999) and (num_dense_layers > 3.503)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers > 1.999) and (num_dense_layers <= 3.503) and (categorical_pooling_flatten > 0.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers > 1.999) and (num_dense_layers <= 3.503) and (categorical_pooling_flatten <= 0.001)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten > 0.5) and (sep_num_filters > 538.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten > 0.5) and (sep_num_filters <= 538.996)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten <= 0.5) and (categorical_pooling_avg > 1.002) and (categorical_pooling_avg > 1.004) and (categorical_denseusebn_0 > 0.009)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten <= 0.5) and (categorical_pooling_avg > 1.002) and (categorical_pooling_avg > 1.004) and (categorical_denseusebn_0 <= 0.009)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten <= 0.5) and (categorical_pooling_avg > 1.002) and (categorical_pooling_avg <= 1.004)
# if (sep_num_filters > 231.996) and (sep_num_filters > 273.504) and (sep_num_filters > 355.508) and (sep_num_filters > 403.5) and (sep_num_filters <= 752.5) and (sep_num_filters <= 664.497) and (sep_num_filters <= 621.0) and (sep_num_filters > 488.508) and (sep_num_filters > 532.498) and (sep_num_filters <= 613.501) and (sep_num_filters <= 540.5) and (sep_num_filters > 535.499) and (num_residual_blocks > 3.496) and (num_dense_layers <= 1.999) and (categorical_pooling_flatten <= 0.5) and (categorical_pooling_avg <= 1.002)
# if (sep_num_filters <= 231.996) and (sep_num_filters <= 145.503) and (sep_num_filters <= 137.5) and (initial_strides <= 2.997) and (categorical_activation_selu <= 0.495) and (categorical_conv2dnumfilters_128 <= -0.001)
# 969

# %%
# from itertools import combinations

# # Given rule list
# rule_list = rules

# # Function to extract features from a rule
# def extract_features(rule):
#     features = set(rule.split("and"))
#     return features

# # Function to calculate Jaccard similarity between two rules
# def jaccard_similarity(rule1, rule2):
#     features1 = extract_features(rule1)
#     features2 = extract_features(rule2)
#     intersection = len(features1.intersection(features2))
#     union = len(features1.union(features2))
    
#     if union == 0:
#         return 0.0  # Handle the case where both sets are empty
#     else:
#         return intersection / union

# # Calculate Jaccard similarity between all pairs of rules and collect them
# similarities = []
# for rule1, rule2 in combinations(rule_list, 2):
#     similarity = jaccard_similarity(rule1, rule2)
#     similarities.append(similarity)

# # Calculate the mean Jaccard similarity for the entire rule set
# mean_similarity = sum(similarities) / len(similarities)

# print(f"Mean Jaccard Similarity for the Rule Set: {mean_similarity:.2f}")

# %%
from skrules import SkopeRules
from sklearn.preprocessing import KBinsDiscretizer
yee = yee/np.max(yee)

# transform the dataset with KBinsDiscretizer
enc = KBinsDiscretizer(n_bins=2, encode="ordinal", strategy='kmeans')
Y_binned = enc.fit_transform(yee.reshape(-1, 1))

clf1 = SkopeRules(
    max_depth_duplication=3, max_depth=3, max_features=0.5,
    max_samples_features=0.5, random_state=0, n_estimators=20,
    feature_names=Xe.columns, recall_min=0.04, precision_min=0.6)

clf1.fit(samp, Y_binned)

p = clf.predict(test_set)


# Define your bounds
lower_bounds = [flattened_mean[i] - 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]
upper_bounds = [flattened_mean[i] + 0.5*flattened_mean[i]  for i in range(len(flattened_mean))]

# Initialize a count for predictions within bounds
clf_count_within_bounds = sum(1 for prediction, lower_bound, upper_bound in zip(p, lower_bounds, upper_bounds) if lower_bound <= prediction <= upper_bound)

# Calculate the percentage within bounds
percentage_within_bounds = (clf_count_within_bounds / len(p)) 

# Print the result
print(f"Percentage of predictions within bounds: {percentage_within_bounds}%")

print(len(clf1.rules_))
print(clf1.rules_)
# Out:
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning:A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#  c:\users\uif75022\phddevstuff\rxboplusdev\rxboplus\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning:`base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Percentage of predictions within bounds: 0.871%
# 9
# [('sep_num_filters <= 273.5037078857422 and sep_num_filters > 238.99710083007812', (1.0, 0.23626373626373626, 2)), ('sep_num_filters <= 273.5037078857422 and sep_num_filters > 239.50214385986328 and num_residual_blocks <= 8.006944179534912', (1.0, 0.22162162162162163, 2)), ('sep_num_filters <= 270.4953155517578 and sep_num_filters > 239.00221252441406 and categorical_activation_relu <= 0.002524379175156355', (1.0, 0.11475409836065574, 2)), ('sep_num_filters <= 275.505126953125 and sep_num_filters > 239.00221252441406 and categorical_activation_relu > 0.002524379175156355', (1.0, 0.1092896174863388, 2)), ('sep_num_filters > 751.498779296875 and categorical_activation_relu > 0.0027288567507639527', (1.0, 0.05913978494623656, 2)), ('categorical_conv2dnumfilters_64 > 1.004474401473999 and dropout_rate > 0.9948501884937286 and categorical_conv2dnumfilters_128 <= 0.00019133463138132356', (0.8333333333333334, 0.05434782608695652, 2)), ('sep_num_filters > 749.50048828125 and num_residual_blocks <= 8.006944179534912 and categorical_activation_relu > 0.002400144934654236', (0.9, 0.05, 2)), ('sep_num_filters > 211.5008773803711 and num_residual_blocks > 8.006929397583008 and learning_rate <= 0.9956328272819519', (0.8888888888888888, 0.044444444444444446, 2)), ('categorical_conv2dnumfilters_64 > 1.004474401473999 and num_residual_blocks > 5.506800413131714 and categorical_pooling_flatten <= 0.006253310013562441', (0.8, 0.04419889502762431, 2))]
